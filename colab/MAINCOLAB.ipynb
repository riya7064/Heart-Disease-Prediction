# %% [markdown]
# # NH3 / H2 Qubit Hamiltonian (Colab Minimal)
#
# This notebook now defers all logic to the repository code. Workflow:
#
# 1. Install pinned dependencies (Qiskit 2.x, qiskit-nature, PySCF).
# 2. Clone the repo.
# 3. Run the CLI script for NH3 (active space, 6 qubits) or H2 (4 qubits).
# 4. (Optional) Use fallback only (`--force-precomputed`) if PySCF fails.
#
# See repository README for details and provenance notes.

# %%
# === Master Environment + Repo Setup (Run FIRST) ===
import sys, subprocess, importlib, os, pathlib, numpy as np

# 1. Pin core quantum chemistry stack (idempotent)
PKGS = ['qiskit==2.1.2','qiskit-nature==0.7.2','pyscf==2.6.1','qiskit-aer']
subprocess.check_call([sys.executable,'-m','pip','install','--upgrade','--no-cache-dir']+PKGS)

# 2. Clone / update repo containing vqeskeletal.py (GroundStateFinder)
REPO_URL = 'https://github.com/Kukyos/GroundStateFinder.git'
REPO_DIR = pathlib.Path('GroundStateFinder')
if not REPO_DIR.exists():
    subprocess.check_call(['git','clone','--depth','1',REPO_URL])
else:
    try:
        subprocess.check_call(['git','-C',str(REPO_DIR),'pull','--ff-only'])
    except Exception as e:
        print('Git pull failed (continuing):', e)

# 3. Ensure repo root and src on sys.path
paths_added = []
for p in [REPO_DIR, REPO_DIR/'src']:
    if p.exists() and str(p) not in sys.path:
        sys.path.insert(0, str(p))
        paths_added.append(str(p))
print('Added to sys.path:', paths_added)

# 4. Verify presence of vqeskeletal.py
vqefile = REPO_DIR/'vqeskeletal.py'
if not vqefile.exists():
    print('FATAL: vqeskeletal.py not found in cloned repo; aborting.')
else:
    print('Found vqeskeletal.py at', vqefile)

# 5. Core chemistry imports
from pyscf import gto, scf, ao2mo
from qiskit_nature.second_q.hamiltonians import ElectronicEnergy
from qiskit_nature.second_q.problems import ElectronicStructureProblem
from qiskit_nature.second_q.mappers import JordanWignerMapper
from qiskit.quantum_info import SparsePauliOp

# 6. Import repo module
import vqeskeletal as vsk
importlib.reload(vsk)

# 7. Version report
print('\nVersions:')
for mod_name in ['qiskit','qiskit_nature','pyscf','qiskit_aer']:
    try:
        m = importlib.import_module(mod_name)
        print(f'  {mod_name:14s}:', getattr(m,'__version__','?'))
    except Exception as e:
        print(f'  {mod_name:14s}: MISSING ({e})')

# 8. Shared constants (NH3 active space 6 qubits)
NH3_GEOM = 'N 0 0 0; H 0.9377 0 -0.3816; H -0.4688 0.8119 -0.3816; H -0.4688 -0.8119 -0.3816'
ELECTRONS_ALPHA = 2
ELECTRONS_BETA  = 2
ACTIVE_SPATIAL_ORBS = 3  # -> 6 spin orbitals

print('\nEnvironment + repository initialization complete.')
# Out:
# Added to sys.path: ['GroundStateFinder', 'GroundStateFinder/src']
# Found vqeskeletal.py at GroundStateFinder/vqeskeletal.py
#
# Versions:
#   qiskit        : 2.1.2
#   qiskit_nature : 0.7.2
#   pyscf         : 2.6.1
#   qiskit_aer    : 0.17.1
#
# Environment + repository initialization complete.

# %% [markdown]
# Direct NH3 6-qubit active-space build and Pauli expansion (no error handling).

# %% [markdown]
# ## Note
# Padding adds zero-coefficient Pauli strings to reach the requested minimum; physics unaffected.

# %%
# === 2. Build NH3 Active-Space Pauli Hamiltonian (Working Cell 2) ===
# Deterministic active-space construction (6 qubits) from PySCF integrals – NO FALLBACKS.

# SCF
mol = gto.M(atom=NH3_GEOM, basis='sto-3g', unit='Angstrom')
mf = scf.RHF(mol).run()
print(f'SCF energy: {mf.e_tot:.8f} Hartree')

# MO integrals
C = mf.mo_coeff
h_core_ao = mf.get_hcore()
h1_mo = C.T @ h_core_ao @ C
nmo = C.shape[1]
# 2-electron integrals (chemist) in MO basis
eri_mo_full = ao2mo.restore(1, ao2mo.full(mf._eri, C), nmo)

# Active space selection (first 3 spatial orbitals)
act = list(range(ACTIVE_SPATIAL_ORBS))
h1_act = h1_mo[np.ix_(act, act)]
eri_act = eri_mo_full[np.ix_(act, act, act, act)]

# Build ElectronicEnergy from raw integrals and wrap minimal problem info
# (We rely on qiskit-nature API directly; if this errors we STOP and fix.)
ee_act = ElectronicEnergy.from_raw_integrals(h1_act, eri_act)
problem_active = ElectronicStructureProblem(ee_act)

# Minimal wrapper supplying attributes AnsatzPlugin expects (accept flexible arg names)
class MiniProblem:
    def __init__(self, num_spin_orbitals=None, n_spin=None, num_alpha=None, n_alpha=None, num_beta=None, n_beta=None):
        self.num_spin_orbitals = num_spin_orbitals if num_spin_orbitals is not None else n_spin
        a = num_alpha if num_alpha is not None else n_alpha
        b = num_beta if num_beta is not None else n_beta
        self.num_particles = (a, b)
        if self.num_spin_orbitals is None or a is None or b is None:
            raise ValueError('MiniProblem requires spin orbitals and both particle counts.')

# Instantiate with explicit keywords
mini_problem = MiniProblem(num_spin_orbitals=2*ACTIVE_SPATIAL_ORBS,
                           num_alpha=ELECTRONS_ALPHA,
                           num_beta=ELECTRONS_BETA)

# Map fermionic Hamiltonian (robust to API return shape; still NO silent fallback)
mapper = JordanWignerMapper()
raw_ops = problem_active.second_q_ops()
print(f"second_q_ops() return type: {type(raw_ops)}")
if isinstance(raw_ops, dict):
    if 'ElectronicEnergy' not in raw_ops:
        raise KeyError("'ElectronicEnergy' key missing in second_q_ops() dict; keys: " + str(list(raw_ops.keys())))
    ferm_op = raw_ops['ElectronicEnergy']
elif isinstance(raw_ops, tuple):
    # Expect (main_op, aux_ops)
    if len(raw_ops) != 2:
        raise ValueError(f"Tuple from second_q_ops() length {len(raw_ops)} != 2; inspect manually.")
    ferm_op, aux_ops = raw_ops
    print(f"Extracted main fermionic operator from tuple; aux count: {len(aux_ops) if hasattr(aux_ops,'__len__') else 'N/A'}")
elif isinstance(raw_ops, list):
    if len(raw_ops) == 0:
        raise ValueError('Empty list from second_q_ops().')
    ferm_op = raw_ops[0]
    print('Warning: second_q_ops() returned list; using first element as main operator.')
else:
    raise TypeError(f"Unhandled type from second_q_ops(): {type(raw_ops)}")

qubit_op = mapper.map(ferm_op)

# Strict sanity checks (no silent fallbacks)
expected_qubits = 2 * ACTIVE_SPATIAL_ORBS
assert qubit_op.num_qubits == expected_qubits, f"Mapped qubits {qubit_op.num_qubits} != expected {expected_qubits}"
assert mini_problem.num_spin_orbitals == expected_qubits, "MiniProblem spin orbital mismatch"
assert sum(mini_problem.num_particles) == ELECTRONS_ALPHA + ELECTRONS_BETA, "Electron count mismatch"

# Term stats
labels = qubit_op.paulis.to_labels()
nonzero = [ (lbl, coeff) for lbl, coeff in zip(labels, qubit_op.coeffs) if abs(complex(coeff)) > 1e-12 ]
print(f"Qubits: {qubit_op.num_qubits}")
print(f"Non-zero Pauli terms: {len(nonzero)}")
print("Sample terms (first 10):")
for (lbl, coeff) in nonzero[:10]:
    print(f"  {coeff.real:+.8f} * {lbl}")

# System dictionary used downstream (NO fallbacks — this is the single source)
ham_system = {
    'problem_active': mini_problem,
    'mapper': mapper,
    'hamiltonian_active': qubit_op,
    'num_qubits': qubit_op.num_qubits,
    'basis': 'sto3g',
    'geometry': NH3_GEOM,
    'fallback': False
}
print('Hamiltonian system ready (use in later cells).')
# Out:
# converged SCF energy = -55.4540739617975
# SCF energy: -55.45407396 Hartree
# second_q_ops() return type: <class 'tuple'>
# Extracted main fermionic operator from tuple; aux count: 0
# Qubits: 6
# Non-zero Pauli terms: 62
# Sample terms (first 10):
#   -34.39753181 * IIIIII
#   +2.40316023 * IIIIZI
#   +11.07956840 * IIIIIZ
#   +0.19849215 * IIIIZZ
#   +2.03924408 * IIIZII
#   +0.17564461 * IIIZIZ
#   +0.12761114 * IIIIYY
#   +0.00469314 * IIIZYY
#   +0.12761114 * IIIIXX
#   +0.00469314 * IIIZXX
# Hamiltonian system ready (use in later cells).

# %% [markdown]
# ### Cell 3 Description: UCCSD Ansatz Construction
# Build the UCCSD excitation ansatz (with Hartree–Fock reference) sized to the previously created NH3 6‑qubit active-space Hamiltonian (`ham_system`).
#
# Inputs: `ham_system` dictionary containing mapped Pauli Hamiltonian & particle/orbital counts.
# Outputs: `uccsd_ansatz` (stored globally) ready for VQE; prints qubit count, parameter count, depth.
# No fallbacks: raises if ansatz can't be constructed.

# %%
# === 3. Build UCCSD Ansatz (Working Cell 3) ===
import importlib, vqeskeletal as vsk
importlib.reload(vsk)
from vqeskeletal import AnsatzPlugin

# Build ansatz from ham_system (expects mapper + mini problem)
ansatz = AnsatzPlugin(ansatz_reps=1, include_hf_state=True, verbose=True)
ansatz.build_from_hamiltonian(ham_system)
info = ansatz.get_ansatz_info()
print('Ansatz info:', {k: info[k] for k in ['num_qubits','num_parameters','circuit_depth','vqe_ready']})

# Store for later VQE runs
uccsd_ansatz = ansatz
print('Stored as uccsd_ansatz.')
# Out:
# ======================================================================
# BUILDING UCCSD ANSATZ FROM HAMILTONIAN
# ======================================================================
# System: qubits=6 spatial_orbs=3 particles=(2, 2)
# ✓ HF state ready (HartreeFock constructed)
# Ansatz depth=2 gates=5 params=8
# ✓ Ansatz construction complete (params=8)
# Ansatz info: {'num_qubits': 6, 'num_parameters': 8, 'circuit_depth': 2, 'vqe_ready': True}
# Stored as uccsd_ansatz.

# %% [markdown]
# ### Cell 3b Description: Optional Compact Ansatz Summary
# Generates an auxiliary UCCSD ansatz using helper utilities (`groundstate` package functions) to display a concise circuit/parameter preview. Safe to skip; does not affect later VQE cells. Purely informational.

# %%
# OPTIONAL: Compact UCCSD summary using provided helper utilities (repo already cloned)
import numpy as np, importlib
try:
    from groundstate import build_molecule_qubit_hamiltonian, uccsd_for_hamiltonian, circuit_summary
except ImportError:
    print('groundstate helpers not found (ensure repo cloned). Skipping summary.')
else:
    nh3_geom = NH3_GEOM
    ham = build_molecule_qubit_hamiltonian('NH3')
    ansatz_tmp, params_tmp = uccsd_for_hamiltonian(nh3_geom, ham, param_scale=0.02, seed=42)
    particles = ansatz_tmp.num_particles if isinstance(ansatz_tmp.num_particles,(tuple,list)) else (ansatz_tmp.num_particles, ansatz_tmp.num_particles)
    active_e = sum(particles)
    spatial = ansatz_tmp.num_spatial_orbitals
    print(f"Active space: {active_e} electrons, {spatial} orbitals -> {ansatz_tmp.num_qubits} qubits")
    print("Parameters:", np.array2string(params_tmp, separator=' ', max_line_width=120))
    print("\nCircuit (compact, high-level):")
    print(circuit_summary(ansatz_tmp, max_gates=25, decompose=False))
# Out:
# Active space: 4 electrons, 3 orbitals -> 6 qubits
# Parameters: [ 0.00609434 -0.02079968  0.01500902  0.01881129 -0.0390207  -0.02604359  0.00255681 -0.00632485]
#
# Circuit (compact, high-level):
# UCCSD: qubits=6 params=8 depth=1 (decomposed=False)
# Parameters: t[0], t[1], t[2], t[3], t[4], t[5], t[6], t[7]
#      ┌──────────────────────────────────────────────────────┐
# q_0: ┤0                                                     ├
#      │                                                      │
# q_1: ┤1                                                     ├
#      │                                                      │
# q_2: ┤2                                                     ├
#      │  EvolvedOps(t[0],t[1],t[2],t[3],t[4],t[5],t[6],t[7]) │
# q_3: ┤3                                                     ├
#      │                                                      │
# q_4: ┤4                                                     ├
#      │                                                      │
# q_5: ┤5                                                     ├
#      └──────────────────────────────────────────────────────┘

# %% [markdown]
# ### VQE Skeleton Integration
# Demonstrate integrating the repository's VQE skeleton (`vqeskeletal.py`) with a simple optimizer plugin.
#
# This cell will:
# 1. Ensure the repo clone is present / updated.
# 2. Import the skeleton classes.
# 3. Define a minimal gradient-free optimizer (coordinate search) that fits the plugin interface.
# 4. Build the Hamiltonian + UCCSD ansatz via the skeleton plugins.
# 5. Run a mock VQE (note: expectation function is a placeholder returning 0.0 in the skeleton).
#
# You can later replace the placeholder expectation with a real Estimator evaluation and plug in a hybrid (global→local) optimizer.

# %% [markdown]
# ### Cell 4 Description: Coordinate-Descent VQE Integration
# Rebuilds a fresh UCCSD ansatz plugin from `ham_system`, wraps the Hamiltonian with a direct plugin, performs an Estimator sanity check, then runs a lightweight coordinate-descent optimization (no stochastic SPSA here). Provides an initial exact estimator energy and improvement after local search. Raises if any estimator anomaly is detected.

# %%
# === VQE Skeleton Integration (REAL Hamiltonian, NO FALLBACK) ===

# Uses the previously built `ham_system` (Cell 2) and REBUILDS a fresh UCCSD ansatz locally.
# If you see an energy near -5, the estimator path failed — we raise immediately.


import importlib, numpy as np, vqeskeletal as vsk
from vqeskeletal import AnsatzPlugin, ZNEDenoiserPlugin, VQE
from qiskit.quantum_info import SparsePauliOp
from vqeskeletal import GenericAnsatzPlugin


# Assert prerequisites
assert 'ham_system' in globals(), 'ham_system missing (run Cell 2)'


# Minimal direct Hamiltonian plugin wrapper (no internal reconstruction)
class DirectHamPlugin:
    def __init__(self, system_dict):
        self.system_dict = system_dict
    def get_hamiltonian(self):
        return self.system_dict

# Coordinate Descent Optimizer (unchanged logic, but clearer prints)
class CoordinateDescentOptimizer(vsk.ClassicalOptimizerPlugin):
    def __init__(self, max_iters=8, step=0.25, shrink=0.5, tol=1e-6, verbose=True):
        self.max_iters=max_iters; self.step=step; self.shrink=shrink; self.tol=tol; self.verbose=verbose
    def optimize(self, objective_function, initial_params):
        params = np.array(initial_params, dtype=float)
        best_val = objective_function(params); step=self.step
        if self.verbose: print(f'[CD] Initial energy: {best_val:.10f}')
        for it in range(self.max_iters):
            improved=False
            for i in range(len(params)):
                for d in (+1,-1):
                    trial = params.copy(); trial[i]+=d*step
                    val=objective_function(trial)
                    if val < best_val - self.tol:
                        best_val=val; params=trial; improved=True
                        if self.verbose: print(f'[CD] iter {it} param {i} {"+" if d>0 else "-"} -> {best_val:.10f}')
            if not improved:
                step*=self.shrink
                if self.verbose: print(f'[CD] No improvement; shrink step -> {step}')
                if step < self.tol:
                    if self.verbose: print('[CD] Converged (step below tol)')
                    break
        return params

# Rebuild ansatz plugin from real ham_system (Generic baseline, not UCCSD)
# robustly read number of qubits from either:
#  - ham_system['num_qubits'] (int), or
#  - ham_system['hamiltonian_active'].num_qubits (object), or
#  - ham_system['hamiltonian_active'].num_qubits (if ham_system is the actual hamiltonian object)
from vqeskeletal import GenericAnsatzPlugin

# determine num_qubits safely (used inside plugin; plugin also tries to handle variations)
def _ensure_ham_system_with_num_qubits(hs):
    if isinstance(hs, dict):
        if 'num_qubits' in hs and int(hs['num_qubits']) > 0:
            return hs
        if 'hamiltonian_active' in hs and getattr(hs['hamiltonian_active'], 'num_qubits', None):
            # inject a convenience key used by GenericAnsatzPlugin
            try:
                hs_with = dict(hs)
                hs_with['num_qubits'] = int(hs['hamiltonian_active'].num_qubits)
                return hs_with
            except Exception:
                return hs
    else:
        # hs might already be the Hamiltonian object with .num_qubits
        try:
            return {'num_qubits': int(hs.num_qubits), 'hamiltonian_active': hs}
        except Exception:
            return hs

ham_in = _ensure_ham_system_with_num_qubits(ham_system)

ansatz_plugin = GenericAnsatzPlugin(layers=2, entanglement='linear', verbose=True)
ansatz_plugin.build_from_hamiltonian(ham_in)
info = ansatz_plugin.get_ansatz_info()
print('Ansatz info (direct):', {k: info[k] for k in ['num_qubits','num_parameters','circuit_depth','vqe_ready']})
assert info['vqe_ready'], 'Ansatz not VQE-ready'

# Prepare plugins (note: ZNE with [1.0] is a no-op)
ham_plugin = DirectHamPlugin(ham_system)
zne_plugin = ZNEDenoiserPlugin(noise_factors=[1.0], extrapolation_method='linear', verbose=False)
coord_opt = CoordinateDescentOptimizer(max_iters=8, step=0.25, shrink=0.5, tol=1e-6, verbose=True)

# Instantiate VQE and run
vqe_instance = VQE(ansatz_plugin, ham_plugin, coord_opt, zne_plugin, verbose=True)

# Initial parameters (zero start for HEA; NOT HF)
init = ansatz_plugin.get_initial_parameters('zero')

# Sanity: direct estimator energy BEFORE optimization
try:
    from qiskit_aer.primitives import Estimator
    est = Estimator()
    trial0 = ansatz_plugin.get_trial_wavefunction(init)
    e0 = est.run([trial0],[ham_system['hamiltonian_active']]).result().values[0]
    print(f'Initial estimator energy (raw) = {e0:.10f} Hartree')
    if abs(e0 + 5) < 0.5:
        raise RuntimeError('Estimator returned suspicious ~-5 energy (placeholder). Investigate measurement path.')
except Exception as ee:
    print('Estimator pre-check failed:', ee)
    raise

# Optimize
opt_params = coord_opt.optimize(vqe_instance.objective_function, init)
final_energy = vqe_instance.objective_function(opt_params)
print('\n[CoordinateDescent VQE] Final energy:', f'{final_energy:.10f}')
print('[CoordinateDescent VQE] Improvement:', f'{(e0-final_energy):.10f} Hartree')

# Expose for summary table
vqe_cd = vqe_instance
energy_cd = final_energy
# Out:
# Ansatz info (direct): {'num_qubits': 6, 'num_parameters': 8, 'circuit_depth': 2, 'vqe_ready': True}
# 🔄 Initializing VQE system...
# ✓ Quantum estimator setup complete (Qiskit Aer)
# Initial estimator energy (raw) = -56.3346496701 Hartree
#
# ============================================================
# 🔄 VQE ITERATION 1
# ============================================================
# 📊 Energy = -56.34350345 Hartree
# 📊 Energy = -35356.0555 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -21.94597164 Hartree
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 8
#    Parameter range: [ 0.0000,  0.0000]
#    Parameter variance:  0.0000
#    RMS parameter:  0.0000
#    Parameters:
#      θ[ 0]= 0.0000 θ[ 1]= 0.0000 θ[ 2]= 0.0000 θ[ 3]= 0.0000
#      θ[ 4]= 0.0000 θ[ 5]= 0.0000 θ[ 6]= 0.0000 θ[ 7]= 0.0000
#    ==================================================
# [CD] Initial energy: -56.3435034487
#
# ============================================================
# 🔄 VQE ITERATION 2
# ============================================================
# 📊 Energy = -55.35681804 Hartree
# 📊 Energy = -34736.9015 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -20.95928623 Hartree
# 📈 Energy improvement: -0.98668540 Hartree (-619.1540 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 8
#    Parameter range: [ 0.0000,  0.2500]
#    Parameter variance:  0.0068
#    RMS parameter:  0.0884
#    Parameters:
#      θ[ 0]= 0.2500 θ[ 1]= 0.0000 θ[ 2]= 0.0000 θ[ 3]= 0.0000
#      θ[ 4]= 0.0000 θ[ 5]= 0.0000 θ[ 6]= 0.0000 θ[ 7]= 0.0000
#    ==================================================
#
# ============================================================
# 🔄 VQE ITERATION 3
# ============================================================
# 📊 Energy = -55.35681804 Hartree
# 📊 Energy = -34736.9015 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -20.95928623 Hartree
# 📈 Energy improvement: -0.00000000 Hartree (-0.0000 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 8
#    Parameter range: [-0.2500,  0.0000]
#    Parameter variance:  0.0068
#    RMS parameter:  0.0884
#    Parameters:
#      θ[ 0]=-0.2500 θ[ 1]= 0.0000 θ[ 2]= 0.0000 θ[ 3]= 0.0000
#      θ[ 4]= 0.0000 θ[ 5]= 0.0000 θ[ 6]= 0.0000 θ[ 7]= 0.0000
#    ==================================================
#
# ============================================================
# 🔄 VQE ITERATION 4
# ============================================================
# 📊 Energy = -56.30787584 Hartree
# 📊 Energy = -35333.6989 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -21.91034402 Hartree
# 📈 Energy improvement: 0.95105779 Hartree (596.7973 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 8
#    Parameter range: [ 0.0000,  0.2500]
#    Parameter variance:  0.0068
#    RMS parameter:  0.0884
#    Parameters:
#      θ[ 0]= 0.0000 θ[ 1]= 0.2500 θ[ 2]= 0.0000 θ[ 3]= 0.0000
#      θ[ 4]= 0.0000 θ[ 5]= 0.0000 θ[ 6]= 0.0000 θ[ 7]= 0.0000
#    ==================================================
#
# ============================================================
# 🔄 VQE ITERATION 5
# ============================================================
# 📊 Energy = -56.30787584 Hartree
# 📊 Energy = -35333.6989 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -21.91034402 Hartree
# 📈 Energy improvement: 0.00000000 Hartree (0.0000 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 8
#    Parameter range: [-0.2500,  0.0000]
#    Parameter variance:  0.0068
#    RMS parameter:  0.0884
#    Parameters:
#      θ[ 0]= 0.0000 θ[ 1]=-0.2500 θ[ 2]= 0.0000 θ[ 3]= 0.0000
#      θ[ 4]= 0.0000 θ[ 5]= 0.0000 θ[ 6]= 0.0000 θ[ 7]= 0.0000
#    ==================================================
#
# ============================================================
# 🔄 VQE ITERATION 6
# ============================================================
# 📊 Energy = -55.35681804 Hartree
# 📊 Energy = -34736.9015 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -20.95928623 Hartree
# 📈 Energy improvement: -0.95105779 Hartree (-596.7973 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 8
#    Parameter range: [ 0.0000,  0.2500]
#    Parameter variance:  0.0068
#    RMS parameter:  0.0884
#    Parameters:
#      θ[ 0]= 0.0000 θ[ 1]= 0.0000 θ[ 2]= 0.2500 θ[ 3]= 0.0000
#      θ[ 4]= 0.0000 θ[ 5]= 0.0000 θ[ 6]= 0.0000 θ[ 7]= 0.0000
#    ==================================================
#
# ============================================================
# 🔄 VQE ITERATION 7
# ============================================================
# 📊 Energy = -55.35681804 Hartree
# 📊 Energy = -34736.9015 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -20.95928623 Hartree
# 📈 Energy improvement: 0.00000000 Hartree (0.0000 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 8
#    Parameter range: [-0.2500,  0.0000]
#    Parameter variance:  0.0068
#    RMS parameter:  0.0884
#    Parameters:
#      θ[ 0]= 0.0000 θ[ 1]= 0.0000 θ[ 2]=-0.2500 θ[ 3]= 0.0000
#      θ[ 4]= 0.0000 θ[ 5]= 0.0000 θ[ 6]= 0.0000 θ[ 7]= 0.0000
#    ==================================================
#
# ============================================================
# 🔄 VQE ITERATION 8
# ============================================================
# 📊 Energy = -56.30787584 Hartree
# 📊 Energy = -35333.6989 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -21.91034402 Hartree
# 📈 Energy improvement: 0.95105779 Hartree (596.7973 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 8
#    Parameter range: [ 0.0000,  0.2500]
#    Parameter variance:  0.0068
#    RMS parameter:  0.0884
#    Parameters:
#      θ[ 0]= 0.0000 θ[ 1]= 0.0000 θ[ 2]= 0.0000 θ[ 3]= 0.2500
#      θ[ 4]= 0.0000 θ[ 5]= 0.0000 θ[ 6]= 0.0000 θ[ 7]= 0.0000
#    ==================================================
#
# ============================================================
# 🔄 VQE ITERATION 9
# ============================================================
# 📊 Energy = -56.30787584 Hartree
# 📊 Energy = -35333.6989 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -21.91034402 Hartree
# 📈 Energy improvement: -0.00000000 Hartree (-0.0000 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 8
#    Parameter range: [-0.2500,  0.0000]
#    Parameter variance:  0.0068
#    RMS parameter:  0.0884
#    Parameters:
#      θ[ 0]= 0.0000 θ[ 1]= 0.0000 θ[ 2]= 0.0000 θ[ 3]=-0.2500
#      θ[ 4]= 0.0000 θ[ 5]= 0.0000 θ[ 6]= 0.0000 θ[ 7]= 0.0000
#    ==================================================
#
# ============================================================
# 🔄 VQE ITERATION 10
# ============================================================
# 📊 Energy = -54.16450709 Hartree
# 📊 Energy = -33988.7157 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -19.76697527 Hartree
# 📈 Energy improvement: -2.14336875 Hartree (-1344.9832 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 8
#    Parameter range: [ 0.0000,  0.2500]
#    Parameter variance:  0.0068
#    RMS parameter:  0.0884
#    Parameters:
#      θ[ 0]= 0.0000 θ[ 1]= 0.0000 θ[ 2]= 0.0000 θ[ 3]= 0.0000
#      θ[ 4]= 0.2500 θ[ 5]= 0.0000 θ[ 6]= 0.0000 θ[ 7]= 0.0000
#    ==================================================
#
# ============================================================
# 🔄 VQE ITERATION 11
# ============================================================
# 📊 Energy = -54.17349242 Hartree
# 📊 Energy = -33994.3541 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -19.77596060 Hartree
# 📈 Energy improvement: 0.00898533 Hartree (5.6384 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 8
#    Parameter range: [-0.2500,  0.0000]
#    Parameter variance:  0.0068
#    RMS parameter:  0.0884
#    Parameters:
#      θ[ 0]= 0.0000 θ[ 1]= 0.0000 θ[ 2]= 0.0000 θ[ 3]= 0.0000
#      θ[ 4]=-0.2500 θ[ 5]= 0.0000 θ[ 6]= 0.0000 θ[ 7]= 0.0000
#    ==================================================
#
# ============================================================
# 🔄 VQE ITERATION 12
# ============================================================
# 📊 Energy = -55.30481831 Hartree
# 📊 Energy = -34704.2712 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -20.90728649 Hartree
# 📈 Energy improvement: 1.13132589 Hartree (709.9172 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 8
#    Parameter range: [ 0.0000,  0.2500]
#    Parameter variance:  0.0068
#    RMS parameter:  0.0884
#    Parameters:
#      θ[ 0]= 0.0000 θ[ 1]= 0.0000 θ[ 2]= 0.0000 θ[ 3]= 0.0000
#      θ[ 4]= 0.0000 θ[ 5]= 0.2500 θ[ 6]= 0.0000 θ[ 7]= 0.0000
#    ==================================================
#
# ============================================================
# 🔄 VQE ITERATION 13
# ============================================================
# 📊 Energy = -55.31931201 Hartree
# 📊 Energy = -34713.3662 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -20.92178019 Hartree
# 📈 Energy improvement: 0.01449370 Hartree (9.0949 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 8
#    Parameter range: [-0.2500,  0.0000]
#    Parameter variance:  0.0068
#    RMS parameter:  0.0884
#    Parameters:
#      θ[ 0]= 0.0000 θ[ 1]= 0.0000 θ[ 2]= 0.0000 θ[ 3]= 0.0000
#      θ[ 4]= 0.0000 θ[ 5]=-0.2500 θ[ 6]= 0.0000 θ[ 7]= 0.0000
#    ==================================================
#
# ============================================================
# 🔄 VQE ITERATION 14
# ============================================================
# 📊 Energy = -55.30481831 Hartree
# 📊 Energy = -34704.2712 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -20.90728649 Hartree
# 📈 Energy improvement: -0.01449370 Hartree (-9.0949 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 8
#    Parameter range: [ 0.0000,  0.2500]
#    Parameter variance:  0.0068
#    RMS parameter:  0.0884
#    Parameters:
#      θ[ 0]= 0.0000 θ[ 1]= 0.0000 θ[ 2]= 0.0000 θ[ 3]= 0.0000
#      θ[ 4]= 0.0000 θ[ 5]= 0.0000 θ[ 6]= 0.2500 θ[ 7]= 0.0000
#    ==================================================
#
# ============================================================
# 🔄 VQE ITERATION 15
# ============================================================
# 📊 Energy = -55.31931201 Hartree
# 📊 Energy = -34713.3662 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -20.92178019 Hartree
# 📈 Energy improvement: 0.01449370 Hartree (9.0949 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 8
#    Parameter range: [-0.2500,  0.0000]
#    Parameter variance:  0.0068
#    RMS parameter:  0.0884
#    Parameters:
#      θ[ 0]= 0.0000 θ[ 1]= 0.0000 θ[ 2]= 0.0000 θ[ 3]= 0.0000
#      θ[ 4]= 0.0000 θ[ 5]= 0.0000 θ[ 6]=-0.2500 θ[ 7]= 0.0000
#    ==================================================
#
# ============================================================
# 🔄 VQE ITERATION 16
# ============================================================
# 📊 Energy = -56.20782947 Hartree
# 📊 Energy = -35270.9189 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -21.81029766 Hartree
# 📈 Energy improvement: 0.88851746 Hartree (557.5527 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 8
#    Parameter range: [ 0.0000,  0.2500]
#    Parameter variance:  0.0068
#    RMS parameter:  0.0884
#    Parameters:
#      θ[ 0]= 0.0000 θ[ 1]= 0.0000 θ[ 2]= 0.0000 θ[ 3]= 0.0000
#      θ[ 4]= 0.0000 θ[ 5]= 0.0000 θ[ 6]= 0.0000 θ[ 7]= 0.2500
#    ==================================================
#
# ============================================================
# 🔄 VQE ITERATION 17
# ============================================================
# 📊 Energy = -56.32776189 Hartree
# 📊 Energy = -35346.1775 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -21.93023007 Hartree
# 📈 Energy improvement: 0.11993242 Hartree (75.2587 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 8
#    Parameter range: [-0.2500,  0.0000]
#    Parameter variance:  0.0068
#    RMS parameter:  0.0884
#    Parameters:
#      θ[ 0]= 0.0000 θ[ 1]= 0.0000 θ[ 2]= 0.0000 θ[ 3]= 0.0000
#      θ[ 4]= 0.0000 θ[ 5]= 0.0000 θ[ 6]= 0.0000 θ[ 7]=-0.2500
#    ==================================================
# [CD] No improvement; shrink step -> 0.125
#
# ============================================================
# 🔄 VQE ITERATION 18
# ============================================================
# 📊 Energy = -56.09293735 Hartree
# 📊 Energy = -35198.8230 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -21.69540554 Hartree
# 📈 Energy improvement: -0.23482453 Hartree (-147.3545 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 8
#    Parameter range: [ 0.0000,  0.1250]
#    Parameter variance:  0.0017
#    RMS parameter:  0.0442
#    Parameters:
#      θ[ 0]= 0.1250 θ[ 1]= 0.0000 θ[ 2]= 0.0000 θ[ 3]= 0.0000
#      θ[ 4]= 0.0000 θ[ 5]= 0.0000 θ[ 6]= 0.0000 θ[ 7]= 0.0000
#    ==================================================
#
# ============================================================
# 🔄 VQE ITERATION 19
# ============================================================
# 📊 Energy = -56.09293735 Hartree
# 📊 Energy = -35198.8230 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -21.69540554 Hartree
# 📈 Energy improvement: -0.00000000 Hartree (-0.0000 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 8
#    Parameter range: [-0.1250,  0.0000]
#    Parameter variance:  0.0017
#    RMS parameter:  0.0442
#    Parameters:
#      θ[ 0]=-0.1250 θ[ 1]= 0.0000 θ[ 2]= 0.0000 θ[ 3]= 0.0000
#      θ[ 4]= 0.0000 θ[ 5]= 0.0000 θ[ 6]= 0.0000 θ[ 7]= 0.0000
#    ==================================================
#
# ============================================================
# 🔄 VQE ITERATION 20
# ============================================================
# 📊 Energy = -56.33445591 Hartree
# 📊 Energy = -35350.3781 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -21.93692410 Hartree
# 📈 Energy improvement: 0.24151856 Hartree (151.5551 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 8
#    Parameter range: [ 0.0000,  0.1250]
#    Parameter variance:  0.0017
#    RMS parameter:  0.0442
#    Parameters:
#      θ[ 0]= 0.0000 θ[ 1]= 0.1250 θ[ 2]= 0.0000 θ[ 3]= 0.0000
#      θ[ 4]= 0.0000 θ[ 5]= 0.0000 θ[ 6]= 0.0000 θ[ 7]= 0.0000
#    ==================================================
#
# ============================================================
# 🔄 VQE ITERATION 21
# ============================================================
# 📊 Energy = -56.33445591 Hartree
# 📊 Energy = -35350.3781 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -21.93692410 Hartree
# 📈 Energy improvement: 0.00000000 Hartree (0.0000 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 8
#    Parameter range: [-0.1250,  0.0000]
#    Parameter variance:  0.0017
#    RMS parameter:  0.0442
#    Parameters:
#      θ[ 0]= 0.0000 θ[ 1]=-0.1250 θ[ 2]= 0.0000 θ[ 3]= 0.0000
#      θ[ 4]= 0.0000 θ[ 5]= 0.0000 θ[ 6]= 0.0000 θ[ 7]= 0.0000
#    ==================================================
#
# ============================================================
# 🔄 VQE ITERATION 22
# ============================================================
# 📊 Energy = -56.09293735 Hartree
# 📊 Energy = -35198.8230 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -21.69540554 Hartree
# 📈 Energy improvement: -0.24151856 Hartree (-151.5551 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 8
#    Parameter range: [ 0.0000,  0.1250]
#    Parameter variance:  0.0017
#    RMS parameter:  0.0442
#    Parameters:
#      θ[ 0]= 0.0000 θ[ 1]= 0.0000 θ[ 2]= 0.1250 θ[ 3]= 0.0000
#      θ[ 4]= 0.0000 θ[ 5]= 0.0000 θ[ 6]= 0.0000 θ[ 7]= 0.0000
#    ==================================================
#
# ============================================================
# 🔄 VQE ITERATION 23
# ============================================================
# 📊 Energy = -56.09293735 Hartree
# 📊 Energy = -35198.8230 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -21.69540554 Hartree
# 📈 Energy improvement: -0.00000000 Hartree (-0.0000 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 8
#    Parameter range: [-0.1250,  0.0000]
#    Parameter variance:  0.0017
#    RMS parameter:  0.0442
#    Parameters:
#      θ[ 0]= 0.0000 θ[ 1]= 0.0000 θ[ 2]=-0.1250 θ[ 3]= 0.0000
#      θ[ 4]= 0.0000 θ[ 5]= 0.0000 θ[ 6]= 0.0000 θ[ 7]= 0.0000
#    ==================================================
#
# ============================================================
# 🔄 VQE ITERATION 24
# ============================================================
# 📊 Energy = -56.33445591 Hartree
# 📊 Energy = -35350.3781 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -21.93692410 Hartree
# 📈 Energy improvement: 0.24151856 Hartree (151.5551 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 8
#    Parameter range: [ 0.0000,  0.1250]
#    Parameter variance:  0.0017
#    RMS parameter:  0.0442
#    Parameters:
#      θ[ 0]= 0.0000 θ[ 1]= 0.0000 θ[ 2]= 0.0000 θ[ 3]= 0.1250
#      θ[ 4]= 0.0000 θ[ 5]= 0.0000 θ[ 6]= 0.0000 θ[ 7]= 0.0000
#    ==================================================
#
# ============================================================
# 🔄 VQE ITERATION 25
# ============================================================
# 📊 Energy = -56.33445591 Hartree
# 📊 Energy = -35350.3781 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -21.93692410 Hartree
# 📈 Energy improvement: -0.00000000 Hartree (-0.0000 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 8
#    Parameter range: [-0.1250,  0.0000]
#    Parameter variance:  0.0017
#    RMS parameter:  0.0442
#    Parameters:
#      θ[ 0]= 0.0000 θ[ 1]= 0.0000 θ[ 2]= 0.0000 θ[ 3]=-0.1250
#      θ[ 4]= 0.0000 θ[ 5]= 0.0000 θ[ 6]= 0.0000 θ[ 7]= 0.0000
#    ==================================================
#
# ============================================================
# 🔄 VQE ITERATION 26
# ============================================================
# 📊 Energy = -55.78897569 Hartree
# 📊 Energy = -35008.0843 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -21.39144388 Hartree
# 📈 Energy improvement: -0.54548022 Hartree (-342.2937 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 8
#    Parameter range: [ 0.0000,  0.1250]
#    Parameter variance:  0.0017
#    RMS parameter:  0.0442
#    Parameters:
#      θ[ 0]= 0.0000 θ[ 1]= 0.0000 θ[ 2]= 0.0000 θ[ 3]= 0.0000
#      θ[ 4]= 0.1250 θ[ 5]= 0.0000 θ[ 6]= 0.0000 θ[ 7]= 0.0000
#    ==================================================
#
# ============================================================
# 🔄 VQE ITERATION 27
# ============================================================
# 📊 Energy = -55.79361250 Hartree
# 📊 Energy = -35010.9940 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -21.39608069 Hartree
# 📈 Energy improvement: 0.00463681 Hartree (2.9096 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 8
#    Parameter range: [-0.1250,  0.0000]
#    Parameter variance:  0.0017
#    RMS parameter:  0.0442
#    Parameters:
#      θ[ 0]= 0.0000 θ[ 1]= 0.0000 θ[ 2]= 0.0000 θ[ 3]= 0.0000
#      θ[ 4]=-0.1250 θ[ 5]= 0.0000 θ[ 6]= 0.0000 θ[ 7]= 0.0000
#    ==================================================
#
# ============================================================
# 🔄 VQE ITERATION 28
# ============================================================
# 📊 Energy = -56.07783279 Hartree
# 📊 Energy = -35189.3448 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -21.68030098 Hartree
# 📈 Energy improvement: 0.28422029 Hartree (178.3508 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 8
#    Parameter range: [ 0.0000,  0.1250]
#    Parameter variance:  0.0017
#    RMS parameter:  0.0442
#    Parameters:
#      θ[ 0]= 0.0000 θ[ 1]= 0.0000 θ[ 2]= 0.0000 θ[ 3]= 0.0000
#      θ[ 4]= 0.0000 θ[ 5]= 0.1250 θ[ 6]= 0.0000 θ[ 7]= 0.0000
#    ==================================================
#
# ============================================================
# 🔄 VQE ITERATION 29
# ============================================================
# 📊 Energy = -56.08531216 Hartree
# 📊 Energy = -35194.0381 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -21.68778035 Hartree
# 📈 Energy improvement: 0.00747937 Hartree (4.6934 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 8
#    Parameter range: [-0.1250,  0.0000]
#    Parameter variance:  0.0017
#    RMS parameter:  0.0442
#    Parameters:
#      θ[ 0]= 0.0000 θ[ 1]= 0.0000 θ[ 2]= 0.0000 θ[ 3]= 0.0000
#      θ[ 4]= 0.0000 θ[ 5]=-0.1250 θ[ 6]= 0.0000 θ[ 7]= 0.0000
#    ==================================================
#
# ============================================================
# 🔄 VQE ITERATION 30
# ============================================================
# 📊 Energy = -56.07783279 Hartree
# 📊 Energy = -35189.3448 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -21.68030098 Hartree
# 📈 Energy improvement: -0.00747937 Hartree (-4.6934 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 8
#    Parameter range: [ 0.0000,  0.1250]
#    Parameter variance:  0.0017
#    RMS parameter:  0.0442
#    Parameters:
#      θ[ 0]= 0.0000 θ[ 1]= 0.0000 θ[ 2]= 0.0000 θ[ 3]= 0.0000
#      θ[ 4]= 0.0000 θ[ 5]= 0.0000 θ[ 6]= 0.1250 θ[ 7]= 0.0000
#    ==================================================
#
# ============================================================
# 🔄 VQE ITERATION 31
# ============================================================
# 📊 Energy = -56.08531216 Hartree
# 📊 Energy = -35194.0381 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -21.68778035 Hartree
# 📈 Energy improvement: 0.00747937 Hartree (4.6934 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 8
#    Parameter range: [-0.1250,  0.0000]
#    Parameter variance:  0.0017
#    RMS parameter:  0.0442
#    Parameters:
#      θ[ 0]= 0.0000 θ[ 1]= 0.0000 θ[ 2]= 0.0000 θ[ 3]= 0.0000
#      θ[ 4]= 0.0000 θ[ 5]= 0.0000 θ[ 6]=-0.1250 θ[ 7]= 0.0000
#    ==================================================
#
# ============================================================
# 🔄 VQE ITERATION 32
# ============================================================
# 📊 Energy = -56.29333255 Hartree
# 📊 Energy = -35324.5728 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -21.89580074 Hartree
# 📈 Energy improvement: 0.20802039 Hartree (130.5347 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 8
#    Parameter range: [ 0.0000,  0.1250]
#    Parameter variance:  0.0017
#    RMS parameter:  0.0442
#    Parameters:
#      θ[ 0]= 0.0000 θ[ 1]= 0.0000 θ[ 2]= 0.0000 θ[ 3]= 0.0000
#      θ[ 4]= 0.0000 θ[ 5]= 0.0000 θ[ 6]= 0.0000 θ[ 7]= 0.1250
#    ==================================================
#
# ============================================================
# 🔄 VQE ITERATION 33
# ============================================================
# 📊 Energy = -56.35522278 Hartree
# 📊 Energy = -35363.4095 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -21.95769096 Hartree
# 📈 Energy improvement: 0.06189023 Hartree (38.8367 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 8
#    Parameter range: [-0.1250,  0.0000]
#    Parameter variance:  0.0017
#    RMS parameter:  0.0442
#    Parameters:
#      θ[ 0]= 0.0000 θ[ 1]= 0.0000 θ[ 2]= 0.0000 θ[ 3]= 0.0000
#      θ[ 4]= 0.0000 θ[ 5]= 0.0000 θ[ 6]= 0.0000 θ[ 7]=-0.1250
#    ==================================================
# [CD] iter 1 param 7 - -> -56.3552227770
#
# ============================================================
# 🔄 VQE ITERATION 34
# ============================================================
# 📊 Energy = -56.10447452 Hartree
# 📊 Energy = -35206.0627 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -21.70694270 Hartree
# 📈 Energy improvement: -0.25074826 Hartree (-157.3468 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 8
#    Parameter range: [-0.1250,  0.1250]
#    Parameter variance:  0.0039
#    RMS parameter:  0.0625
#    Parameters:
#      θ[ 0]= 0.1250 θ[ 1]= 0.0000 θ[ 2]= 0.0000 θ[ 3]= 0.0000
#      θ[ 4]= 0.0000 θ[ 5]= 0.0000 θ[ 6]= 0.0000 θ[ 7]=-0.1250
#    ==================================================
#
# ============================================================
# 🔄 VQE ITERATION 35
# ============================================================
# 📊 Energy = -56.10447452 Hartree
# 📊 Energy = -35206.0627 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -21.70694270 Hartree
# 📈 Energy improvement: -0.00000000 Hartree (-0.0000 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 8
#    Parameter range: [-0.1250,  0.0000]
#    Parameter variance:  0.0029
#    RMS parameter:  0.0625
#    Parameters:
#      θ[ 0]=-0.1250 θ[ 1]= 0.0000 θ[ 2]= 0.0000 θ[ 3]= 0.0000
#      θ[ 4]= 0.0000 θ[ 5]= 0.0000 θ[ 6]= 0.0000 θ[ 7]=-0.1250
#    ==================================================
#
# ============================================================
# 🔄 VQE ITERATION 36
# ============================================================
# 📊 Energy = -56.34599308 Hartree
# 📊 Energy = -35357.6178 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -21.94846127 Hartree
# 📈 Energy improvement: 0.24151856 Hartree (151.5551 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 8
#    Parameter range: [-0.1250,  0.1250]
#    Parameter variance:  0.0039
#    RMS parameter:  0.0625
#    Parameters:
#      θ[ 0]= 0.0000 θ[ 1]= 0.1250 θ[ 2]= 0.0000 θ[ 3]= 0.0000
#      θ[ 4]= 0.0000 θ[ 5]= 0.0000 θ[ 6]= 0.0000 θ[ 7]=-0.1250
#    ==================================================
#
# ============================================================
# 🔄 VQE ITERATION 37
# ============================================================
# 📊 Energy = -56.34599308 Hartree
# 📊 Energy = -35357.6178 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -21.94846127 Hartree
# 📈 Energy improvement: -0.00000000 Hartree (-0.0000 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 8
#    Parameter range: [-0.1250,  0.0000]
#    Parameter variance:  0.0029
#    RMS parameter:  0.0625
#    Parameters:
#      θ[ 0]= 0.0000 θ[ 1]=-0.1250 θ[ 2]= 0.0000 θ[ 3]= 0.0000
#      θ[ 4]= 0.0000 θ[ 5]= 0.0000 θ[ 6]= 0.0000 θ[ 7]=-0.1250
#    ==================================================
#
# ============================================================
# 🔄 VQE ITERATION 38
# ============================================================
# 📊 Energy = -56.10447452 Hartree
# 📊 Energy = -35206.0627 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -21.70694270 Hartree
# 📈 Energy improvement: -0.24151856 Hartree (-151.5551 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 8
#    Parameter range: [-0.1250,  0.1250]
#    Parameter variance:  0.0039
#    RMS parameter:  0.0625
#    Parameters:
#      θ[ 0]= 0.0000 θ[ 1]= 0.0000 θ[ 2]= 0.1250 θ[ 3]= 0.0000
#      θ[ 4]= 0.0000 θ[ 5]= 0.0000 θ[ 6]= 0.0000 θ[ 7]=-0.1250
#    ==================================================
#
# ============================================================
# 🔄 VQE ITERATION 39
# ============================================================
# 📊 Energy = -56.10447452 Hartree
# 📊 Energy = -35206.0627 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -21.70694270 Hartree
# 📈 Energy improvement: -0.00000000 Hartree (-0.0000 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 8
#    Parameter range: [-0.1250,  0.0000]
#    Parameter variance:  0.0029
#    RMS parameter:  0.0625
#    Parameters:
#      θ[ 0]= 0.0000 θ[ 1]= 0.0000 θ[ 2]=-0.1250 θ[ 3]= 0.0000
#      θ[ 4]= 0.0000 θ[ 5]= 0.0000 θ[ 6]= 0.0000 θ[ 7]=-0.1250
#    ==================================================
#
# ============================================================
# 🔄 VQE ITERATION 40
# ============================================================
# 📊 Energy = -56.34599308 Hartree
# 📊 Energy = -35357.6178 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -21.94846127 Hartree
# 📈 Energy improvement: 0.24151856 Hartree (151.5551 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 8
#    Parameter range: [-0.1250,  0.1250]
#    Parameter variance:  0.0039
#    RMS parameter:  0.0625
#    Parameters:
#      θ[ 0]= 0.0000 θ[ 1]= 0.0000 θ[ 2]= 0.0000 θ[ 3]= 0.1250
#      θ[ 4]= 0.0000 θ[ 5]= 0.0000 θ[ 6]= 0.0000 θ[ 7]=-0.1250
#    ==================================================
#
# ============================================================
# 🔄 VQE ITERATION 41
# ============================================================
# 📊 Energy = -56.34599308 Hartree
# 📊 Energy = -35357.6178 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -21.94846127 Hartree
# 📈 Energy improvement: -0.00000000 Hartree (-0.0000 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 8
#    Parameter range: [-0.1250,  0.0000]
#    Parameter variance:  0.0029
#    RMS parameter:  0.0625
#    Parameters:
#      θ[ 0]= 0.0000 θ[ 1]= 0.0000 θ[ 2]= 0.0000 θ[ 3]=-0.1250
#      θ[ 4]= 0.0000 θ[ 5]= 0.0000 θ[ 6]= 0.0000 θ[ 7]=-0.1250
#    ==================================================
#
# ============================================================
# 🔄 VQE ITERATION 42
# ============================================================
# 📊 Energy = -55.80193058 Hartree
# 📊 Energy = -35016.2137 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -21.40439877 Hartree
# 📈 Energy improvement: -0.54406250 Hartree (-341.4041 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 8
#    Parameter range: [-0.1250,  0.1250]
#    Parameter variance:  0.0039
#    RMS parameter:  0.0625
#    Parameters:
#      θ[ 0]= 0.0000 θ[ 1]= 0.0000 θ[ 2]= 0.0000 θ[ 3]= 0.0000
#      θ[ 4]= 0.1250 θ[ 5]= 0.0000 θ[ 6]= 0.0000 θ[ 7]=-0.1250
#    ==================================================
#
# ============================================================
# 🔄 VQE ITERATION 43
# ============================================================
# 📊 Energy = -55.80373195 Hartree
# 📊 Energy = -35017.3440 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -21.40620013 Hartree
# 📈 Energy improvement: 0.00180136 Hartree (1.1304 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 8
#    Parameter range: [-0.1250,  0.0000]
#    Parameter variance:  0.0029
#    RMS parameter:  0.0625
#    Parameters:
#      θ[ 0]= 0.0000 θ[ 1]= 0.0000 θ[ 2]= 0.0000 θ[ 3]= 0.0000
#      θ[ 4]=-0.1250 θ[ 5]= 0.0000 θ[ 6]= 0.0000 θ[ 7]=-0.1250
#    ==================================================
#
# ============================================================
# 🔄 VQE ITERATION 44
# ============================================================
# 📊 Energy = -56.08702573 Hartree
# 📊 Energy = -35195.1134 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -21.68949392 Hartree
# 📈 Energy improvement: 0.28329379 Hartree (177.7694 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 8
#    Parameter range: [-0.1250,  0.1250]
#    Parameter variance:  0.0039
#    RMS parameter:  0.0625
#    Parameters:
#      θ[ 0]= 0.0000 θ[ 1]= 0.0000 θ[ 2]= 0.0000 θ[ 3]= 0.0000
#      θ[ 4]= 0.0000 θ[ 5]= 0.1250 θ[ 6]= 0.0000 θ[ 7]=-0.1250
#    ==================================================
#
# ============================================================
# 🔄 VQE ITERATION 45
# ============================================================
# 📊 Energy = -56.09919355 Hartree
# 📊 Energy = -35202.7488 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -21.70166174 Hartree
# 📈 Energy improvement: 0.01216782 Hartree (7.6354 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 8
#    Parameter range: [-0.1250,  0.0000]
#    Parameter variance:  0.0029
#    RMS parameter:  0.0625
#    Parameters:
#      θ[ 0]= 0.0000 θ[ 1]= 0.0000 θ[ 2]= 0.0000 θ[ 3]= 0.0000
#      θ[ 4]= 0.0000 θ[ 5]=-0.1250 θ[ 6]= 0.0000 θ[ 7]=-0.1250
#    ==================================================
#
# ============================================================
# 🔄 VQE ITERATION 46
# ============================================================
# 📊 Energy = -56.08702573 Hartree
# 📊 Energy = -35195.1134 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -21.68949392 Hartree
# 📈 Energy improvement: -0.01216782 Hartree (-7.6354 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 8
#    Parameter range: [-0.1250,  0.1250]
#    Parameter variance:  0.0039
#    RMS parameter:  0.0625
#    Parameters:
#      θ[ 0]= 0.0000 θ[ 1]= 0.0000 θ[ 2]= 0.0000 θ[ 3]= 0.0000
#      θ[ 4]= 0.0000 θ[ 5]= 0.0000 θ[ 6]= 0.1250 θ[ 7]=-0.1250
#    ==================================================
#
# ============================================================
# 🔄 VQE ITERATION 47
# ============================================================
# 📊 Energy = -56.09919355 Hartree
# 📊 Energy = -35202.7488 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -21.70166174 Hartree
# 📈 Energy improvement: 0.01216782 Hartree (7.6354 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 8
#    Parameter range: [-0.1250,  0.0000]
#    Parameter variance:  0.0029
#    RMS parameter:  0.0625
#    Parameters:
#      θ[ 0]= 0.0000 θ[ 1]= 0.0000 θ[ 2]= 0.0000 θ[ 3]= 0.0000
#      θ[ 4]= 0.0000 θ[ 5]= 0.0000 θ[ 6]=-0.1250 θ[ 7]=-0.1250
#    ==================================================
#
# ============================================================
# 🔄 VQE ITERATION 48
# ============================================================
# 📊 Energy = -56.34350345 Hartree
# 📊 Energy = -35356.0555 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -21.94597164 Hartree
# 📈 Energy improvement: 0.24430990 Hartree (153.3067 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 8
#    Parameter range: [ 0.0000,  0.0000]
#    Parameter variance:  0.0000
#    RMS parameter:  0.0000
#    Parameters:
#      θ[ 0]= 0.0000 θ[ 1]= 0.0000 θ[ 2]= 0.0000 θ[ 3]= 0.0000
#      θ[ 4]= 0.0000 θ[ 5]= 0.0000 θ[ 6]= 0.0000 θ[ 7]= 0.0000
#    ==================================================
#
# ============================================================
# 🔄 VQE ITERATION 49
# ============================================================
# 📊 Energy = -56.32776189 Hartree
# 📊 Energy = -35346.1775 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -21.93023007 Hartree
# 📈 Energy improvement: -0.01574156 Hartree (-9.8780 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 8
#    Parameter range: [-0.2500,  0.0000]
#    Parameter variance:  0.0068
#    RMS parameter:  0.0884
#    Parameters:
#      θ[ 0]= 0.0000 θ[ 1]= 0.0000 θ[ 2]= 0.0000 θ[ 3]= 0.0000
#      θ[ 4]= 0.0000 θ[ 5]= 0.0000 θ[ 6]= 0.0000 θ[ 7]=-0.2500
#    ==================================================
# [CD] No improvement; shrink step -> 0.0625
#
# ============================================================
# 🔄 VQE ITERATION 50
# ============================================================
# 📊 Energy = -56.29229020 Hartree
# 📊 Energy = -35323.9187 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -21.89475839 Hartree
# 📈 Energy improvement: -0.03547168 Hartree (-22.2588 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 8
#    Parameter range: [-0.1250,  0.0625]
#    Parameter variance:  0.0024
#    RMS parameter:  0.0494
#    Parameters:
#      θ[ 0]= 0.0625 θ[ 1]= 0.0000 θ[ 2]= 0.0000 θ[ 3]= 0.0000
#      θ[ 4]= 0.0000 θ[ 5]= 0.0000 θ[ 6]= 0.0000 θ[ 7]=-0.1250
#    ==================================================
#
# ============================================================
# 🔄 VQE ITERATION 51
# ============================================================
# 📊 Energy = -56.29229020 Hartree
# 📊 Energy = -35323.9187 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -21.89475839 Hartree
# 📈 Energy improvement: 0.00000000 Hartree (0.0000 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 8
#    Parameter range: [-0.1250,  0.0000]
#    Parameter variance:  0.0019
#    RMS parameter:  0.0494
#    Parameters:
#      θ[ 0]=-0.0625 θ[ 1]= 0.0000 θ[ 2]= 0.0000 θ[ 3]= 0.0000
#      θ[ 4]= 0.0000 θ[ 5]= 0.0000 θ[ 6]= 0.0000 θ[ 7]=-0.1250
#    ==================================================
#
# ============================================================
# 🔄 VQE ITERATION 52
# ============================================================
# 📊 Energy = -56.35290632 Hartree
# 📊 Energy = -35361.9559 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -21.95537450 Hartree
# 📈 Energy improvement: 0.06061611 Hartree (38.0372 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 8
#    Parameter range: [-0.1250,  0.0625]
#    Parameter variance:  0.0024
#    RMS parameter:  0.0494
#    Parameters:
#      θ[ 0]= 0.0000 θ[ 1]= 0.0625 θ[ 2]= 0.0000 θ[ 3]= 0.0000
#      θ[ 4]= 0.0000 θ[ 5]= 0.0000 θ[ 6]= 0.0000 θ[ 7]=-0.1250
#    ==================================================
#
# ============================================================
# 🔄 VQE ITERATION 53
# ============================================================
# 📊 Energy = -56.35290632 Hartree
# 📊 Energy = -35361.9559 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -21.95537450 Hartree
# 📈 Energy improvement: 0.00000000 Hartree (0.0000 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 8
#    Parameter range: [-0.1250,  0.0000]
#    Parameter variance:  0.0019
#    RMS parameter:  0.0494
#    Parameters:
#      θ[ 0]= 0.0000 θ[ 1]=-0.0625 θ[ 2]= 0.0000 θ[ 3]= 0.0000
#      θ[ 4]= 0.0000 θ[ 5]= 0.0000 θ[ 6]= 0.0000 θ[ 7]=-0.1250
#    ==================================================
#
# ============================================================
# 🔄 VQE ITERATION 54
# ============================================================
# 📊 Energy = -56.29229020 Hartree
# 📊 Energy = -35323.9187 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -21.89475839 Hartree
# 📈 Energy improvement: -0.06061611 Hartree (-38.0372 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 8
#    Parameter range: [-0.1250,  0.0625]
#    Parameter variance:  0.0024
#    RMS parameter:  0.0494
#    Parameters:
#      θ[ 0]= 0.0000 θ[ 1]= 0.0000 θ[ 2]= 0.0625 θ[ 3]= 0.0000
#      θ[ 4]= 0.0000 θ[ 5]= 0.0000 θ[ 6]= 0.0000 θ[ 7]=-0.1250
#    ==================================================
#
# ============================================================
# 🔄 VQE ITERATION 55
# ============================================================
# 📊 Energy = -56.29229020 Hartree
# 📊 Energy = -35323.9187 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -21.89475839 Hartree
# 📈 Energy improvement: 0.00000000 Hartree (0.0000 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 8
#    Parameter range: [-0.1250,  0.0000]
#    Parameter variance:  0.0019
#    RMS parameter:  0.0494
#    Parameters:
#      θ[ 0]= 0.0000 θ[ 1]= 0.0000 θ[ 2]=-0.0625 θ[ 3]= 0.0000
#      θ[ 4]= 0.0000 θ[ 5]= 0.0000 θ[ 6]= 0.0000 θ[ 7]=-0.1250
#    ==================================================
#
# ============================================================
# 🔄 VQE ITERATION 56
# ============================================================
# 📊 Energy = -56.35290632 Hartree
# 📊 Energy = -35361.9559 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -21.95537450 Hartree
# 📈 Energy improvement: 0.06061611 Hartree (38.0372 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 8
#    Parameter range: [-0.1250,  0.0625]
#    Parameter variance:  0.0024
#    RMS parameter:  0.0494
#    Parameters:
#      θ[ 0]= 0.0000 θ[ 1]= 0.0000 θ[ 2]= 0.0000 θ[ 3]= 0.0625
#      θ[ 4]= 0.0000 θ[ 5]= 0.0000 θ[ 6]= 0.0000 θ[ 7]=-0.1250
#    ==================================================
#
# ============================================================
# 🔄 VQE ITERATION 57
# ============================================================
# 📊 Energy = -56.35290632 Hartree
# 📊 Energy = -35361.9559 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -21.95537450 Hartree
# 📈 Energy improvement: -0.00000000 Hartree (-0.0000 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 8
#    Parameter range: [-0.1250,  0.0000]
#    Parameter variance:  0.0019
#    RMS parameter:  0.0494
#    Parameters:
#      θ[ 0]= 0.0000 θ[ 1]= 0.0000 θ[ 2]= 0.0000 θ[ 3]=-0.0625
#      θ[ 4]= 0.0000 θ[ 5]= 0.0000 θ[ 6]= 0.0000 θ[ 7]=-0.1250
#    ==================================================
#
# ============================================================
# 🔄 VQE ITERATION 58
# ============================================================
# 📊 Energy = -56.21613016 Hartree
# 📊 Energy = -35276.1276 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -21.81859835 Hartree
# 📈 Energy improvement: -0.13677615 Hartree (-85.8283 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 8
#    Parameter range: [-0.1250,  0.0625]
#    Parameter variance:  0.0024
#    RMS parameter:  0.0494
#    Parameters:
#      θ[ 0]= 0.0000 θ[ 1]= 0.0000 θ[ 2]= 0.0000 θ[ 3]= 0.0000
#      θ[ 4]= 0.0625 θ[ 5]= 0.0000 θ[ 6]= 0.0000 θ[ 7]=-0.1250
#    ==================================================
#
# ============================================================
# 🔄 VQE ITERATION 59
# ============================================================
# 📊 Energy = -56.21703793 Hartree
# 📊 Energy = -35276.6973 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -21.81950612 Hartree
# 📈 Energy improvement: 0.00090776 Hartree (0.5696 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 8
#    Parameter range: [-0.1250,  0.0000]
#    Parameter variance:  0.0019
#    RMS parameter:  0.0494
#    Parameters:
#      θ[ 0]= 0.0000 θ[ 1]= 0.0000 θ[ 2]= 0.0000 θ[ 3]= 0.0000
#      θ[ 4]=-0.0625 θ[ 5]= 0.0000 θ[ 6]= 0.0000 θ[ 7]=-0.1250
#    ==================================================
#
# ============================================================
# 🔄 VQE ITERATION 60
# ============================================================
# 📊 Energy = -56.28637198 Hartree
# 📊 Energy = -35320.2050 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -21.88884017 Hartree
# 📈 Energy improvement: 0.06933405 Hartree (43.5077 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 8
#    Parameter range: [-0.1250,  0.0625]
#    Parameter variance:  0.0024
#    RMS parameter:  0.0494
#    Parameters:
#      θ[ 0]= 0.0000 θ[ 1]= 0.0000 θ[ 2]= 0.0000 θ[ 3]= 0.0000
#      θ[ 4]= 0.0000 θ[ 5]= 0.0625 θ[ 6]= 0.0000 θ[ 7]=-0.1250
#    ==================================================
#
# ============================================================
# 🔄 VQE ITERATION 61
# ============================================================
# 📊 Energy = -56.29250373 Hartree
# 📊 Energy = -35324.0527 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -21.89497192 Hartree
# 📈 Energy improvement: 0.00613175 Hartree (3.8477 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 8
#    Parameter range: [-0.1250,  0.0000]
#    Parameter variance:  0.0019
#    RMS parameter:  0.0494
#    Parameters:
#      θ[ 0]= 0.0000 θ[ 1]= 0.0000 θ[ 2]= 0.0000 θ[ 3]= 0.0000
#      θ[ 4]= 0.0000 θ[ 5]=-0.0625 θ[ 6]= 0.0000 θ[ 7]=-0.1250
#    ==================================================
#
# ============================================================
# 🔄 VQE ITERATION 62
# ============================================================
# 📊 Energy = -56.28637198 Hartree
# 📊 Energy = -35320.2050 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -21.88884017 Hartree
# 📈 Energy improvement: -0.00613175 Hartree (-3.8477 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 8
#    Parameter range: [-0.1250,  0.0625]
#    Parameter variance:  0.0024
#    RMS parameter:  0.0494
#    Parameters:
#      θ[ 0]= 0.0000 θ[ 1]= 0.0000 θ[ 2]= 0.0000 θ[ 3]= 0.0000
#      θ[ 4]= 0.0000 θ[ 5]= 0.0000 θ[ 6]= 0.0625 θ[ 7]=-0.1250
#    ==================================================
#
# ============================================================
# 🔄 VQE ITERATION 63
# ============================================================
# 📊 Energy = -56.29250373 Hartree
# 📊 Energy = -35324.0527 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -21.89497192 Hartree
# 📈 Energy improvement: 0.00613175 Hartree (3.8477 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 8
#    Parameter range: [-0.1250,  0.0000]
#    Parameter variance:  0.0019
#    RMS parameter:  0.0494
#    Parameters:
#      θ[ 0]= 0.0000 θ[ 1]= 0.0000 θ[ 2]= 0.0000 θ[ 3]= 0.0000
#      θ[ 4]= 0.0000 θ[ 5]= 0.0000 θ[ 6]=-0.0625 θ[ 7]=-0.1250
#    ==================================================
#
# ============================================================
# 🔄 VQE ITERATION 64
# ============================================================
# 📊 Energy = -56.35427241 Hartree
# 📊 Energy = -35362.8131 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -21.95674059 Hartree
# 📈 Energy improvement: 0.06176868 Hartree (38.7604 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 8
#    Parameter range: [-0.0625,  0.0000]
#    Parameter variance:  0.0004
#    RMS parameter:  0.0221
#    Parameters:
#      θ[ 0]= 0.0000 θ[ 1]= 0.0000 θ[ 2]= 0.0000 θ[ 3]= 0.0000
#      θ[ 4]= 0.0000 θ[ 5]= 0.0000 θ[ 6]= 0.0000 θ[ 7]=-0.0625
#    ==================================================
#
# ============================================================
# 🔄 VQE ITERATION 65
# ============================================================
# 📊 Energy = -56.34633973 Hartree
# 📊 Energy = -35357.8353 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -21.94880792 Hartree
# 📈 Energy improvement: -0.00793268 Hartree (-4.9778 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 8
#    Parameter range: [-0.1875,  0.0000]
#    Parameter variance:  0.0038
#    RMS parameter:  0.0663
#    Parameters:
#      θ[ 0]= 0.0000 θ[ 1]= 0.0000 θ[ 2]= 0.0000 θ[ 3]= 0.0000
#      θ[ 4]= 0.0000 θ[ 5]= 0.0000 θ[ 6]= 0.0000 θ[ 7]=-0.1875
#    ==================================================
# [CD] No improvement; shrink step -> 0.03125
#
# ============================================================
# 🔄 VQE ITERATION 66
# ============================================================
# 📊 Energy = -56.33947426 Hartree
# 📊 Energy = -35353.5272 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -21.94194245 Hartree
# 📈 Energy improvement: -0.00686547 Hartree (-4.3081 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
# ...
# 📊 Energy (minus constant shift -34.397532) = -21.95502614 Hartree
# 📈 Energy improvement: 0.00139055 Hartree (0.8726 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 8
#    Parameter range: [-0.0938,  0.0000]
#    Parameter variance:  0.0009
#    RMS parameter:  0.0336
#    Parameters:
#      θ[ 0]= 0.0000 θ[ 1]= 0.0000 θ[ 2]= 0.0000 θ[ 3]= 0.0000
#      θ[ 4]= 0.0000 θ[ 5]=-0.0156 θ[ 6]= 0.0000 θ[ 7]=-0.0938
#    ==================================================
#
# ============================================================
# 🔄 VQE ITERATION 110
# ============================================================
# 📊 Energy = -56.35116741 Hartree
# 📊 Energy = -35360.8647 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -21.95363559 Hartree
# 📈 Energy improvement: -0.00139055 Hartree (-0.8726 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 8
#    Parameter range: [-0.0938,  0.0156]
#    Parameter variance:  0.0010
#    RMS parameter:  0.0336
#    Parameters:
#      θ[ 0]= 0.0000 θ[ 1]= 0.0000 θ[ 2]= 0.0000 θ[ 3]= 0.0000
#      θ[ 4]= 0.0000 θ[ 5]= 0.0000 θ[ 6]= 0.0156 θ[ 7]=-0.0938
#    ==================================================
#
# ============================================================
# 🔄 VQE ITERATION 111
# ============================================================
# 📊 Energy = -56.35255796 Hartree
# 📊 Energy = -35361.7373 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -21.95502614 Hartree
# 📈 Energy improvement: 0.00139055 Hartree (0.8726 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 8
#    Parameter range: [-0.0938,  0.0000]
#    Parameter variance:  0.0009
#    RMS parameter:  0.0336
#    Parameters:
#      θ[ 0]= 0.0000 θ[ 1]= 0.0000 θ[ 2]= 0.0000 θ[ 3]= 0.0000
#      θ[ 4]= 0.0000 θ[ 5]= 0.0000 θ[ 6]=-0.0156 θ[ 7]=-0.0938
#    ==================================================
#
# ============================================================
# 🔄 VQE ITERATION 112
# ============================================================
# 📊 Energy = -56.35543370 Hartree
# 📊 Energy = -35363.5418 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -21.95790189 Hartree
# 📈 Energy improvement: 0.00287574 Hartree (1.8046 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 8
#    Parameter range: [-0.0781,  0.0000]
#    Parameter variance:  0.0007
#    RMS parameter:  0.0276
#    Parameters:
#      θ[ 0]= 0.0000 θ[ 1]= 0.0000 θ[ 2]= 0.0000 θ[ 3]= 0.0000
#      θ[ 4]= 0.0000 θ[ 5]= 0.0000 θ[ 6]= 0.0000 θ[ 7]=-0.0781
#    ==================================================
#
# ============================================================
# 🔄 VQE ITERATION 113
# ============================================================
# 📊 Energy = -56.35590912 Hartree
# 📊 Energy = -35363.8402 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -21.95837730 Hartree
# 📈 Energy improvement: 0.00047542 Hartree (0.2983 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 8
#    Parameter range: [-0.1094,  0.0000]
#    Parameter variance:  0.0013
#    RMS parameter:  0.0387
#    Parameters:
#      θ[ 0]= 0.0000 θ[ 1]= 0.0000 θ[ 2]= 0.0000 θ[ 3]= 0.0000
#      θ[ 4]= 0.0000 θ[ 5]= 0.0000 θ[ 6]= 0.0000 θ[ 7]=-0.1094
#    ==================================================
# [CD] No improvement; shrink step -> 0.0078125
#
# ============================================================
# 🔄 VQE ITERATION 114
# ============================================================
# 📊 Energy = -56.35499482 Hartree
# 📊 Energy = -35363.2664 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -21.95746301 Hartree
# 📈 Energy improvement: -0.00091430 Hartree (-0.5737 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 8
#    Parameter range: [-0.0938,  0.0078]
#    Parameter variance:  0.0010
#    RMS parameter:  0.0333
#    Parameters:
#      θ[ 0]= 0.0078 θ[ 1]= 0.0000 θ[ 2]= 0.0000 θ[ 3]= 0.0000
#      θ[ 4]= 0.0000 θ[ 5]= 0.0000 θ[ 6]= 0.0000 θ[ 7]=-0.0938
#    ==================================================
#
# ============================================================
# 🔄 VQE ITERATION 115
# ============================================================
# 📊 Energy = -56.35499482 Hartree
# 📊 Energy = -35363.2664 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -21.95746301 Hartree
# 📈 Energy improvement: 0.00000000 Hartree (0.0000 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 8
#    Parameter range: [-0.0938,  0.0000]
#    Parameter variance:  0.0009
#    RMS parameter:  0.0333
#    Parameters:
#      θ[ 0]=-0.0078 θ[ 1]= 0.0000 θ[ 2]= 0.0000 θ[ 3]= 0.0000
#      θ[ 4]= 0.0000 θ[ 5]= 0.0000 θ[ 6]= 0.0000 θ[ 7]=-0.0938
#    ==================================================
#
# ============================================================
# 🔄 VQE ITERATION 116
# ============================================================
# 📊 Energy = -56.35594316 Hartree
# 📊 Energy = -35363.8615 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -21.95841135 Hartree
# 📈 Energy improvement: 0.00094834 Hartree (0.5951 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 8
#    Parameter range: [-0.0938,  0.0078]
#    Parameter variance:  0.0010
#    RMS parameter:  0.0333
#    Parameters:
#      θ[ 0]= 0.0000 θ[ 1]= 0.0078 θ[ 2]= 0.0000 θ[ 3]= 0.0000
#      θ[ 4]= 0.0000 θ[ 5]= 0.0000 θ[ 6]= 0.0000 θ[ 7]=-0.0938
#    ==================================================
#
# ============================================================
# 🔄 VQE ITERATION 117
# ============================================================
# 📊 Energy = -56.35594316 Hartree
# 📊 Energy = -35363.8615 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -21.95841135 Hartree
# 📈 Energy improvement: 0.00000000 Hartree (0.0000 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 8
#    Parameter range: [-0.0938,  0.0000]
#    Parameter variance:  0.0009
#    RMS parameter:  0.0333
#    Parameters:
#      θ[ 0]= 0.0000 θ[ 1]=-0.0078 θ[ 2]= 0.0000 θ[ 3]= 0.0000
#      θ[ 4]= 0.0000 θ[ 5]= 0.0000 θ[ 6]= 0.0000 θ[ 7]=-0.0938
#    ==================================================
#
# ============================================================
# 🔄 VQE ITERATION 118
# ============================================================
# 📊 Energy = -56.35499482 Hartree
# 📊 Energy = -35363.2664 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -21.95746301 Hartree
# 📈 Energy improvement: -0.00094834 Hartree (-0.5951 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 8
#    Parameter range: [-0.0938,  0.0078]
#    Parameter variance:  0.0010
#    RMS parameter:  0.0333
#    Parameters:
#      θ[ 0]= 0.0000 θ[ 1]= 0.0000 θ[ 2]= 0.0078 θ[ 3]= 0.0000
#      θ[ 4]= 0.0000 θ[ 5]= 0.0000 θ[ 6]= 0.0000 θ[ 7]=-0.0938
#    ==================================================
#
# ============================================================
# 🔄 VQE ITERATION 119
# ============================================================
# 📊 Energy = -56.35499482 Hartree
# 📊 Energy = -35363.2664 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -21.95746301 Hartree
# 📈 Energy improvement: 0.00000000 Hartree (0.0000 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 8
#    Parameter range: [-0.0938,  0.0000]
#    Parameter variance:  0.0009
#    RMS parameter:  0.0333
#    Parameters:
#      θ[ 0]= 0.0000 θ[ 1]= 0.0000 θ[ 2]=-0.0078 θ[ 3]= 0.0000
#      θ[ 4]= 0.0000 θ[ 5]= 0.0000 θ[ 6]= 0.0000 θ[ 7]=-0.0938
#    ==================================================
#
# ============================================================
# 🔄 VQE ITERATION 120
# ============================================================
# 📊 Energy = -56.35594316 Hartree
# 📊 Energy = -35363.8615 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -21.95841135 Hartree
# 📈 Energy improvement: 0.00094834 Hartree (0.5951 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 8
#    Parameter range: [-0.0938,  0.0078]
#    Parameter variance:  0.0010
#    RMS parameter:  0.0333
#    Parameters:
#      θ[ 0]= 0.0000 θ[ 1]= 0.0000 θ[ 2]= 0.0000 θ[ 3]= 0.0078
#      θ[ 4]= 0.0000 θ[ 5]= 0.0000 θ[ 6]= 0.0000 θ[ 7]=-0.0938
#    ==================================================
#
# ============================================================
# 🔄 VQE ITERATION 121
# ============================================================
# 📊 Energy = -56.35594316 Hartree
# 📊 Energy = -35363.8615 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -21.95841135 Hartree
# 📈 Energy improvement: 0.00000000 Hartree (0.0000 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 8
#    Parameter range: [-0.0938,  0.0000]
#    Parameter variance:  0.0009
#    RMS parameter:  0.0333
#    Parameters:
#      θ[ 0]= 0.0000 θ[ 1]= 0.0000 θ[ 2]= 0.0000 θ[ 3]=-0.0078
#      θ[ 4]= 0.0000 θ[ 5]= 0.0000 θ[ 6]= 0.0000 θ[ 7]=-0.0938
#    ==================================================
#
# ============================================================
# 🔄 VQE ITERATION 122
# ============================================================
# 📊 Energy = -56.35373099 Hartree
# 📊 Energy = -35362.4734 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -21.95619918 Hartree
# 📈 Energy improvement: -0.00221217 Hartree (-1.3882 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 8
#    Parameter range: [-0.0938,  0.0078]
#    Parameter variance:  0.0010
#    RMS parameter:  0.0333
#    Parameters:
#      θ[ 0]= 0.0000 θ[ 1]= 0.0000 θ[ 2]= 0.0000 θ[ 3]= 0.0000
#      θ[ 4]= 0.0078 θ[ 5]= 0.0000 θ[ 6]= 0.0000 θ[ 7]=-0.0938
#    ==================================================
#
# ============================================================
# 🔄 VQE ITERATION 123
# ============================================================
# 📊 Energy = -56.35388979 Hartree
# 📊 Energy = -35362.5730 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -21.95635798 Hartree
# 📈 Energy improvement: 0.00015881 Hartree (0.0997 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 8
#    Parameter range: [-0.0938,  0.0000]
#    Parameter variance:  0.0009
#    RMS parameter:  0.0333
#    Parameters:
#      θ[ 0]= 0.0000 θ[ 1]= 0.0000 θ[ 2]= 0.0000 θ[ 3]= 0.0000
#      θ[ 4]=-0.0078 θ[ 5]= 0.0000 θ[ 6]= 0.0000 θ[ 7]=-0.0938
#    ==================================================
#
# ============================================================
# 🔄 VQE ITERATION 124
# ============================================================
# 📊 Energy = -56.35460251 Hartree
# 📊 Energy = -35363.0203 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -21.95707070 Hartree
# 📈 Energy improvement: 0.00071272 Hartree (0.4472 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 8
#    Parameter range: [-0.0938,  0.0078]
#    Parameter variance:  0.0010
#    RMS parameter:  0.0333
#    Parameters:
#      θ[ 0]= 0.0000 θ[ 1]= 0.0000 θ[ 2]= 0.0000 θ[ 3]= 0.0000
#      θ[ 4]= 0.0000 θ[ 5]= 0.0078 θ[ 6]= 0.0000 θ[ 7]=-0.0938
#    ==================================================
#
# ============================================================
# 🔄 VQE ITERATION 125
# ============================================================
# 📊 Energy = -56.35529787 Hartree
# 📊 Energy = -35363.4566 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -21.95776606 Hartree
# 📈 Energy improvement: 0.00069536 Hartree (0.4363 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 8
#    Parameter range: [-0.0938,  0.0000]
#    Parameter variance:  0.0009
#    RMS parameter:  0.0333
#    Parameters:
#      θ[ 0]= 0.0000 θ[ 1]= 0.0000 θ[ 2]= 0.0000 θ[ 3]= 0.0000
#      θ[ 4]= 0.0000 θ[ 5]=-0.0078 θ[ 6]= 0.0000 θ[ 7]=-0.0938
#    ==================================================
#
# ============================================================
# 🔄 VQE ITERATION 126
# ============================================================
# 📊 Energy = -56.35460251 Hartree
# 📊 Energy = -35363.0203 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -21.95707070 Hartree
# 📈 Energy improvement: -0.00069536 Hartree (-0.4363 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 8
#    Parameter range: [-0.0938,  0.0078]
#    Parameter variance:  0.0010
#    RMS parameter:  0.0333
#    Parameters:
#      θ[ 0]= 0.0000 θ[ 1]= 0.0000 θ[ 2]= 0.0000 θ[ 3]= 0.0000
#      θ[ 4]= 0.0000 θ[ 5]= 0.0000 θ[ 6]= 0.0078 θ[ 7]=-0.0938
#    ==================================================
#
# ============================================================
# 🔄 VQE ITERATION 127
# ============================================================
# 📊 Energy = -56.35529787 Hartree
# 📊 Energy = -35363.4566 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -21.95776606 Hartree
# 📈 Energy improvement: 0.00069536 Hartree (0.4363 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 8
#    Parameter range: [-0.0938,  0.0000]
#    Parameter variance:  0.0009
#    RMS parameter:  0.0333
#    Parameters:
#      θ[ 0]= 0.0000 θ[ 1]= 0.0000 θ[ 2]= 0.0000 θ[ 3]= 0.0000
#      θ[ 4]= 0.0000 θ[ 5]= 0.0000 θ[ 6]=-0.0078 θ[ 7]=-0.0938
#    ==================================================
#
# ============================================================
# 🔄 VQE ITERATION 128
# ============================================================
# 📊 Energy = -56.35578356 Hartree
# 📊 Energy = -35363.7614 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -21.95825175 Hartree
# 📈 Energy improvement: 0.00048569 Hartree (0.3048 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 8
#    Parameter range: [-0.0859,  0.0000]
#    Parameter variance:  0.0008
#    RMS parameter:  0.0304
#    Parameters:
#      θ[ 0]= 0.0000 θ[ 1]= 0.0000 θ[ 2]= 0.0000 θ[ 3]= 0.0000
#      θ[ 4]= 0.0000 θ[ 5]= 0.0000 θ[ 6]= 0.0000 θ[ 7]=-0.0859
#    ==================================================
#
# ============================================================
# 🔄 VQE ITERATION 129
# ============================================================
# 📊 Energy = -56.35602130 Hartree
# 📊 Energy = -35363.9106 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -21.95848949 Hartree
# 📈 Energy improvement: 0.00023774 Hartree (0.1492 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 8
#    Parameter range: [-0.1016,  0.0000]
#    Parameter variance:  0.0011
#    RMS parameter:  0.0359
#    Parameters:
#      θ[ 0]= 0.0000 θ[ 1]= 0.0000 θ[ 2]= 0.0000 θ[ 3]= 0.0000
#      θ[ 4]= 0.0000 θ[ 5]= 0.0000 θ[ 6]= 0.0000 θ[ 7]=-0.1016
#    ==================================================
# [CD] iter 7 param 7 - -> -56.3560213016
#
# ============================================================
# 🔄 VQE ITERATION 130
# ============================================================
# 📊 Energy = -56.35602130 Hartree
# 📊 Energy = -35363.9106 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -21.95848949 Hartree
# 📈 Energy improvement: 0.00000000 Hartree (0.0000 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 8
#    Parameter range: [-0.1016,  0.0000]
#    Parameter variance:  0.0011
#    RMS parameter:  0.0359
#    Parameters:
#      θ[ 0]= 0.0000 θ[ 1]= 0.0000 θ[ 2]= 0.0000 θ[ 3]= 0.0000
#      θ[ 4]= 0.0000 θ[ 5]= 0.0000 θ[ 6]= 0.0000 θ[ 7]=-0.1016
#    ==================================================
#
# [CoordinateDescent VQE] Final energy: -56.3560213016
# [CoordinateDescent VQE] Improvement: 0.0213716315 Hartree

# %% [markdown]
# ### Cell 4a Description: Baseline Minimal VQE (No UCCSD)
# Runs the simplest possible VQE loop on the NH3 Hamiltonian with a hardware-efficient layered Ry + CNOT ladder ansatz (depth=2 by default). Provides a quick reference energy and timing before UCCSD-based variants. Adjustable via NUM_LAYERS. No ZNE, no hybrid switching.

# %%
# === 4a. Baseline Normal VQE (UCCSD HF Only, No Enhancements) ===
# Purpose: Provide a fair baseline using the SAME chemistry-aware UCCSD ansatz
# but with zero parameters (Hartree–Fock reference) and an optional tiny
# quick SPSA refinement (few iterations) WITHOUT hybrid switching or ZNE.
# This lets later variants (full SPSA, Hybrid, Hybrid+ZNE) show incremental gains.

from qiskit_aer.primitives import Estimator
from vqeskeletal import VQE, ZNEDenoiserPlugin, SPSAOptimizer
import numpy as np

assert 'uccsd_ansatz' in globals(), 'Run the UCCSD ansatz build cell first.'
assert 'ham_system' in globals(), 'Run the Hamiltonian build cell first.'

# 1. Hartree–Fock (zero-parameter) energy
hf_params = uccsd_ansatz.get_initial_parameters('zero')
est = Estimator()
hf_circuit = uccsd_ansatz.get_trial_wavefunction(hf_params)
hf_energy = est.run([hf_circuit],[ham_system['hamiltonian_active']]).result().values[0]
print(f"[Baseline HF] Energy (UCCSD ansatz, zero params / HF state): {hf_energy:.10f} Hartree")

# 2. Optional tiny plain SPSA (very few iterations) to show immediate improvement path
RUN_QUICK_OPT = True
quick_energy = hf_energy
quick_params = hf_params.copy()
if RUN_QUICK_OPT and len(hf_params) > 0:
    quick_spsa = SPSAOptimizer(max_iter=5, a=0.2, c=0.15, tol=1e-4, verbose=False)
    # Minimal wrapper VQE instance (ZNE disabled, no hybrid)
    class DirectHam:
        def __init__(self, sysd): self.sysd = sysd
        def get_hamiltonian(self): return self.sysd
    no_zne_min = ZNEDenoiserPlugin(noise_factors=[1.0], verbose=False)
    vqe_min = VQE(uccsd_ansatz, DirectHam(ham_system), quick_spsa, no_zne_min, verbose=False)
    opt_params = quick_spsa.optimize(vqe_min.objective_function, hf_params)
    quick_energy = vqe_min.objective_function(opt_params)
    print(f"[Baseline Quick SPSA] Energy after {vqe_min.iteration_count} evals: {quick_energy:.10f} Hartree")
    print(f"[Baseline Quick SPSA] Improvement: {hf_energy - quick_energy:+.6f} Hartree")
    baseline_params = opt_params
else:
    baseline_params = hf_params

# Values captured for summary table
baseline_energy = float(quick_energy)
# Out:
# [Baseline HF] Energy (UCCSD ansatz, zero params / HF state): -56.3332275762 Hartree
# 🔄 Initializing VQE system...
# ======================================================================
# BUILDING UCCSD ANSATZ FROM HAMILTONIAN
# ======================================================================
# System: qubits=6 spatial_orbs=3 particles=(2, 2)
# ✓ HF state ready (HartreeFock constructed)
# Ansatz depth=2 gates=5 params=8
# ✓ Ansatz construction complete (params=8)
# [Baseline Quick SPSA] Energy after 17 evals: -56.3435034487 Hartree
# [Baseline Quick SPSA] Improvement: +0.010276 Hartree

# %% [markdown]
# ### Cell 5 Description: Basic VQE (SPSA Only, Generic Ansatz)
# Runs a standalone SPSA optimization on a small hardware‑efficient (Ry+CX) ansatz built directly from the NH3 Hamiltonian qubit count. This is a neutral baseline with zero or random initialization and no chemistry priors. ZNE disabled (single‑factor identity).

# %%
# === 5. Basic VQE (SPSA only, no ZNE) — Generic hardware-efficient ansatz ===
from vqeskeletal import VQE, ZNEDenoiserPlugin, SPSAOptimizer, GenericAnsatzPlugin

class DirectHam:
    def __init__(self, sysd): self.sysd = sysd
    def get_hamiltonian(self): return self.sysd

# Build a small HEA baseline (no chemistry priors)
# Note: params = layers * num_qubits; with 6 qubits and layers=2 -> 12 parameters.
# To try fewer params, use layers=1 (-> 6 params).
generic = GenericAnsatzPlugin(layers=2, entanglement='linear', verbose=True)
generic.build_from_hamiltonian(ham_system)
print(f"[Basic] HEA ansatz: qubits={generic.num_qubits}, params={generic.num_parameters}, layers={generic.layers}")

# Increase SPSA iterations to 200
BASIC_SPSA_ITERS = 200
basic_optimizer = SPSAOptimizer(max_iter=BASIC_SPSA_ITERS, a=0.25, c=0.15, tol=5e-4, verbose=True)
print(f"[Basic] SPSA iterations set to {BASIC_SPSA_ITERS} (expected objective evals ≈ {3*BASIC_SPSA_ITERS + 2})")

no_zne = ZNEDenoiserPlugin(noise_factors=[1.0], extrapolation_method='linear', verbose=False)

vqe_basic = VQE(generic, DirectHam(ham_system), basic_optimizer, no_zne, verbose=True)
# Choose standard "normal VQE" starts: zero or random
init_basic = generic.get_initial_parameters('zero')  # or 'random_normal'
params_basic, energy_basic = vqe_basic.run(init_basic)

# Report both raw and shift-adjusted energies for clarity
shift = getattr(vqe_basic, 'energy_constant_shift', 0.0) or 0.0
print('\n[Basic VQE] Final total energy (raw):', f'{energy_basic:.10f} Hartree')
print('[Basic VQE] Final energy (minus constant shift', f'{shift:.6f}', '):', f'{(energy_basic-shift):.10f} Hartree')

# Expose for summary table
energy_basic = float(energy_basic)
# Out:
# Streaming output truncated to the last 5000 lines.
#    Parameter range: [-8.7333,  6.2767]
#    Parameter variance: 17.5013
#    RMS parameter:  4.1914
#    Parameters:
#      θ[ 0]= 3.0406 θ[ 1]=-5.7800 θ[ 2]= 1.9979 θ[ 3]= 3.3732
#      θ[ 4]= 0.2667 θ[ 5]=-8.7333 θ[ 6]=-0.2289 θ[ 7]= 3.3986
#      ... and 4 more parameters
#    ==================================================
#
# ============================================================
# 🔄 VQE ITERATION 145
# ============================================================
# 📊 Energy = -51.39484961 Hartree
# 📊 Energy = -32250.7307 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -16.99731779 Hartree
# 📈 Energy improvement: -4.05416805 Hartree (-2544.0269 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 12
#    Parameter range: [-8.2754,  6.7347]
#    Parameter variance: 16.8640
#    RMS parameter:  4.1079
#    Parameters:
#      θ[ 0]= 3.4985 θ[ 1]=-5.3221 θ[ 2]= 2.4558 θ[ 3]= 2.9153
#      θ[ 4]= 0.7246 θ[ 5]=-8.2754 θ[ 6]= 0.2290 θ[ 7]= 2.9407
#      ... and 4 more parameters
#    ==================================================
# [SPSA] iter= 48 energy=-51.39484961 ΔE=-1.966e+00 ak=2.431e-02 ck=1.015e-01
#
# ============================================================
# 🔄 VQE ITERATION 146
# ============================================================
# 📊 Energy = -50.40119813 Hartree
# 📊 Energy = -31627.2054 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -16.00366632 Hartree
# 📈 Energy improvement: -0.99365148 Hartree (-623.5252 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 12
#    Parameter range: [-8.3766,  6.6334]
#    Parameter variance: 17.0944
#    RMS parameter:  4.1363
#    Parameters:
#      θ[ 0]= 3.5998 θ[ 1]=-5.4233 θ[ 2]= 2.5570 θ[ 3]= 3.0166
#      θ[ 4]= 0.6234 θ[ 5]=-8.3766 θ[ 6]= 0.3303 θ[ 7]= 2.8394
#      ... and 4 more parameters
#    ==================================================
#
# ============================================================
# 🔄 VQE ITERATION 147
# ============================================================
# 📊 Energy = -51.72759643 Hartree
# 📊 Energy = -32459.5323 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -17.33006462 Hartree
# 📈 Energy improvement: 1.32639830 Hartree (832.3269 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 12
#    Parameter range: [-8.1741,  6.8359]
#    Parameter variance: 16.6535
#    RMS parameter:  4.0818
#    Parameters:
#      θ[ 0]= 3.3973 θ[ 1]=-5.2208 θ[ 2]= 2.3546 θ[ 3]= 2.8141
#      θ[ 4]= 0.8259 θ[ 5]=-8.1741 θ[ 6]= 0.1278 θ[ 7]= 3.0419
#      ... and 4 more parameters
#    ==================================================
#
# ============================================================
# 🔄 VQE ITERATION 148
# ============================================================
# 📊 Energy = -51.62429116 Hartree
# 📊 Energy = -32394.7073 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -17.22675935 Hartree
# 📈 Energy improvement: -0.10330527 Hartree (-64.8250 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 12
#    Parameter range: [-8.1181,  6.8920]
#    Parameter variance: 16.5455
#    RMS parameter:  4.0684
#    Parameters:
#      θ[ 0]= 3.3412 θ[ 1]=-5.1648 θ[ 2]= 2.2985 θ[ 3]= 2.7580
#      θ[ 4]= 0.8819 θ[ 5]=-8.1181 θ[ 6]= 0.0717 θ[ 7]= 3.0980
#      ... and 4 more parameters
#    ==================================================
# [SPSA] iter= 49 energy=-51.62429116 ΔE=2.294e-01 ak=2.401e-02 ck=1.012e-01
#
# ============================================================
# 🔄 VQE ITERATION 149
# ============================================================
# 📊 Energy = -54.15331285 Hartree
# 📊 Energy = -33981.6912 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -19.75578103 Hartree
# 📈 Energy improvement: 2.52902169 Hartree (1586.9839 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 12
#    Parameter range: [-8.2191,  6.9930]
#    Parameter variance: 17.1129
#    RMS parameter:  4.1370
#    Parameters:
#      θ[ 0]= 3.4423 θ[ 1]=-5.2658 θ[ 2]= 2.3995 θ[ 3]= 2.8591
#      θ[ 4]= 0.9830 θ[ 5]=-8.2191 θ[ 6]=-0.0293 θ[ 7]= 3.1990
#      ... and 4 more parameters
#    ==================================================
#
# ============================================================
# 🔄 VQE ITERATION 150
# ============================================================
# 📊 Energy = -48.78995590 Hartree
# 📊 Energy = -30616.1364 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -14.39242408 Hartree
# 📈 Energy improvement: -5.36335695 Hartree (-3365.5548 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 12
#    Parameter range: [-8.0171,  6.7909]
#    Parameter variance: 15.9963
#    RMS parameter:  4.0011
#    Parameters:
#      θ[ 0]= 3.2402 θ[ 1]=-5.0638 θ[ 2]= 2.1975 θ[ 3]= 2.6570
#      θ[ 4]= 0.7809 θ[ 5]=-8.0171 θ[ 6]= 0.1728 θ[ 7]= 2.9969
#      ... and 4 more parameters
#    ==================================================
#
# ============================================================
# 🔄 VQE ITERATION 151
# ============================================================
# 📊 Energy = -48.72886157 Hartree
# 📊 Energy = -30577.7992 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -14.33132975 Hartree
# 📈 Energy improvement: -0.06109433 Hartree (-38.3372 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 12
#    Parameter range: [-8.7477,  7.5216]
#    Parameter variance: 20.3771
#    RMS parameter:  4.5160
#    Parameters:
#      θ[ 0]= 3.9708 θ[ 1]=-5.7944 θ[ 2]= 2.9281 θ[ 3]= 3.3876
#      θ[ 4]= 1.5115 θ[ 5]=-8.7477 θ[ 6]=-0.5579 θ[ 7]= 3.7276
#      ... and 4 more parameters
#    ==================================================
# [SPSA] iter= 50 energy=-48.72886157 ΔE=-2.895e+00 ak=2.372e-02 ck=1.010e-01
#
# ============================================================
# 🔄 VQE ITERATION 152
# ============================================================
# 📊 Energy = -49.29592599 Hartree
# 📊 Energy = -30933.6372 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -14.89839417 Hartree
# 📈 Energy improvement: 0.56706442 Hartree (355.8380 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 12
#    Parameter range: [-8.6469,  7.4207]
#    Parameter variance: 20.3412
#    RMS parameter:  4.5120
#    Parameters:
#      θ[ 0]= 3.8700 θ[ 1]=-5.8952 θ[ 2]= 3.0290 θ[ 3]= 3.2868
#      θ[ 4]= 1.6124 θ[ 5]=-8.6469 θ[ 6]=-0.4570 θ[ 7]= 3.8284
#      ... and 4 more parameters
#    ==================================================
#
# ============================================================
# 🔄 VQE ITERATION 153
# ============================================================
# 📊 Energy = -47.84933007 Hartree
# 📊 Energy = -30025.8853 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -13.45179826 Hartree
# 📈 Energy improvement: -1.44659592 Hartree (-907.7520 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 12
#    Parameter range: [-8.8485,  7.6224]
#    Parameter variance: 20.4333
#    RMS parameter:  4.5222
#    Parameters:
#      θ[ 0]= 4.0717 θ[ 1]=-5.6936 θ[ 2]= 2.8273 θ[ 3]= 3.4885
#      θ[ 4]= 1.4107 θ[ 5]=-8.8485 θ[ 6]=-0.6587 θ[ 7]= 3.6267
#      ... and 4 more parameters
#    ==================================================
#
# ============================================================
# 🔄 VQE ITERATION 154
# ============================================================
# 📊 Energy = -49.48190452 Hartree
# 📊 Energy = -31050.3404 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -15.08437270 Hartree
# 📈 Energy improvement: 1.63257445 Hartree (1024.4552 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 12
#    Parameter range: [-8.5796,  7.3534]
#    Parameter variance: 20.3286
#    RMS parameter:  4.5106
#    Parameters:
#      θ[ 0]= 3.8027 θ[ 1]=-5.9626 θ[ 2]= 3.0963 θ[ 3]= 3.2195
#      θ[ 4]= 1.6797 θ[ 5]=-8.5796 θ[ 6]=-0.3897 θ[ 7]= 3.8957
#      ... and 4 more parameters
#    ==================================================
# [SPSA] iter= 51 energy=-49.48190452 ΔE=7.530e-01 ak=2.344e-02 ck=1.008e-01
#
# ============================================================
# 🔄 VQE ITERATION 155
# ============================================================
# 📊 Energy = -48.02492996 Hartree
# 📊 Energy = -30136.0758 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -13.62739814 Hartree
# 📈 Energy improvement: -1.45697456 Hartree (-914.2646 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 12
#    Parameter range: [-8.6802,  7.2528]
#    Parameter variance: 20.2312
#    RMS parameter:  4.4994
#    Parameters:
#      θ[ 0]= 3.9033 θ[ 1]=-5.8619 θ[ 2]= 2.9956 θ[ 3]= 3.1188
#      θ[ 4]= 1.7803 θ[ 5]=-8.6802 θ[ 6]=-0.4904 θ[ 7]= 3.7951
#      ... and 4 more parameters
#    ==================================================
#
# ============================================================
# 🔄 VQE ITERATION 156
# ============================================================
# 📊 Energy = -50.43437637 Hartree
# 📊 Energy = -31648.0251 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -16.03684456 Hartree
# 📈 Energy improvement: 2.40944642 Hartree (1511.9493 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 12
#    Parameter range: [-8.4789,  7.4541]
#    Parameter variance: 20.4458
#    RMS parameter:  4.5241
#    Parameters:
#      θ[ 0]= 3.7021 θ[ 1]=-6.0632 θ[ 2]= 3.1969 θ[ 3]= 3.3201
#      θ[ 4]= 1.5790 θ[ 5]=-8.4789 θ[ 6]=-0.2891 θ[ 7]= 3.9964
#      ... and 4 more parameters
#    ==================================================
#
# ============================================================
# 🔄 VQE ITERATION 157
# ============================================================
# 📊 Energy = -50.81949605 Hartree
# 📊 Energy = -31889.6911 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -16.42196424 Hartree
# 📈 Energy improvement: 0.38511968 Hartree (241.6661 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 12
#    Parameter range: [-8.3022,  7.6308]
#    Parameter variance: 20.6991
#    RMS parameter:  4.5531
#    Parameters:
#      θ[ 0]= 3.5253 θ[ 1]=-6.2399 θ[ 2]= 3.3736 θ[ 3]= 3.4968
#      θ[ 4]= 1.4023 θ[ 5]=-8.3022 θ[ 6]=-0.1124 θ[ 7]= 4.1731
#      ... and 4 more parameters
#    ==================================================
# [SPSA] iter= 52 energy=-50.81949605 ΔE=1.338e+00 ak=2.317e-02 ck=1.006e-01
#
# ============================================================
# 🔄 VQE ITERATION 158
# ============================================================
# 📊 Energy = -48.15388760 Hartree
# 📊 Energy = -30216.9979 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -13.75635578 Hartree
# 📈 Energy improvement: -2.66560846 Hartree (-1672.6933 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 12
#    Parameter range: [-8.2018,  7.7312]
#    Parameter variance: 20.8242
#    RMS parameter:  4.5690
#    Parameters:
#      θ[ 0]= 3.6258 θ[ 1]=-6.3403 θ[ 2]= 3.2732 θ[ 3]= 3.5973
#      θ[ 4]= 1.5028 θ[ 5]=-8.2018 θ[ 6]=-0.2128 θ[ 7]= 4.2735
#      ... and 4 more parameters
#    ==================================================
#
# ============================================================
# 🔄 VQE ITERATION 159
# ============================================================
# 📊 Energy = -52.86095901 Hartree
# 📊 Energy = -33170.7275 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -18.46342720 Hartree
# 📈 Energy improvement: 4.70707141 Hartree (2953.7297 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 12
#    Parameter range: [-8.4027,  7.5303]
#    Parameter variance: 20.5891
#    RMS parameter:  4.5393
#    Parameters:
#      θ[ 0]= 3.4249 θ[ 1]=-6.1394 θ[ 2]= 3.4741 θ[ 3]= 3.3964
#      θ[ 4]= 1.3019 θ[ 5]=-8.4027 θ[ 6]=-0.0119 θ[ 7]= 4.0726
#      ... and 4 more parameters
#    ==================================================
#
# ============================================================
# 🔄 VQE ITERATION 160
# ============================================================
# 📊 Energy = -50.80616919 Hartree
# 📊 Energy = -31881.3284 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -16.40863738 Hartree
# 📈 Energy improvement: -2.05478982 Hartree (-1289.3991 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 12
#    Parameter range: [-8.8389,  7.0941]
#    Parameter variance: 20.2870
#    RMS parameter:  4.5050
#    Parameters:
#      θ[ 0]= 2.9887 θ[ 1]=-5.7032 θ[ 2]= 3.9103 θ[ 3]= 2.9602
#      θ[ 4]= 0.8657 θ[ 5]=-8.8389 θ[ 6]= 0.4243 θ[ 7]= 3.6364
#      ... and 4 more parameters
#    ==================================================
# [SPSA] iter= 53 energy=-50.80616919 ΔE=-1.333e-02 ak=2.290e-02 ck=1.004e-01
#
# ============================================================
# 🔄 VQE ITERATION 161
# ============================================================
# 📊 Energy = -48.59731253 Hartree
# 📊 Energy = -30495.2510 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -14.19978072 Hartree
# 📈 Energy improvement: -2.20885666 Hartree (-1386.0774 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 12
#    Parameter range: [-8.7386,  7.1944]
#    Parameter variance: 20.1454
#    RMS parameter:  4.4890
#    Parameters:
#      θ[ 0]= 2.8884 θ[ 1]=-5.6030 θ[ 2]= 3.8100 θ[ 3]= 3.0604
#      θ[ 4]= 0.7654 θ[ 5]=-8.7386 θ[ 6]= 0.5245 θ[ 7]= 3.7366
#      ... and 4 more parameters
#    ==================================================
#
# ============================================================
# 🔄 VQE ITERATION 162
# ============================================================
# 📊 Energy = -52.84436275 Hartree
# 📊 Energy = -33160.3132 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -18.44683094 Hartree
# 📈 Energy improvement: 4.24705022 Hartree (2665.0622 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 12
#    Parameter range: [-8.9391,  6.9938]
#    Parameter variance: 20.4482
#    RMS parameter:  4.5232
#    Parameters:
#      θ[ 0]= 3.0889 θ[ 1]=-5.8035 θ[ 2]= 4.0105 θ[ 3]= 2.8599
#      θ[ 4]= 0.9659 θ[ 5]=-8.9391 θ[ 6]= 0.3240 θ[ 7]= 3.5361
#      ... and 4 more parameters
#    ==================================================
#
# ============================================================
# 🔄 VQE ITERATION 163
# ============================================================
# 📊 Energy = -55.02630828 Hartree
# 📊 Energy = -34529.5037 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -20.62877647 Hartree
# 📈 Energy improvement: 2.18194553 Hartree (1369.1905 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 12
#    Parameter range: [-9.3186,  6.6144]
#    Parameter variance: 21.2350
#    RMS parameter:  4.6113
#    Parameters:
#      θ[ 0]= 3.4684 θ[ 1]=-6.1829 θ[ 2]= 4.3900 θ[ 3]= 2.4805
#      θ[ 4]= 1.3454 θ[ 5]=-9.3186 θ[ 6]=-0.0554 θ[ 7]= 3.1567
#      ... and 4 more parameters
#    ==================================================
# [SPSA] iter= 54 energy=-55.02630828 ΔE=4.220e+00 ak=2.265e-02 ck=1.003e-01
#
# ============================================================
# 🔄 VQE ITERATION 164
# ============================================================
# 📊 Energy = -53.10521149 Hartree
# 📊 Energy = -33323.9982 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -18.70767968 Hartree
# 📈 Energy improvement: -1.92109679 Hartree (-1205.5055 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 12
#    Parameter range: [-9.4187,  6.5143]
#    Parameter variance: 21.2603
#    RMS parameter:  4.6147
#    Parameters:
#      θ[ 0]= 3.5685 θ[ 1]=-6.0829 θ[ 2]= 4.4901 θ[ 3]= 2.3804
#      θ[ 4]= 1.2453 θ[ 5]=-9.4187 θ[ 6]=-0.1555 θ[ 7]= 3.2568
#      ... and 4 more parameters
#    ==================================================
#
# ============================================================
# 🔄 VQE ITERATION 165
# ============================================================
# 📊 Energy = -56.28975127 Hartree
# 📊 Energy = -35322.3255 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -21.89221946 Hartree
# 📈 Energy improvement: 3.18453978 Hartree (1998.3274 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 12
#    Parameter range: [-9.2185,  6.7145]
#    Parameter variance: 21.2291
#    RMS parameter:  4.6101
#    Parameters:
#      θ[ 0]= 3.3683 θ[ 1]=-6.2830 θ[ 2]= 4.2899 θ[ 3]= 2.5805
#      θ[ 4]= 1.4455 θ[ 5]=-9.2185 θ[ 6]= 0.0446 θ[ 7]= 3.0566
#      ... and 4 more parameters
#    ==================================================
#
# ============================================================
# 🔄 VQE ITERATION 166
# ============================================================
# 📊 Energy = -54.86290114 Hartree
# 📊 Energy = -34426.9642 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -20.46536933 Hartree
# 📈 Energy improvement: -1.42685013 Hartree (-895.3613 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 12
#    Parameter range: [-8.9622,  6.9708]
#    Parameter variance: 21.3028
#    RMS parameter:  4.6168
#    Parameters:
#      θ[ 0]= 3.1120 θ[ 1]=-6.5393 θ[ 2]= 4.0336 θ[ 3]= 2.8369
#      θ[ 4]= 1.7018 θ[ 5]=-8.9622 θ[ 6]= 0.3010 θ[ 7]= 2.8003
#      ... and 4 more parameters
#    ==================================================
# [SPSA] iter= 55 energy=-54.86290114 ΔE=-1.634e-01 ak=2.240e-02 ck=1.001e-01
#
# ============================================================
# 🔄 VQE ITERATION 167
# ============================================================
# 📊 Energy = -51.89397456 Hartree
# 📊 Energy = -32563.9361 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -17.49644275 Hartree
# 📈 Energy improvement: -2.96892658 Hartree (-1863.0281 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 12
#    Parameter range: [-9.0621,  6.8709]
#    Parameter variance: 21.4600
#    RMS parameter:  4.6353
#    Parameters:
#      θ[ 0]= 3.2119 θ[ 1]=-6.6392 θ[ 2]= 3.9337 θ[ 3]= 2.7370
#      θ[ 4]= 1.6019 θ[ 5]=-9.0621 θ[ 6]= 0.4009 θ[ 7]= 2.7004
#      ... and 4 more parameters
#    ==================================================
#
# ============================================================
# 🔄 VQE ITERATION 168
# ============================================================
# 📊 Energy = -57.30254267 Hartree
# 📊 Energy = -35957.8612 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -22.90501086 Hartree
# 📈 Energy improvement: 5.40856811 Hartree (3393.9252 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 12
#    Parameter range: [-8.8623,  7.0707]
#    Parameter variance: 21.1607
#    RMS parameter:  4.6005
#    Parameters:
#      θ[ 0]= 3.0121 θ[ 1]=-6.4394 θ[ 2]= 4.1335 θ[ 3]= 2.9367
#      θ[ 4]= 1.8017 θ[ 5]=-8.8623 θ[ 6]= 0.2011 θ[ 7]= 2.9002
#      ... and 4 more parameters
#    ==================================================
#
# ============================================================
# 🔄 VQE ITERATION 169
# ============================================================
# 📊 Energy = -50.54561259 Hartree
# 📊 Energy = -31717.8268 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -16.14808077 Hartree
# 📈 Energy improvement: -6.75693009 Hartree (-4240.0344 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 12
#    Parameter range: [-8.3623,  7.5707]
#    Parameter variance: 20.6741
#    RMS parameter:  4.5508
#    Parameters:
#      θ[ 0]= 2.5121 θ[ 1]=-5.9395 θ[ 2]= 4.6334 θ[ 3]= 3.4367
#      θ[ 4]= 2.3017 θ[ 5]=-8.3623 θ[ 6]=-0.2989 θ[ 7]= 3.4001
#      ... and 4 more parameters
#    ==================================================
# [SPSA] iter= 56 energy=-50.54561259 ΔE=-4.317e+00 ak=2.216e-02 ck=9.989e-02
#
# ============================================================
# 🔄 VQE ITERATION 170
# ============================================================
# 📊 Energy = -50.95796556 Hartree
# 📊 Energy = -31976.5820 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -16.56043374 Hartree
# 📈 Energy improvement: 0.41235297 Hartree (258.7552 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 12
#    Parameter range: [-8.4620,  7.4710]
#    Parameter variance: 20.6711
#    RMS parameter:  4.5505
#    Parameters:
#      θ[ 0]= 2.4124 θ[ 1]=-6.0392 θ[ 2]= 4.7332 θ[ 3]= 3.3370
#      θ[ 4]= 2.2019 θ[ 5]=-8.4620 θ[ 6]=-0.1992 θ[ 7]= 3.4999
#      ... and 4 more parameters
#    ==================================================
#
# ============================================================
# 🔄 VQE ITERATION 171
# ============================================================
# 📊 Energy = -49.64379011 Hartree
# 📊 Energy = -31151.9251 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -15.24625830 Hartree
# 📈 Energy improvement: -1.31417544 Hartree (-824.6569 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 12
#    Parameter range: [-8.2626,  7.6704]
#    Parameter variance: 20.6969
#    RMS parameter:  4.5533
#    Parameters:
#      θ[ 0]= 2.6118 θ[ 1]=-5.8398 θ[ 2]= 4.5337 θ[ 3]= 3.5364
#      θ[ 4]= 2.4014 θ[ 5]=-8.2626 θ[ 6]=-0.3986 θ[ 7]= 3.3004
#      ... and 4 more parameters
#    ==================================================
#
# ============================================================
# 🔄 VQE ITERATION 172
# ============================================================
# 📊 Energy = -50.91350993 Hartree
# 📊 Energy = -31948.6857 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -16.51597811 Hartree
# 📈 Energy improvement: 1.26971982 Hartree (796.7606 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 12
#    Parameter range: [-8.5068,  7.4262]
#    Parameter variance: 20.6762
#    RMS parameter:  4.5510
#    Parameters:
#      θ[ 0]= 2.3676 θ[ 1]=-6.0839 θ[ 2]= 4.7779 θ[ 3]= 3.2923
#      θ[ 4]= 2.1572 θ[ 5]=-8.5068 θ[ 6]=-0.1544 θ[ 7]= 3.5446
#      ... and 4 more parameters
#    ==================================================
# [SPSA] iter= 57 energy=-50.91350993 ΔE=3.679e-01 ak=2.192e-02 ck=9.971e-02
#
# ============================================================
# 🔄 VQE ITERATION 173
# ============================================================
# 📊 Energy = -52.04111319 Hartree
# 📊 Energy = -32656.2669 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -17.64358137 Hartree
# 📈 Energy improvement: 1.12760326 Hartree (707.5812 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 12
#    Parameter range: [-8.4073,  7.3267]
#    Parameter variance: 20.4387
#    RMS parameter:  4.5263
#    Parameters:
#      θ[ 0]= 2.4672 θ[ 1]=-6.1835 θ[ 2]= 4.8775 θ[ 3]= 3.1927
#      θ[ 4]= 2.2567 θ[ 5]=-8.4073 θ[ 6]=-0.0549 θ[ 7]= 3.4451
#      ... and 4 more parameters
#    ==================================================
#
# ============================================================
# 🔄 VQE ITERATION 174
# ============================================================
# 📊 Energy = -49.06720432 Hartree
# 📊 Energy = -30790.1123 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -14.66967250 Hartree
# 📈 Energy improvement: -2.97390887 Hartree (-1866.1546 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 12
#    Parameter range: [-8.6063,  7.5257]
#    Parameter variance: 20.9314
#    RMS parameter:  4.5777
#    Parameters:
#      θ[ 0]= 2.2681 θ[ 1]=-5.9844 θ[ 2]= 4.6784 θ[ 3]= 3.3918
#      θ[ 4]= 2.0577 θ[ 5]=-8.6063 θ[ 6]=-0.2540 θ[ 7]= 3.6442
#      ... and 4 more parameters
#    ==================================================
#
# ============================================================
# 🔄 VQE ITERATION 175
# ============================================================
# 📊 Energy = -51.23136113 Hartree
# 📊 Energy = -32148.1402 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -16.83382932 Hartree
# 📈 Energy improvement: 2.16415682 Hartree (1358.0279 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 12
#    Parameter range: [-8.1827,  7.1021]
#    Parameter variance: 19.9674
#    RMS parameter:  4.4783
#    Parameters:
#      θ[ 0]= 2.6917 θ[ 1]=-6.4080 θ[ 2]= 5.1020 θ[ 3]= 2.9682
#      θ[ 4]= 2.4813 θ[ 5]=-8.1827 θ[ 6]= 0.1697 θ[ 7]= 3.2205
#      ... and 4 more parameters
#    ==================================================
# [SPSA] iter= 58 energy=-51.23136113 ΔE=3.179e-01 ak=2.169e-02 ck=9.954e-02
#
# ============================================================
# 🔄 VQE ITERATION 176
# ============================================================
# 📊 Energy = -50.58508802 Hartree
# 📊 Energy = -31742.5980 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -16.18755620 Hartree
# 📈 Energy improvement: -0.64627311 Hartree (-405.5422 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 12
#    Parameter range: [-8.0833,  7.2015]
#    Parameter variance: 19.9001
#    RMS parameter:  4.4719
#    Parameters:
#      θ[ 0]= 2.5924 θ[ 1]=-6.3087 θ[ 2]= 5.2014 θ[ 3]= 2.8688
#      θ[ 4]= 2.3819 θ[ 5]=-8.0833 θ[ 6]= 0.0703 θ[ 7]= 3.3199
#      ... and 4 more parameters
#    ==================================================
#
# ============================================================
# 🔄 VQE ITERATION 177
# ============================================================
# 📊 Energy = -51.24299014 Hartree
# 📊 Energy = -32155.4375 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -16.84545832 Hartree
# 📈 Energy improvement: 0.65790212 Hartree (412.8395 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 12
#    Parameter range: [-8.2821,  7.0027]
#    Parameter variance: 20.0540
#    RMS parameter:  4.4869
#    Parameters:
#      θ[ 0]= 2.7911 θ[ 1]=-6.5074 θ[ 2]= 5.0026 θ[ 3]= 3.0675
#      θ[ 4]= 2.5806 θ[ 5]=-8.2821 θ[ 6]= 0.2690 θ[ 7]= 3.1212
#      ... and 4 more parameters
#    ==================================================
#
# ============================================================
# 🔄 VQE ITERATION 178
# ============================================================
# 📊 Energy = -51.30426776 Hartree
# 📊 Energy = -32193.8898 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -16.90673595 Hartree
# 📈 Energy improvement: 0.06127762 Hartree (38.4523 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 12
#    Parameter range: [-8.2538,  7.0310]
#    Parameter variance: 20.0274
#    RMS parameter:  4.4842
#    Parameters:
#      θ[ 0]= 2.7628 θ[ 1]=-6.4791 θ[ 2]= 5.0309 θ[ 3]= 3.0393
#      θ[ 4]= 2.5524 θ[ 5]=-8.2538 θ[ 6]= 0.2408 θ[ 7]= 3.1494
#      ... and 4 more parameters
#    ==================================================
# [SPSA] iter= 59 energy=-51.30426776 ΔE=7.291e-02 ak=2.147e-02 ck=9.937e-02
#
# ============================================================
# 🔄 VQE ITERATION 179
# ============================================================
# 📊 Energy = -52.28449192 Hartree
# 📊 Energy = -32808.9892 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -17.88696011 Hartree
# 📈 Energy improvement: 0.98022416 Hartree (615.0995 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 12
#    Parameter range: [-8.3530,  7.1302]
#    Parameter variance: 20.2007
#    RMS parameter:  4.5035
#    Parameters:
#      θ[ 0]= 2.8620 θ[ 1]=-6.3799 θ[ 2]= 4.9317 θ[ 3]= 2.9401
#      θ[ 4]= 2.6516 θ[ 5]=-8.3530 θ[ 6]= 0.3399 θ[ 7]= 3.0502
#      ... and 4 more parameters
#    ==================================================
#
# ============================================================
# 🔄 VQE ITERATION 180
# ============================================================
# 📊 Energy = -49.75461739 Hartree
# 📊 Energy = -31221.4702 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -15.35708557 Hartree
# 📈 Energy improvement: -2.52987453 Hartree (-1587.5190 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 12
#    Parameter range: [-8.1546,  6.9318]
#    Parameter variance: 19.8737
#    RMS parameter:  4.4671
#    Parameters:
#      θ[ 0]= 2.6636 θ[ 1]=-6.5783 θ[ 2]= 5.1301 θ[ 3]= 3.1384
#      θ[ 4]= 2.4532 θ[ 5]=-8.1546 θ[ 6]= 0.1416 θ[ 7]= 3.2486
#      ... and 4 more parameters
#    ==================================================
#
# ============================================================
# 🔄 VQE ITERATION 181
# ============================================================
# 📊 Energy = -52.05804477 Hartree
# 📊 Energy = -32666.8916 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -17.66051296 Hartree
# 📈 Energy improvement: 2.30342739 Hartree (1445.4214 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 12
#    Parameter range: [-8.5248,  7.3021]
#    Parameter variance: 20.5476
#    RMS parameter:  4.5419
#    Parameters:
#      θ[ 0]= 3.0339 θ[ 1]=-6.2081 θ[ 2]= 4.7599 θ[ 3]= 2.7682
#      θ[ 4]= 2.8234 θ[ 5]=-8.5248 θ[ 6]= 0.5118 θ[ 7]= 2.8784
#      ... and 4 more parameters
#    ==================================================
# [SPSA] iter= 60 energy=-52.05804477 ΔE=7.538e-01 ak=2.126e-02 ck=9.920e-02
#
# ============================================================
# 🔄 VQE ITERATION 182
# ============================================================
# 📊 Energy = -52.27746041 Hartree
# 📊 Energy = -32804.5769 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -17.87992859 Hartree
# 📈 Energy improvement: 0.21941563 Hartree (137.6853 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 12
#    Parameter range: [-8.6239,  7.4011]
#    Parameter variance: 20.6099
#    RMS parameter:  4.5509
#    Parameters:
#      θ[ 0]= 3.1329 θ[ 1]=-6.1090 θ[ 2]= 4.6608 θ[ 3]= 2.6692
#      θ[ 4]= 2.9225 θ[ 5]=-8.6239 θ[ 6]= 0.4128 θ[ 7]= 2.9774
#      ... and 4 more parameters
#    ==================================================
#
# ============================================================
# 🔄 VQE ITERATION 183
# ============================================================
# 📊 Energy = -51.12053036 Hartree
# 📊 Energy = -32078.5929 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -16.72299855 Hartree
# 📈 Energy improvement: -1.15693005 Hartree (-725.9840 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 12
#    Parameter range: [-8.4258,  7.2030]
#    Parameter variance: 20.5027
#    RMS parameter:  4.5350
#    Parameters:
#      θ[ 0]= 2.9348 θ[ 1]=-6.3071 θ[ 2]= 4.8589 θ[ 3]= 2.8672
#      θ[ 4]= 2.7244 θ[ 5]=-8.4258 θ[ 6]= 0.6108 θ[ 7]= 2.7793
#      ... and 4 more parameters
#    ==================================================
#
# ============================================================
# 🔄 VQE ITERATION 184
# ============================================================
# 📊 Energy = -52.21483781 Hartree
# 📊 Energy = -32765.2807 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -17.81730599 Hartree
# 📈 Energy improvement: 1.09430745 Hartree (686.6878 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 12
#    Parameter range: [-8.6478,  7.4250]
#    Parameter variance: 20.6276
#    RMS parameter:  4.5534
#    Parameters:
#      θ[ 0]= 3.1568 θ[ 1]=-6.0851 θ[ 2]= 4.6369 θ[ 3]= 2.6453
#      θ[ 4]= 2.9464 θ[ 5]=-8.6478 θ[ 6]= 0.3889 θ[ 7]= 3.0013
#      ... and 4 more parameters
#    ==================================================
# [SPSA] iter= 61 energy=-52.21483781 ΔE=1.568e-01 ak=2.105e-02 ck=9.903e-02
#
# ============================================================
# 🔄 VQE ITERATION 185
# ============================================================
# 📊 Energy = -50.30999063 Hartree
# 📊 Energy = -31569.9719 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -15.91245882 Hartree
# 📈 Energy improvement: -1.90484718 Hartree (-1195.3087 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 12
#    Parameter range: [-8.7466,  7.5239]
#    Parameter variance: 20.8412
#    RMS parameter:  4.5793
#    Parameters:
#      θ[ 0]= 3.2557 θ[ 1]=-5.9863 θ[ 2]= 4.7358 θ[ 3]= 2.5464
#      θ[ 4]= 3.0452 θ[ 5]=-8.7466 θ[ 6]= 0.4877 θ[ 7]= 2.9024
#      ... and 4 more parameters
#    ==================================================
#
# ============================================================
# 🔄 VQE ITERATION 186
# ============================================================
# 📊 Energy = -53.29334742 Hartree
# 📊 Energy = -33442.0551 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -18.89581560 Hartree
# 📈 Energy improvement: 2.98335679 Hartree (1872.0832 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 12
#    Parameter range: [-8.5489,  7.3261]
#    Parameter variance: 20.4313
#    RMS parameter:  4.5296
#    Parameters:
#      θ[ 0]= 3.0579 θ[ 1]=-6.1840 θ[ 2]= 4.5381 θ[ 3]= 2.7441
#      θ[ 4]= 2.8475 θ[ 5]=-8.5489 θ[ 6]= 0.2900 θ[ 7]= 3.1002
#      ... and 4 more parameters
#    ==================================================
#
# ============================================================
# 🔄 VQE ITERATION 187
# ============================================================
# 📊 Energy = -52.38489114 Hartree
# 📊 Energy = -32871.9907 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -17.98735933 Hartree
# 📈 Energy improvement: -0.90845628 Hartree (-570.0645 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 12
#    Parameter range: [-8.3333,  7.1106]
#    Parameter variance: 20.0636
#    RMS parameter:  4.4847
#    Parameters:
#      θ[ 0]= 2.8424 θ[ 1]=-6.3996 θ[ 2]= 4.3225 θ[ 3]= 2.9597
#      θ[ 4]= 2.6319 θ[ 5]=-8.3333 θ[ 6]= 0.0744 θ[ 7]= 3.3158
#      ... and 4 more parameters
#    ==================================================
# [SPSA] iter= 62 energy=-52.38489114 ΔE=1.701e-01 ak=2.084e-02 ck=9.887e-02
#
# ============================================================
# 🔄 VQE ITERATION 188
# ============================================================
# 📊 Energy = -52.35624118 Hartree
# 📊 Energy = -32854.0125 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -17.95870936 Hartree
# 📈 Energy improvement: -0.02864997 Hartree (-17.9781 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 12
#    Parameter range: [-8.4320,  7.0119]
#    Parameter variance: 20.0525
#    RMS parameter:  4.4852
#    Parameters:
#      θ[ 0]= 2.9411 θ[ 1]=-6.3008 θ[ 2]= 4.4212 θ[ 3]= 3.0584
#      θ[ 4]= 2.5332 θ[ 5]=-8.4320 θ[ 6]=-0.0243 θ[ 7]= 3.4145
#      ... and 4 more parameters
#    ==================================================
#
# ============================================================
# 🔄 VQE ITERATION 189
# ============================================================
# 📊 Energy = -51.85476049 Hartree
# 📊 Energy = -32539.3289 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -17.45722867 Hartree
# 📈 Energy improvement: -0.50148069 Hartree (-314.6836 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 12
#    Parameter range: [-8.2346,  7.2093]
#    Parameter variance: 20.0920
#    RMS parameter:  4.4863
#    Parameters:
#      θ[ 0]= 2.7437 θ[ 1]=-6.4983 θ[ 2]= 4.2238 θ[ 3]= 2.8610
#      θ[ 4]= 2.7306 θ[ 5]=-8.2346 θ[ 6]= 0.1731 θ[ 7]= 3.2170
#      ... and 4 more parameters
#    ==================================================
#
# ============================================================
# 🔄 VQE ITERATION 190
# ============================================================
# 📊 Energy = -52.43564577 Hartree
# 📊 Energy = -32903.8396 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -18.03811396 Hartree
# 📈 Energy improvement: 0.58088528 Hartree (364.5107 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 12
#    Parameter range: [-8.3858,  7.0581]
#    Parameter variance: 20.0556
#    RMS parameter:  4.4847
#    Parameters:
#      θ[ 0]= 2.8948 θ[ 1]=-6.3471 θ[ 2]= 4.3749 θ[ 3]= 3.0121
#      θ[ 4]= 2.5795 θ[ 5]=-8.3858 θ[ 6]= 0.0220 θ[ 7]= 3.3682
#      ... and 4 more parameters
#    ==================================================
# [SPSA] iter= 63 energy=-52.43564577 ΔE=5.075e-02 ak=2.064e-02 ck=9.871e-02
#
# ============================================================
# 🔄 VQE ITERATION 191
# ============================================================
# 📊 Energy = -53.59003765 Hartree
# 📊 Energy = -33628.2309 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -19.19250583 Hartree
# 📈 Energy improvement: 1.15439188 Hartree (724.3913 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 12
#    Parameter range: [-8.4843,  7.1567]
#    Parameter variance: 20.5393
#    RMS parameter:  4.5392
#    Parameters:
#      θ[ 0]= 2.9934 θ[ 1]=-6.4457 θ[ 2]= 4.4735 θ[ 3]= 2.9136
#      θ[ 4]= 2.6780 θ[ 5]=-8.4843 θ[ 6]=-0.0765 θ[ 7]= 3.4667
#      ... and 4 more parameters
#    ==================================================
#
# ============================================================
# 🔄 VQE ITERATION 192
# ============================================================
# 📊 Energy = -50.46928596 Hartree
# 📊 Energy = -31669.9312 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -16.07175415 Hartree
# 📈 Energy improvement: -3.12075169 Hartree (-1958.2998 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 12
#    Parameter range: [-8.2872,  6.9596]
#    Parameter variance: 19.5907
#    RMS parameter:  4.4317
#    Parameters:
#      θ[ 0]= 2.7963 θ[ 1]=-6.2486 θ[ 2]= 4.2764 θ[ 3]= 3.1107
#      θ[ 4]= 2.4809 θ[ 5]=-8.2872 θ[ 6]= 0.1206 θ[ 7]= 3.2696
#      ... and 4 more parameters
#    ==================================================
#
# ============================================================
# 🔄 VQE ITERATION 193
# ============================================================
# 📊 Energy = -52.47165045 Hartree
# 📊 Energy = -32926.4329 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -18.07411864 Hartree
# 📈 Energy improvement: 2.00236449 Hartree (1256.5017 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 12
#    Parameter range: [-8.7095,  7.3819]
#    Parameter variance: 21.7155
#    RMS parameter:  4.6691
#    Parameters:
#      θ[ 0]= 3.2185 θ[ 1]=-6.6709 θ[ 2]= 4.6987 θ[ 3]= 2.6884
#      θ[ 4]= 2.9032 θ[ 5]=-8.7095 θ[ 6]=-0.3017 θ[ 7]= 3.6919
#      ... and 4 more parameters
#    ==================================================
# [SPSA] iter= 64 energy=-52.47165045 ΔE=3.600e-02 ak=2.045e-02 ck=9.855e-02
#
# ============================================================
# 🔄 VQE ITERATION 194
# ============================================================
# 📊 Energy = -52.89368911 Hartree
# 📊 Energy = -33191.2660 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -18.49615729 Hartree
# 📈 Energy improvement: 0.42203866 Hartree (264.8331 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 12
#    Parameter range: [-8.6111,  7.4803]
#    Parameter variance: 21.6481
#    RMS parameter:  4.6600
#    Parameters:
#      θ[ 0]= 3.1201 θ[ 1]=-6.7693 θ[ 2]= 4.7971 θ[ 3]= 2.5900
#      θ[ 4]= 2.8048 θ[ 5]=-8.6111 θ[ 6]=-0.4001 θ[ 7]= 3.5935
#      ... and 4 more parameters
#    ==================================================
#
# ============================================================
# 🔄 VQE ITERATION 195
# ============================================================
# 📊 Energy = -51.21744229 Hartree
# 📊 Energy = -32139.4060 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -16.81991048 Hartree
# 📈 Energy improvement: -1.67624681 Hartree (-1051.8600 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 12
#    Parameter range: [-8.8079,  7.2835]
#    Parameter variance: 21.8002
#    RMS parameter:  4.6804
#    Parameters:
#      θ[ 0]= 3.3169 θ[ 1]=-6.5725 θ[ 2]= 4.6003 θ[ 3]= 2.7868
#      θ[ 4]= 3.0016 θ[ 5]=-8.8079 θ[ 6]=-0.2033 θ[ 7]= 3.7903
#      ... and 4 more parameters
#    ==================================================
#
# ============================================================
# 🔄 VQE ITERATION 196
# ============================================================
# 📊 Energy = -52.54291109 Hartree
# 📊 Energy = -32971.1496 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -18.14537927 Hartree
# 📈 Energy improvement: 1.32546879 Hartree (831.7436 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 12
#    Parameter range: [-8.5370,  7.5544]
#    Parameter variance: 21.6086
#    RMS parameter:  4.6544
#    Parameters:
#      θ[ 0]= 3.0460 θ[ 1]=-6.8434 θ[ 2]= 4.8712 θ[ 3]= 2.5159
#      θ[ 4]= 2.7307 θ[ 5]=-8.5370 θ[ 6]=-0.4743 θ[ 7]= 3.5194
#      ... and 4 more parameters
#    ==================================================
# [SPSA] iter= 65 energy=-52.54291109 ΔE=7.126e-02 ak=2.026e-02 ck=9.840e-02
#
# ============================================================
# 🔄 VQE ITERATION 197
# ============================================================
# 📊 Energy = -52.26738380 Hartree
# 📊 Energy = -32798.2537 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -17.86985198 Hartree
# 📈 Energy improvement: -0.27552729 Hartree (-172.8959 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 12
#    Parameter range: [-8.6352,  7.4562]
#    Parameter variance: 21.9109
#    RMS parameter:  4.6853
#    Parameters:
#      θ[ 0]= 3.1442 θ[ 1]=-6.9416 θ[ 2]= 4.7729 θ[ 3]= 2.6141
#      θ[ 4]= 2.6324 θ[ 5]=-8.6352 θ[ 6]=-0.5725 θ[ 7]= 3.6176
#      ... and 4 more parameters
#    ==================================================
#
# ============================================================
# 🔄 VQE ITERATION 198
# ============================================================
# 📊 Energy = -51.65453556 Hartree
# 📊 Energy = -32413.6860 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -17.25700375 Hartree
# 📈 Energy improvement: -0.61284823 Hartree (-384.5678 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 12
#    Parameter range: [-8.4387,  7.6527]
#    Parameter variance: 21.3234
#    RMS parameter:  4.6255
#    Parameters:
#      θ[ 0]= 2.9477 θ[ 1]=-6.7451 θ[ 2]= 4.9694 θ[ 3]= 2.4176
#      θ[ 4]= 2.8289 θ[ 5]=-8.4387 θ[ 6]=-0.3760 θ[ 7]= 3.4211
#      ... and 4 more parameters
#    ==================================================
#
# ============================================================
# 🔄 VQE ITERATION 199
# ============================================================
# 📊 Energy = -52.52267356 Hartree
# 📊 Energy = -32958.4504 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -18.12514175 Hartree
# 📈 Energy improvement: 0.86813800 Hartree (544.7644 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 12
#    Parameter range: [-8.5996,  7.4918]
#    Parameter variance: 21.7992
#    RMS parameter:  4.6739
#    Parameters:
#      θ[ 0]= 3.1086 θ[ 1]=-6.9060 θ[ 2]= 4.8086 θ[ 3]= 2.5785
#      θ[ 4]= 2.6681 θ[ 5]=-8.5996 θ[ 6]=-0.5369 θ[ 7]= 3.5820
#      ... and 4 more parameters
#    ==================================================
# [SPSA] iter= 66 energy=-52.52267356 ΔE=-2.024e-02 ak=2.007e-02 ck=9.825e-02
#
# ============================================================
# 🔄 VQE ITERATION 200
# ============================================================
# 📊 Energy = -53.33923387 Hartree
# 📊 Energy = -33470.8493 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -18.94170206 Hartree
# 📈 Energy improvement: 0.81656031 Hartree (512.3989 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 12
#    Parameter range: [-8.6977,  7.3937]
#    Parameter variance: 21.5366
#    RMS parameter:  4.6465
#    Parameters:
#      θ[ 0]= 3.0105 θ[ 1]=-6.8079 θ[ 2]= 4.7105 θ[ 3]= 2.4804
#      θ[ 4]= 2.7662 θ[ 5]=-8.6977 θ[ 6]=-0.4388 θ[ 7]= 3.6801
#      ... and 4 more parameters
#    ==================================================
#
# ============================================================
# 🔄 VQE ITERATION 201
# ============================================================
# 📊 Energy = -50.59766607 Hartree
# 📊 Energy = -31750.4908 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -16.20013426 Hartree
# 📈 Energy improvement: -2.74156780 Hartree (-1720.3585 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 12
#    Parameter range: [-8.5015,  7.5899]
#    Parameter variance: 22.0806
#    RMS parameter:  4.7032
#    Parameters:
#      θ[ 0]= 3.2067 θ[ 1]=-7.0041 θ[ 2]= 4.9067 θ[ 3]= 2.6766
#      θ[ 4]= 2.5700 θ[ 5]=-8.5015 θ[ 6]=-0.6350 θ[ 7]= 3.4839
#      ... and 4 more parameters
#    ==================================================
#
# ============================================================
# 🔄 VQE ITERATION 202
# ============================================================
# 📊 Energy = -51.88415830 Hartree
# 📊 Energy = -32557.7763 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -17.48662649 Hartree
# 📈 Energy improvement: 1.28649223 Hartree (807.2855 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 12
#    Parameter range: [-8.8775,  7.2139]
#    Parameter variance: 21.1037
#    RMS parameter:  4.6012
#    Parameters:
#      θ[ 0]= 2.8307 θ[ 1]=-6.6281 θ[ 2]= 4.5307 θ[ 3]= 2.3005
#      θ[ 4]= 2.9460 θ[ 5]=-8.8775 θ[ 6]=-0.2589 θ[ 7]= 3.8599
#      ... and 4 more parameters
#    ==================================================
# [SPSA] iter= 67 energy=-51.88415830 ΔE=-6.385e-01 ak=1.989e-02 ck=9.810e-02
#
# ============================================================
# 🔄 VQE ITERATION 203
# ============================================================
# 📊 Energy = -52.32419577 Hartree
# 📊 Energy = -32833.9038 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -17.92666396 Hartree
# 📈 Energy improvement: 0.44003747 Hartree (276.1275 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 12
#    Parameter range: [-8.9755,  7.3118]
#    Parameter variance: 20.9164
#    RMS parameter:  4.5808
#    Parameters:
#      θ[ 0]= 2.7327 θ[ 1]=-6.5301 θ[ 2]= 4.4327 θ[ 3]= 2.2026
#      θ[ 4]= 2.8481 θ[ 5]=-8.9755 θ[ 6]=-0.1610 θ[ 7]= 3.7620
#      ... and 4 more parameters
#    ==================================================
#
# ============================================================
# 🔄 VQE ITERATION 204
# ============================================================
# 📊 Energy = -51.15285984 Hartree
# 📊 Energy = -32098.8799 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -16.75532803 Hartree
# 📈 Energy improvement: -1.17133593 Hartree (-735.0238 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 12
#    Parameter range: [-8.7796,  7.1159]
#    Parameter variance: 21.3101
#    RMS parameter:  4.6236
#    Parameters:
#      θ[ 0]= 2.9286 θ[ 1]=-6.7260 θ[ 2]= 4.6286 θ[ 3]= 2.3985
#      θ[ 4]= 3.0440 θ[ 5]=-8.7796 θ[ 6]=-0.3569 θ[ 7]= 3.9579
#      ... and 4 more parameters
#    ==================================================
#
# ============================================================
# 🔄 VQE ITERATION 205
# ============================================================
# 📊 Energy = -52.37095474 Hartree
# 📊 Energy = -32863.2454 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -17.97342292 Hartree
# 📈 Energy improvement: 1.21809490 Hartree (764.3655 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 12
# ...
# 📊 Energy = -58.80210741 Hartree
# 📊 Energy = -36898.8516 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -24.40457560 Hartree
# 📈 Energy improvement: 0.05651674 Hartree (35.4648 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 12
#    Parameter range: [-7.8017,  7.2480]
#    Parameter variance: 19.5553
#    RMS parameter:  4.4376
#    Parameters:
#      θ[ 0]= 2.9302 θ[ 1]=-6.3296 θ[ 2]= 5.8288 θ[ 3]= 1.5532
#      θ[ 4]= 1.6632 θ[ 5]=-7.8017 θ[ 6]= 0.1414 θ[ 7]= 2.9839
#      ... and 4 more parameters
#    ==================================================
# [SPSA] iter=123 energy=-58.80210741 ΔE=6.771e-01 ak=1.380e-02 ck=9.226e-02
#
# ============================================================
# 🔄 VQE ITERATION 371
# ============================================================
# 📊 Energy = -57.02292776 Hartree
# 📊 Energy = -35782.4004 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -22.62539595 Hartree
# 📈 Energy improvement: -1.77917964 Hartree (-1116.4512 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 12
#    Parameter range: [-7.8939,  7.3402]
#    Parameter variance: 19.9630
#    RMS parameter:  4.4874
#    Parameters:
#      θ[ 0]= 3.0224 θ[ 1]=-6.4218 θ[ 2]= 5.9210 θ[ 3]= 1.6454
#      θ[ 4]= 1.7553 θ[ 5]=-7.8939 θ[ 6]= 0.2336 θ[ 7]= 3.0761
#      ... and 4 more parameters
#    ==================================================
#
# ============================================================
# 🔄 VQE ITERATION 372
# ============================================================
# 📊 Energy = -59.61473651 Hartree
# 📊 Energy = -37408.7837 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -25.21720470 Hartree
# 📈 Energy improvement: 2.59180875 Hartree (1626.3833 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 12
#    Parameter range: [-7.7096,  7.1558]
#    Parameter variance: 19.1603
#    RMS parameter:  4.3892
#    Parameters:
#      θ[ 0]= 2.8380 θ[ 1]=-6.2374 θ[ 2]= 5.7366 θ[ 3]= 1.4610
#      θ[ 4]= 1.5710 θ[ 5]=-7.7096 θ[ 6]= 0.0493 θ[ 7]= 2.8917
#      ... and 4 more parameters
#    ==================================================
#
# ============================================================
# 🔄 VQE ITERATION 373
# ============================================================
# 📊 Energy = -59.08661863 Hartree
# 📊 Energy = -37077.3850 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -24.68908681 Hartree
# 📈 Energy improvement: -0.52811789 Hartree (-331.3987 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 12
#    Parameter range: [-7.6087,  7.0550]
#    Parameter variance: 18.7428
#    RMS parameter:  4.3379
#    Parameters:
#      θ[ 0]= 2.7371 θ[ 1]=-6.1366 θ[ 2]= 5.6358 θ[ 3]= 1.3602
#      θ[ 4]= 1.4701 θ[ 5]=-7.6087 θ[ 6]=-0.0516 θ[ 7]= 2.7908
#      ... and 4 more parameters
#    ==================================================
# [SPSA] iter=124 energy=-59.08661863 ΔE=2.845e-01 ak=1.373e-02 ck=9.218e-02
#
# ============================================================
# 🔄 VQE ITERATION 374
# ============================================================
# 📊 Energy = -59.75033016 Hartree
# 📊 Energy = -37493.8699 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -25.35279835 Hartree
# 📈 Energy improvement: 0.66371154 Hartree (416.4850 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 12
#    Parameter range: [-7.5166,  6.9629]
#    Parameter variance: 18.4748
#    RMS parameter:  4.3113
#    Parameters:
#      θ[ 0]= 2.8292 θ[ 1]=-6.0445 θ[ 2]= 5.7279 θ[ 3]= 1.4523
#      θ[ 4]= 1.5622 θ[ 5]=-7.5166 θ[ 6]= 0.0405 θ[ 7]= 2.8829
#      ... and 4 more parameters
#    ==================================================
#
# ============================================================
# 🔄 VQE ITERATION 375
# ============================================================
# 📊 Energy = -57.19185934 Hartree
# 📊 Energy = -35888.4065 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -22.79432752 Hartree
# 📈 Energy improvement: -2.55847082 Hartree (-1605.4635 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 12
#    Parameter range: [-7.7008,  7.1471]
#    Parameter variance: 19.0202
#    RMS parameter:  4.3664
#    Parameters:
#      θ[ 0]= 2.6450 θ[ 1]=-6.2287 θ[ 2]= 5.5437 θ[ 3]= 1.2681
#      θ[ 4]= 1.3780 θ[ 5]=-7.7008 θ[ 6]=-0.1437 θ[ 7]= 2.6987
#      ... and 4 more parameters
#    ==================================================
#
# ============================================================
# 🔄 VQE ITERATION 376
# ============================================================
# 📊 Energy = -58.90386344 Hartree
# 📊 Energy = -36962.7044 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -24.50633163 Hartree
# 📈 Energy improvement: 1.71200411 Hartree (1074.2980 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 12
#    Parameter range: [-7.4189,  6.8652]
#    Parameter variance: 18.2010
#    RMS parameter:  4.2850
#    Parameters:
#      θ[ 0]= 2.9269 θ[ 1]=-5.9468 θ[ 2]= 5.8256 θ[ 3]= 1.5500
#      θ[ 4]= 1.6599 θ[ 5]=-7.4189 θ[ 6]= 0.1382 θ[ 7]= 2.9806
#      ... and 4 more parameters
#    ==================================================
# [SPSA] iter=125 energy=-58.90386344 ΔE=-1.828e-01 ak=1.366e-02 ck=9.211e-02
#
# ============================================================
# 🔄 VQE ITERATION 377
# ============================================================
# 📊 Energy = -58.89669013 Hartree
# 📊 Energy = -36958.2031 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -24.49915831 Hartree
# 📈 Energy improvement: -0.00717332 Hartree (-4.5013 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 12
#    Parameter range: [-7.3269,  6.7732]
#    Parameter variance: 17.9347
#    RMS parameter:  4.2538
#    Parameters:
#      θ[ 0]= 2.8349 θ[ 1]=-6.0388 θ[ 2]= 5.7335 θ[ 3]= 1.4579
#      θ[ 4]= 1.7519 θ[ 5]=-7.3269 θ[ 6]= 0.0462 θ[ 7]= 3.0727
#      ... and 4 more parameters
#    ==================================================
#
# ============================================================
# 🔄 VQE ITERATION 378
# ============================================================
# 📊 Energy = -57.80375860 Hartree
# 📊 Energy = -36272.3788 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -23.40622679 Hartree
# 📈 Energy improvement: -1.09293152 Hartree (-685.8244 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 12
#    Parameter range: [-7.5110,  6.9572]
#    Parameter variance: 18.4843
#    RMS parameter:  4.3179
#    Parameters:
#      θ[ 0]= 3.0190 θ[ 1]=-5.8548 θ[ 2]= 5.9176 θ[ 3]= 1.6420
#      θ[ 4]= 1.5679 θ[ 5]=-7.5110 θ[ 6]= 0.2302 θ[ 7]= 2.8886
#      ... and 4 more parameters
#    ==================================================
#
# ============================================================
# 🔄 VQE ITERATION 379
# ============================================================
# 📊 Energy = -58.95735859 Hartree
# 📊 Energy = -36996.2731 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -24.55982677 Hartree
# 📈 Energy improvement: 1.15359998 Hartree (723.8944 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 12
#    Parameter range: [-7.3382,  6.7845]
#    Parameter variance: 17.9664
#    RMS parameter:  4.2575
#    Parameters:
#      θ[ 0]= 2.8462 θ[ 1]=-6.0275 θ[ 2]= 5.7448 θ[ 3]= 1.4692
#      θ[ 4]= 1.7407 θ[ 5]=-7.3382 θ[ 6]= 0.0574 θ[ 7]= 3.0614
#      ... and 4 more parameters
#    ==================================================
# [SPSA] iter=126 energy=-58.95735859 ΔE=5.350e-02 ak=1.360e-02 ck=9.204e-02
#
# ============================================================
# 🔄 VQE ITERATION 380
# ============================================================
# 📊 Energy = -58.17355604 Hartree
# 📊 Energy = -36504.4300 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -23.77602423 Hartree
# 📈 Energy improvement: -0.78380254 Hartree (-491.8432 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 12
#    Parameter range: [-7.4302,  6.6925]
#    Parameter variance: 18.1257
#    RMS parameter:  4.2762
#    Parameters:
#      θ[ 0]= 2.9381 θ[ 1]=-6.1195 θ[ 2]= 5.8368 θ[ 3]= 1.5612
#      θ[ 4]= 1.6487 θ[ 5]=-7.4302 θ[ 6]=-0.0345 θ[ 7]= 3.1533
#      ... and 4 more parameters
#    ==================================================
#
# ============================================================
# 🔄 VQE ITERATION 381
# ============================================================
# 📊 Energy = -59.02160758 Hartree
# 📊 Energy = -37036.5899 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -24.62407576 Hartree
# 📈 Energy improvement: 0.84805153 Hartree (532.1600 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 12
#    Parameter range: [-7.2462,  6.8764]
#    Parameter variance: 17.8241
#    RMS parameter:  4.2408
#    Parameters:
#      θ[ 0]= 2.7542 θ[ 1]=-5.9356 θ[ 2]= 5.6528 θ[ 3]= 1.3773
#      θ[ 4]= 1.8326 θ[ 5]=-7.2462 θ[ 6]= 0.1494 θ[ 7]= 2.9694
#      ... and 4 more parameters
#    ==================================================
#
# ============================================================
# 🔄 VQE ITERATION 382
# ============================================================
# 📊 Energy = -59.07578391 Hartree
# 📊 Energy = -37070.5861 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -24.67825210 Hartree
# 📈 Energy improvement: 0.05417633 Hartree (33.9961 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 12
#    Parameter range: [-7.2758,  6.8469]
#    Parameter variance: 17.8680
#    RMS parameter:  4.2460
#    Parameters:
#      θ[ 0]= 2.7838 θ[ 1]=-5.9651 θ[ 2]= 5.6824 θ[ 3]= 1.4068
#      θ[ 4]= 1.8031 θ[ 5]=-7.2758 θ[ 6]= 0.1199 θ[ 7]= 2.9990
#      ... and 4 more parameters
#    ==================================================
# [SPSA] iter=127 energy=-59.07578391 ΔE=1.184e-01 ak=1.353e-02 ck=9.196e-02
#
# ============================================================
# 🔄 VQE ITERATION 383
# ============================================================
# 📊 Energy = -58.99308739 Hartree
# 📊 Energy = -37018.6933 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -24.59555558 Hartree
# 📈 Energy improvement: -0.08269652 Hartree (-51.8928 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 12
#    Parameter range: [-7.3677,  6.9388]
#    Parameter variance: 18.0848
#    RMS parameter:  4.2744
#    Parameters:
#      θ[ 0]= 2.8757 θ[ 1]=-6.0570 θ[ 2]= 5.5905 θ[ 3]= 1.4987
#      θ[ 4]= 1.8950 θ[ 5]=-7.3677 θ[ 6]= 0.2117 θ[ 7]= 3.0908
#      ... and 4 more parameters
#    ==================================================
#
# ============================================================
# 🔄 VQE ITERATION 384
# ============================================================
# 📊 Energy = -58.28141933 Hartree
# 📊 Energy = -36572.1152 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -23.88388752 Hartree
# 📈 Energy improvement: -0.71166806 Hartree (-446.5781 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 12
#    Parameter range: [-7.1839,  6.7550]
#    Parameter variance: 17.6662
#    RMS parameter:  4.2193
#    Parameters:
#      θ[ 0]= 2.6919 θ[ 1]=-5.8732 θ[ 2]= 5.7743 θ[ 3]= 1.3149
#      θ[ 4]= 1.7112 θ[ 5]=-7.1839 θ[ 6]= 0.0280 θ[ 7]= 2.9071
#      ... and 4 more parameters
#    ==================================================
#
# ============================================================
# 🔄 VQE ITERATION 385
# ============================================================
# 📊 Energy = -59.12378612 Hartree
# 📊 Energy = -37100.7079 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -24.72625431 Hartree
# 📈 Energy improvement: 0.84236678 Hartree (528.5927 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 12
#    Parameter range: [-7.3279,  6.8990]
#    Parameter variance: 17.9892
#    RMS parameter:  4.2619
#    Parameters:
#      θ[ 0]= 2.8359 θ[ 1]=-6.0173 θ[ 2]= 5.6302 θ[ 3]= 1.4590
#      θ[ 4]= 1.8552 θ[ 5]=-7.3279 θ[ 6]= 0.1720 θ[ 7]= 3.0511
#      ... and 4 more parameters
#    ==================================================
# [SPSA] iter=128 energy=-59.12378612 ΔE=4.800e-02 ak=1.347e-02 ck=9.189e-02
#
# ============================================================
# 🔄 VQE ITERATION 386
# ============================================================
# 📊 Energy = -58.60932773 Hartree
# 📊 Energy = -36777.8806 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -24.21179592 Hartree
# 📈 Energy improvement: -0.51445839 Hartree (-322.8273 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 12
#    Parameter range: [-7.4198,  6.9909]
#    Parameter variance: 18.2698
#    RMS parameter:  4.2947
#    Parameters:
#      θ[ 0]= 2.9277 θ[ 1]=-6.1091 θ[ 2]= 5.7221 θ[ 3]= 1.3672
#      θ[ 4]= 1.9470 θ[ 5]=-7.4198 θ[ 6]= 0.0802 θ[ 7]= 2.9593
#      ... and 4 more parameters
#    ==================================================
#
# ============================================================
# 🔄 VQE ITERATION 387
# ============================================================
# 📊 Energy = -58.34109314 Hartree
# 📊 Energy = -36609.5610 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -23.94356133 Hartree
# 📈 Energy improvement: -0.26823459 Hartree (-168.3196 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 12
#    Parameter range: [-7.2361,  6.8072]
#    Parameter variance: 17.7254
#    RMS parameter:  4.2308
#    Parameters:
#      θ[ 0]= 2.7441 θ[ 1]=-5.9255 θ[ 2]= 5.5384 θ[ 3]= 1.5508
#      θ[ 4]= 1.7634 θ[ 5]=-7.2361 θ[ 6]= 0.2638 θ[ 7]= 3.1429
#      ... and 4 more parameters
#    ==================================================
#
# ============================================================
# 🔄 VQE ITERATION 388
# ============================================================
# 📊 Energy = -59.12349505 Hartree
# 📊 Energy = -37100.5253 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -24.72596324 Hartree
# 📈 Energy improvement: 0.78240191 Hartree (490.9642 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 12
#    Parameter range: [-7.3475,  6.9186]
#    Parameter variance: 18.0476
#    RMS parameter:  4.2687
#    Parameters:
#      θ[ 0]= 2.8555 θ[ 1]=-6.0369 θ[ 2]= 5.6498 θ[ 3]= 1.4394
#      θ[ 4]= 1.8748 θ[ 5]=-7.3475 θ[ 6]= 0.1524 θ[ 7]= 3.0315
#      ... and 4 more parameters
#    ==================================================
# [SPSA] iter=129 energy=-59.12349505 ΔE=-2.911e-04 ak=1.341e-02 ck=9.182e-02
# [SPSA] Converged (|ΔE| < 0.0005) at iter 129
#
# ============================================================
# 🔄 VQE ITERATION 389
# ============================================================
# 📊 Energy = -60.32196200 Hartree
# 📊 Energy = -37852.5741 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -25.92443019 Hartree
# 📈 Energy improvement: 1.19846695 Hartree (752.0488 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 12
#    Parameter range: [-8.0712,  7.7701]
#    Parameter variance: 20.3140
#    RMS parameter:  4.5288
#    Parameters:
#      θ[ 0]= 3.1151 θ[ 1]=-6.0091 θ[ 2]= 5.3912 θ[ 3]= 1.7403
#      θ[ 4]= 1.7992 θ[ 5]=-8.0712 θ[ 6]=-0.1302 θ[ 7]= 3.2533
#      ... and 4 more parameters
#    ==================================================
#
# 🏁 VQE optimization complete
#    Final energy: -60.3219620006 Hartree
#    Total improvement: 60.321962 Hartree
#    Objective evaluations: 389
#    Effective circuit evaluations: 389
#
# [Basic VQE] Final total energy (raw): -60.3219620006 Hartree
# [Basic VQE] Final energy (minus constant shift -34.397532 ): -25.9244301874 Hartree

# %% [markdown]
# ### Cell 6 Description: Hybrid VQE (SPSA → COBYLA)
# Executes a two-phase optimization: global stochastic exploration via SPSA, then deterministic local refinement via COBYLA (forced switch). Tracks energy history to quantify improvement over pure SPSA.

# %%
# === 6. Hybrid VQE (SPSA -> COBYLA, no ZNE) ===
from vqeskeletal import HybridSPSAThenCOBYLA, ZNEDenoiserPlugin, VQE

class DirectHam:
    def __init__(self, sysd): self.sysd = sysd
    def get_hamiltonian(self): return self.sysd

hybrid_opt = HybridSPSAThenCOBYLA(spsa_iters=40, switch_tol=5e-3, min_spsa=12, force_cobyla=True, verbose=True)
no_zne2 = ZNEDenoiserPlugin(noise_factors=[1.0], verbose=False)

vqe_hybrid = VQE(uccsd_ansatz, DirectHam(ham_system), hybrid_opt, no_zne2, verbose=True)
init_hybrid = uccsd_ansatz.get_initial_parameters('random_small')
params_hybrid, energy_hybrid = vqe_hybrid.run(init_hybrid)
print('\n[Hybrid VQE] Final energy:', energy_hybrid)
# Out:
# 🔄 Initializing VQE system...
# ======================================================================
# BUILDING UCCSD ANSATZ FROM HAMILTONIAN
# ======================================================================
# System: qubits=6 spatial_orbs=3 particles=(2, 2)
# ✓ HF state ready (HartreeFock constructed)
# Ansatz depth=2 gates=5 params=8
# ✓ Ansatz construction complete (params=8)
# ✓ Quantum estimator setup complete (Qiskit Aer)
#
# 🚀 Starting VQE optimization run
#    Parameter count: 8
#    Optimizer: HybridSPSAThenCOBYLA
# [Hybrid] Starting SPSA (max_iter=40) -> COBYLA (switch_tol=0.005)
#
# ============================================================
# 🔄 VQE ITERATION 1
# ============================================================
# 📊 Energy = -56.34099028 Hartree
# 📊 Energy = -35354.4785 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -21.94345847 Hartree
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 8
#    Parameter range: [-0.0128,  0.0072]
#    Parameter variance:  0.0001
#    RMS parameter:  0.0079
#    Parameters:
#      θ[ 0]= 0.0072 θ[ 1]=-0.0010 θ[ 2]= 0.0025 θ[ 3]=-0.0111
#      θ[ 4]=-0.0098 θ[ 5]= 0.0060 θ[ 6]= 0.0043 θ[ 7]=-0.0128
#    ==================================================
# [SPSA] Initial energy: -56.34099028076384
#
# ============================================================
# 🔄 VQE ITERATION 2
# ============================================================
# 📊 Energy = -53.79719479 Hartree
# 📊 Energy = -33758.2239 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -19.39966297 Hartree
# 📈 Energy improvement: -2.54379549 Hartree (-1596.2546 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 8
#    Parameter range: [-0.1611,  0.1572]
#    Parameter variance:  0.0170
#    RMS parameter:  0.1497
#    Parameters:
#      θ[ 0]= 0.1572 θ[ 1]= 0.1490 θ[ 2]= 0.1525 θ[ 3]=-0.1611
#      θ[ 4]= 0.1402 θ[ 5]=-0.1440 θ[ 6]= 0.1543 θ[ 7]= 0.1372
#    ==================================================
#
# ============================================================
# 🔄 VQE ITERATION 3
# ============================================================
# 📊 Energy = -54.56319463 Hartree
# 📊 Energy = -34238.8957 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -20.16566281 Hartree
# 📈 Energy improvement: 0.76599984 Hartree (480.6718 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 8
#    Parameter range: [-0.1628,  0.1560]
#    Parameter variance:  0.0168
#    RMS parameter:  0.1508
#    Parameters:
#      θ[ 0]=-0.1428 θ[ 1]=-0.1510 θ[ 2]=-0.1475 θ[ 3]= 0.1389
#      θ[ 4]=-0.1598 θ[ 5]= 0.1560 θ[ 6]=-0.1457 θ[ 7]=-0.1628
#    ==================================================
#
# ============================================================
# 🔄 VQE ITERATION 4
# ============================================================
# 📊 Energy = -50.72237738 Hartree
# 📊 Energy = -31828.7483 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -16.32484557 Hartree
# 📈 Energy improvement: -3.84081724 Hartree (-2410.1474 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 8
#    Parameter range: [-0.5235,  0.5166]
#    Parameter variance:  0.1953
#    RMS parameter:  0.5113
#    Parameters:
#      θ[ 0]=-0.5034 θ[ 1]=-0.5117 θ[ 2]=-0.5082 θ[ 3]= 0.4995
#      θ[ 4]=-0.5204 θ[ 5]= 0.5166 θ[ 6]=-0.5064 θ[ 7]=-0.5235
#    ==================================================
# [SPSA] iter=  1 energy=-50.72237738 ΔE=-5.619e+00 ak=2.000e-01 ck=1.500e-01
#
# ============================================================
# 🔄 VQE ITERATION 5
# ============================================================
# 📊 Energy = -49.33782882 Hartree
# 📊 Energy = -30959.9316 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -14.94029700 Hartree
# 📈 Energy improvement: -1.38454857 Hartree (-868.8167 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 8
#    Parameter range: [-0.6480,  0.6565]
#    Parameter variance:  0.2449
#    RMS parameter:  0.5291
#    Parameters:
#      θ[ 0]=-0.3636 θ[ 1]=-0.3718 θ[ 2]=-0.6480 θ[ 3]= 0.6394
#      θ[ 4]=-0.3806 θ[ 5]= 0.6565 θ[ 6]=-0.6463 θ[ 7]=-0.3837
#    ==================================================
#
# ============================================================
# 🔄 VQE ITERATION 6
# ============================================================
# 📊 Energy = -49.62811222 Hartree
# 📊 Energy = -31142.0871 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -15.23058041 Hartree
# 📈 Energy improvement: 0.29028340 Hartree (182.1554 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 8
#    Parameter range: [-0.6634,  0.3768]
#    Parameter variance:  0.1750
#    RMS parameter:  0.5310
#    Parameters:
#      θ[ 0]=-0.6433 θ[ 1]=-0.6515 θ[ 2]=-0.3683 θ[ 3]= 0.3597
#      θ[ 4]=-0.6603 θ[ 5]= 0.3768 θ[ 6]=-0.3665 θ[ 7]=-0.6634
#    ==================================================
#
# ============================================================
# 🔄 VQE ITERATION 7
# ============================================================
# 📊 Energy = -49.67808785 Hartree
# 📊 Energy = -31173.4472 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -15.28055604 Hartree
# 📈 Energy improvement: 0.04997563 Hartree (31.3602 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 8
#    Parameter range: [-0.6603,  0.3799]
#    Parameter variance:  0.1751
#    RMS parameter:  0.5302
#    Parameters:
#      θ[ 0]=-0.6402 θ[ 1]=-0.6484 θ[ 2]=-0.3714 θ[ 3]= 0.3628
#      θ[ 4]=-0.6572 θ[ 5]= 0.3799 θ[ 6]=-0.3697 θ[ 7]=-0.6603
#    ==================================================
# [SPSA] iter=  2 energy=-49.67808785 ΔE=-1.044e+00 ak=1.318e-01 ck=1.399e-01
#
# ============================================================
# 🔄 VQE ITERATION 8
# ============================================================
# 📊 Energy = -49.96328144 Hartree
# 📊 Energy = -31352.4088 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -15.56574963 Hartree
# 📈 Energy improvement: 0.28519359 Hartree (178.9615 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 8
#    Parameter range: [-0.7827,  0.5141]
#    Parameter variance:  0.2419
#    RMS parameter:  0.5899
#    Parameters:
#      θ[ 0]=-0.7744 θ[ 1]=-0.7827 θ[ 2]=-0.5057 θ[ 3]= 0.4970
#      θ[ 4]=-0.5229 θ[ 5]= 0.5141 θ[ 6]=-0.5039 θ[ 7]=-0.5260
#    ==================================================
#
# ============================================================
# 🔄 VQE ITERATION 9
# ============================================================
# 📊 Energy = -45.37057736 Hartree
# 📊 Energy = -28470.4456 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -10.97304555 Hartree
# 📈 Energy improvement: -4.59270408 Hartree (-2881.9631 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 8
#    Parameter range: [-0.7945,  0.2456]
#    Parameter variance:  0.1443
#    RMS parameter:  0.5003
#    Parameters:
#      θ[ 0]=-0.5059 θ[ 1]=-0.5142 θ[ 2]=-0.2372 θ[ 3]= 0.2285
#      θ[ 4]=-0.7914 θ[ 5]= 0.2456 θ[ 6]=-0.2354 θ[ 7]=-0.7945
#    ==================================================
#
# ============================================================
# 🔄 VQE ITERATION 10
# ============================================================
# 📊 Energy = -40.72607775 Hartree
# 📊 Energy = -25555.9803 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -6.32854593 Hartree
# 📈 Energy improvement: -4.64449961 Hartree (-2914.4653 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 8
#    Parameter range: [-2.4142,  2.1457]
#    Parameter variance:  3.9354
#    RMS parameter:  2.0103
#    Parameters:
#      θ[ 0]=-2.4060 θ[ 1]=-2.4142 θ[ 2]=-2.1372 θ[ 3]= 2.1286
#      θ[ 4]= 1.1086 θ[ 5]= 2.1457 θ[ 6]=-2.1355 θ[ 7]= 1.1055
#    ==================================================
# [SPSA] iter=  3 energy=-40.72607775 ΔE=-8.952e+00 ak=1.032e-01 ck=1.342e-01
#
# ============================================================
# 🔄 VQE ITERATION 11
# ============================================================
# 📊 Energy = -40.08488365 Hartree
# 📊 Energy = -25153.6253 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -5.68735184 Hartree
# 📈 Energy improvement: -0.64119409 Hartree (-402.3551 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 8
#    Parameter range: [-2.2838,  2.2761]
#    Parameter variance:  3.6045
#    RMS parameter:  1.9210
#    Parameters:
#      θ[ 0]=-2.2756 θ[ 1]=-2.2838 θ[ 2]=-2.0068 θ[ 3]= 1.9982
#      θ[ 4]= 0.9782 θ[ 5]= 2.2761 θ[ 6]=-2.0050 θ[ 7]= 0.9751
#    ==================================================
#
# ============================================================
# 🔄 VQE ITERATION 12
# ============================================================
# 📊 Energy = -40.60206693 Hartree
# 📊 Energy = -25478.1624 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -6.20453512 Hartree
# 📈 Energy improvement: 0.51718328 Hartree (324.5372 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 8
#    Parameter range: [-2.5446,  2.2590]
#    Parameter variance:  4.2981
#    RMS parameter:  2.1039
#    Parameters:
#      θ[ 0]=-2.5364 θ[ 1]=-2.5446 θ[ 2]=-2.2676 θ[ 3]= 2.2590
#      θ[ 4]= 1.2390 θ[ 5]= 2.0153 θ[ 6]=-2.2659 θ[ 7]= 1.2359
#    ==================================================
#
# ============================================================
# 🔄 VQE ITERATION 13
# ============================================================
# 📊 Energy = -40.41391007 Hartree
# 📊 Energy = -25360.0923 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -6.01637826 Hartree
# 📈 Energy improvement: -0.18815686 Hartree (-118.0701 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 8
#    Parameter range: [-2.5864,  2.3007]
#    Parameter variance:  4.4210
#    RMS parameter:  2.1347
#    Parameters:
#      θ[ 0]=-2.5781 θ[ 1]=-2.5864 θ[ 2]=-2.3094 θ[ 3]= 2.3007
#      θ[ 4]= 1.2808 θ[ 5]= 1.9735 θ[ 6]=-2.3076 θ[ 7]= 1.2777
#    ==================================================
# [SPSA] iter=  4 energy=-40.41391007 ΔE=-3.122e-01 ak=8.681e-02 ck=1.304e-01
#
# ============================================================
# 🔄 VQE ITERATION 14
# ============================================================
# 📊 Energy = -41.33796698 Hartree
# 📊 Energy = -25939.9463 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -6.94043517 Hartree
# 📈 Energy improvement: 0.92405692 Hartree (579.8540 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 8
#    Parameter range: [-2.4589,  2.1732]
#    Parameter variance:  4.0304
#    RMS parameter:  2.0471
#    Parameters:
#      θ[ 0]=-2.4506 θ[ 1]=-2.4589 θ[ 2]=-2.4369 θ[ 3]= 2.1732
#      θ[ 4]= 1.1533 θ[ 5]= 1.8460 θ[ 6]=-2.1801 θ[ 7]= 1.1502
#    ==================================================
#
# ============================================================
# 🔄 VQE ITERATION 15
# ============================================================
# 📊 Energy = -39.72845649 Hartree
# 📊 Energy = -24929.9640 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -5.33092468 Hartree
# 📈 Energy improvement: -1.60951049 Hartree (-1009.9823 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 8
#    Parameter range: [-2.7139,  2.4282]
#    Parameter variance:  4.8421
#    RMS parameter:  2.2261
#    Parameters:
#      θ[ 0]=-2.7056 θ[ 1]=-2.7139 θ[ 2]=-2.1819 θ[ 3]= 2.4282
#      θ[ 4]= 1.4083 θ[ 5]= 2.1010 θ[ 6]=-2.4351 θ[ 7]= 1.4052
#    ==================================================
#
# ============================================================
# 🔄 VQE ITERATION 16
# ============================================================
# 📊 Energy = -42.15922912 Hartree
# 📊 Energy = -26455.2957 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -7.76169731 Hartree
# 📈 Energy improvement: 2.43077263 Hartree (1525.3317 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 8
#    Parameter range: [-2.7885,  1.8216]
#    Parameter variance:  3.1112
#    RMS parameter:  1.8302
#    Parameters:
#      θ[ 0]=-2.0990 θ[ 1]=-2.1073 θ[ 2]=-2.7885 θ[ 3]= 1.8216
#      θ[ 4]= 0.8017 θ[ 5]= 1.4944 θ[ 6]=-1.8285 θ[ 7]= 0.7986
#    ==================================================
# [SPSA] iter=  5 energy=-42.15922912 ΔE=1.745e+00 ak=7.590e-02 ck=1.275e-01
#
# ============================================================
# 🔄 VQE ITERATION 17
# ============================================================
# 📊 Energy = -41.86055363 Hartree
# 📊 Energy = -26267.8742 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -7.46302182 Hartree
# 📈 Energy improvement: -0.29867549 Hartree (-187.4216 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 8
#    Parameter range: [-2.6633,  1.9468]
#    Parameter variance:  3.3321
#    RMS parameter:  1.8896
#    Parameters:
#      θ[ 0]=-2.2242 θ[ 1]=-2.2324 θ[ 2]=-2.6633 θ[ 3]= 1.9468
#      θ[ 4]= 0.6765 θ[ 5]= 1.6196 θ[ 6]=-1.9537 θ[ 7]= 0.9238
#    ==================================================
#
# ============================================================
# 🔄 VQE ITERATION 18
# ============================================================
# 📊 Energy = -41.60642569 Hartree
# 📊 Energy = -26108.4066 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -7.20889387 Hartree
# 📈 Energy improvement: -0.25412795 Hartree (-159.4676 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 8
#    Parameter range: [-2.9136,  1.6965]
#    Parameter variance:  2.9216
#    RMS parameter:  1.7777
#    Parameters:
#      θ[ 0]=-1.9739 θ[ 1]=-1.9821 θ[ 2]=-2.9136 θ[ 3]= 1.6965
#      θ[ 4]= 0.9269 θ[ 5]= 1.3692 θ[ 6]=-1.7033 θ[ 7]= 0.6734
#    ==================================================
#
# ============================================================
# 🔄 VQE ITERATION 19
# ============================================================
# 📊 Energy = -42.10093104 Hartree
# 📊 Energy = -26418.7131 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -7.70339923 Hartree
# 📈 Energy improvement: 0.49450536 Hartree (310.3066 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 8
#    Parameter range: [-2.7194,  1.8907]
#    Parameter variance:  3.2292
#    RMS parameter:  1.8622
#    Parameters:
#      θ[ 0]=-2.1681 θ[ 1]=-2.1763 θ[ 2]=-2.7194 θ[ 3]= 1.8907
#      θ[ 4]= 0.7326 θ[ 5]= 1.5635 θ[ 6]=-1.8976 θ[ 7]= 0.8676
#    ==================================================
# [SPSA] iter=  6 energy=-42.10093104 ΔE=-5.830e-02 ak=6.801e-02 ck=1.252e-01
#
# ============================================================
# 🔄 VQE ITERATION 20
# ============================================================
# 📊 Energy = -39.27322066 Hartree
# 📊 Energy = -24644.2994 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -4.87568885 Hartree
# 📈 Energy improvement: -2.82771038 Hartree (-1774.4137 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 8
#    Parameter range: [-2.5962,  1.7674]
#    Parameter variance:  2.8952
#    RMS parameter:  1.7620
#    Parameters:
#      θ[ 0]=-2.0448 θ[ 1]=-2.0531 θ[ 2]=-2.5962 θ[ 3]= 1.7674
#      θ[ 4]= 0.6094 θ[ 5]= 1.4402 θ[ 6]=-1.7743 θ[ 7]= 0.9909
#    ==================================================
#
# ============================================================
# 🔄 VQE ITERATION 21
# ============================================================
# 📊 Energy = -44.59554566 Hartree
# 📊 Energy = -27984.1063 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -10.19801385 Hartree
# 📈 Energy improvement: 5.32232500 Hartree (3339.8068 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 8
#    Parameter range: [-2.8427,  2.0139]
#    Parameter variance:  3.5917
#    RMS parameter:  1.9650
#    Parameters:
#      θ[ 0]=-2.2913 θ[ 1]=-2.2995 θ[ 2]=-2.8427 θ[ 3]= 2.0139
#      θ[ 4]= 0.8559 θ[ 5]= 1.6867 θ[ 6]=-2.0208 θ[ 7]= 0.7444
#    ==================================================
#
# ============================================================
# 🔄 VQE ITERATION 22
# ============================================================
# 📊 Energy = -42.13409806 Hartree
# 📊 Energy = -26439.5257 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -7.73656625 Hartree
# 📈 Energy improvement: -2.46144760 Hartree (-1544.5805 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 8
#    Parameter range: [-4.0579,  3.2292]
#    Parameter variance:  8.6913
#    RMS parameter:  3.0608
#    Parameters:
#      θ[ 0]=-3.5066 θ[ 1]=-3.5148 θ[ 2]=-4.0579 θ[ 3]= 3.2292
#      θ[ 4]= 2.0711 θ[ 5]= 2.9020 θ[ 6]=-3.2360 θ[ 7]=-0.4709
#    ==================================================
# [SPSA] iter=  7 energy=-42.13409806 ΔE=3.317e-02 ak=6.198e-02 ck=1.232e-01
#
# ============================================================
# 🔄 VQE ITERATION 23
# ============================================================
# 📊 Energy = -43.87837569 Hartree
# 📊 Energy = -27534.0756 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -9.48084387 Hartree
# 📈 Energy improvement: 1.74427763 Hartree (1094.5499 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 8
#    Parameter range: [-4.1795,  3.1076]
#    Parameter variance:  8.5510
#    RMS parameter:  3.0638
#    Parameters:
#      θ[ 0]=-3.6281 θ[ 1]=-3.6364 θ[ 2]=-4.1795 θ[ 3]= 3.1076
#      θ[ 4]= 1.9496 θ[ 5]= 2.7804 θ[ 6]=-3.1145 θ[ 7]=-0.5924
#    ==================================================
#
# ============================================================
# 🔄 VQE ITERATION 24
# ============================================================
# 📊 Energy = -40.89008413 Hartree
# 📊 Energy = -25658.8958 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -6.49255232 Hartree
# 📈 Energy improvement: -2.98829155 Hartree (-1875.1798 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 8
#    Parameter range: [-3.9363,  3.3507]
#    Parameter variance:  8.8444
#    RMS parameter:  3.0627
#    Parameters:
#      θ[ 0]=-3.3850 θ[ 1]=-3.3932 θ[ 2]=-3.9363 θ[ 3]= 3.3507
#      θ[ 4]= 2.1927 θ[ 5]= 3.0235 θ[ 6]=-3.3576 θ[ 7]=-0.3493
#    ==================================================
#
# ============================================================
# 🔄 VQE ITERATION 25
# ============================================================
# 📊 Energy = -45.38412471 Hartree
# 📊 Energy = -28478.9467 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -10.98659290 Hartree
# 📈 Energy improvement: 4.49404058 Hartree (2820.0509 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 8
#    Parameter range: [-4.7608,  2.5263]
#    Parameter variance:  8.0594
#    RMS parameter:  3.1436
#    Parameters:
#      θ[ 0]=-4.2094 θ[ 1]=-4.2177 θ[ 2]=-4.7608 θ[ 3]= 2.5263
#      θ[ 4]= 1.3683 θ[ 5]= 2.1991 θ[ 6]=-2.5332 θ[ 7]=-1.1737
#    ==================================================
# [SPSA] iter=  8 energy=-45.38412471 ΔE=3.250e+00 ak=5.720e-02 ck=1.216e-01
#
# ============================================================
# 🔄 VQE ITERATION 26
# ============================================================
# 📊 Energy = -45.11729444 Hartree
# 📊 Energy = -28311.5083 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -10.71976263 Hartree
# 📈 Energy improvement: -0.26683027 Hartree (-167.4384 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 8
#    Parameter range: [-4.6407,  2.6464]
#    Parameter variance:  8.1524
#    RMS parameter:  3.1457
#    Parameters:
#      θ[ 0]=-4.3296 θ[ 1]=-4.0975 θ[ 2]=-4.6407 θ[ 3]= 2.6464
#      θ[ 4]= 1.2481 θ[ 5]= 2.3192 θ[ 6]=-2.6533 θ[ 7]=-1.0536
#    ==================================================
#
# ============================================================
# 🔄 VQE ITERATION 27
# ============================================================
# 📊 Energy = -45.06346239 Hartree
# 📊 Energy = -28277.7282 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -10.66593058 Hartree
# 📈 Energy improvement: -0.05383205 Hartree (-33.7801 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 8
#    Parameter range: [-4.8810,  2.4061]
#    Parameter variance:  7.9934
#    RMS parameter:  3.1462
#    Parameters:
#      θ[ 0]=-4.0893 θ[ 1]=-4.3378 θ[ 2]=-4.8810 θ[ 3]= 2.4061
#      θ[ 4]= 1.4884 θ[ 5]= 2.0789 θ[ 6]=-2.4130 θ[ 7]=-1.2939
#    ==================================================
#
# ============================================================
# 🔄 VQE ITERATION 28
# ============================================================
# 📊 Energy = -45.39405697 Hartree
# 📊 Energy = -28485.1793 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -10.99652515 Hartree
# 📈 Energy improvement: 0.33059458 Hartree (207.4511 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 8
#    Parameter range: [-4.7489,  2.5382]
#    Parameter variance:  8.0674
#    RMS parameter:  3.1436
#    Parameters:
#      θ[ 0]=-4.2214 θ[ 1]=-4.2057 θ[ 2]=-4.7489 θ[ 3]= 2.5382
#      θ[ 4]= 1.3563 θ[ 5]= 2.2110 θ[ 6]=-2.5451 θ[ 7]=-1.1618
#    ==================================================
# [SPSA] iter=  9 energy=-45.39405697 ΔE=9.932e-03 ak=5.328e-02 ck=1.201e-01
#
# ============================================================
# 🔄 VQE ITERATION 29
# ============================================================
# 📊 Energy = -44.41779965 Hartree
# 📊 Energy = -27872.5690 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -10.02026784 Hartree
# 📈 Energy improvement: -0.97625731 Hartree (-612.6103 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 8
#    Parameter range: [-4.8678,  2.6571]
#    Parameter variance:  8.3014
#    RMS parameter:  3.1933
#    Parameters:
#      θ[ 0]=-4.1025 θ[ 1]=-4.3246 θ[ 2]=-4.8678 θ[ 3]= 2.6571
#      θ[ 4]= 1.4752 θ[ 5]= 2.0921 θ[ 6]=-2.6640 θ[ 7]=-1.2807
#    ==================================================
#
# ============================================================
# 🔄 VQE ITERATION 30
# ============================================================
# 📊 Energy = -44.63085339 Hartree
# 📊 Energy = -28006.2622 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -10.23332158 Hartree
# 📈 Energy improvement: 0.21305374 Hartree (133.6931 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 8
#    Parameter range: [-4.6300,  2.4193]
#    Parameter variance:  7.8599
#    RMS parameter:  3.0977
#    Parameters:
#      θ[ 0]=-4.3403 θ[ 1]=-4.0869 θ[ 2]=-4.6300 θ[ 3]= 2.4193
#      θ[ 4]= 1.2374 θ[ 5]= 2.3299 θ[ 6]=-2.4262 θ[ 7]=-1.0429
#    ==================================================
#
# ============================================================
# 🔄 VQE ITERATION 31
# ============================================================
# 📊 Energy = -45.34018164 Hartree
# 📊 Energy = -28451.3720 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -10.94264983 Hartree
# 📈 Energy improvement: 0.70932825 Hartree (445.1099 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 8
#    Parameter range: [-4.7041,  2.4934]
#    Parameter variance:  7.9860
#    RMS parameter:  3.1258
#    Parameters:
#      θ[ 0]=-4.2662 θ[ 1]=-4.1609 θ[ 2]=-4.7041 θ[ 3]= 2.4934
#      θ[ 4]= 1.3115 θ[ 5]= 2.2558 θ[ 6]=-2.5003 θ[ 7]=-1.1170
#    ==================================================
# [SPSA] iter= 10 energy=-45.34018164 ΔE=-5.388e-02 ak=5.001e-02 ck=1.189e-01
#
# ============================================================
# 🔄 VQE ITERATION 32
# ============================================================
# 📊 Energy = -42.47535032 Hartree
# 📊 Energy = -26653.6646 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -8.07781851 Hartree
# 📈 Energy improvement: -2.86483132 Hartree (-1797.7074 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 8
#    Parameter range: [-4.8218,  2.3757]
#    Parameter variance:  7.6731
#    RMS parameter:  3.0883
#    Parameters:
#      θ[ 0]=-4.1485 θ[ 1]=-4.0432 θ[ 2]=-4.8218 θ[ 3]= 2.3757
#      θ[ 4]= 1.1938 θ[ 5]= 2.1381 θ[ 6]=-2.6180 θ[ 7]=-0.9993
#    ==================================================
#
# ============================================================
# 🔄 VQE ITERATION 33
# ============================================================
# 📊 Energy = -46.96538855 Hartree
# 📊 Energy = -29471.2040 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -12.56785674 Hartree
# 📈 Energy improvement: 4.49003823 Hartree (2817.5394 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 8
#    Parameter range: [-4.5863,  2.6111]
#    Parameter variance:  8.3249
#    RMS parameter:  3.1673
#    Parameters:
#      θ[ 0]=-4.3839 θ[ 1]=-4.2787 θ[ 2]=-4.5863 θ[ 3]= 2.6111
#      θ[ 4]= 1.4292 θ[ 5]= 2.3736 θ[ 6]=-2.3826 θ[ 7]=-1.2347
#    ==================================================
#
# ============================================================
# 🔄 VQE ITERATION 34
# ============================================================
# 📊 Energy = -41.57062329 Hartree
# 📊 Energy = -26085.9402 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -7.17309148 Hartree
# 📈 Energy improvement: -5.39476526 Hartree (-3385.2638 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 8
#    Parameter range: [-5.1666,  3.3938]
#    Parameter variance: 11.2384
#    RMS parameter:  3.5316
#    Parameters:
#      θ[ 0]=-5.1666 θ[ 1]=-5.0613 θ[ 2]=-3.8037 θ[ 3]= 3.3938
#      θ[ 4]= 2.2119 θ[ 5]= 3.1562 θ[ 6]=-1.5999 θ[ 7]=-2.0174
#    ==================================================
# [SPSA] iter= 11 energy=-41.57062329 ΔE=-3.770e+00 ak=4.722e-02 ck=1.177e-01
#
# ============================================================
# 🔄 VQE ITERATION 35
# ============================================================
# 📊 Energy = -41.35702302 Hartree
# 📊 Energy = -25951.9042 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -6.95949121 Hartree
# 📈 Energy improvement: -0.21360027 Hartree (-134.0361 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 8
#    Parameter range: [-5.1780,  3.2771]
#    Parameter variance: 10.8288
#    RMS parameter:  3.4826
#    Parameters:
#      θ[ 0]=-5.0499 θ[ 1]=-5.1780 θ[ 2]=-3.6870 θ[ 3]= 3.2771
#      θ[ 4]= 2.0952 θ[ 5]= 3.0395 θ[ 6]=-1.4832 θ[ 7]=-2.1341
#    ==================================================
#
# ============================================================
# 🔄 VQE ITERATION 36
# ============================================================
# 📊 Energy = -41.34301271 Hartree
# 📊 Energy = -25943.1126 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -6.94548090 Hartree
# 📈 Energy improvement: -0.01401031 Hartree (-8.7916 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 8
#    Parameter range: [-5.2833,  3.5105]
#    Parameter variance: 11.6735
#    RMS parameter:  3.5838
#    Parameters:
#      θ[ 0]=-5.2833 θ[ 1]=-4.9446 θ[ 2]=-3.9204 θ[ 3]= 3.5105
#      θ[ 4]= 2.3286 θ[ 5]= 3.2729 θ[ 6]=-1.7166 θ[ 7]=-1.9007
#    ==================================================
#
# ============================================================
# 🔄 VQE ITERATION 37
# ============================================================
# 📊 Energy = -41.57059601 Hartree
# 📊 Energy = -26085.9231 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -7.17306420 Hartree
# 📈 Energy improvement: 0.22758330 Hartree (142.8106 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 8
#    Parameter range: [-5.1639,  3.3911]
#    Parameter variance: 11.2286
#    RMS parameter:  3.5305
#    Parameters:
#      θ[ 0]=-5.1639 θ[ 1]=-5.0640 θ[ 2]=-3.8010 θ[ 3]= 3.3911
#      θ[ 4]= 2.2092 θ[ 5]= 3.1535 θ[ 6]=-1.5972 θ[ 7]=-2.0200
#    ==================================================
# [SPSA] iter= 12 energy=-41.57059601 ΔE=-2.727e-05 ak=4.481e-02 ck=1.167e-01
# [SPSA] Converged (|ΔE| < 0.001) at iter 12
# [Hybrid] Decision metrics: last=2.276e-01 ma=2.068e+00 rel_ma=4.975e-02 plateau=False
# [Hybrid] Switching to COBYLA in 5 seconds...
#
# ============================================================
# 🔄 VQE ITERATION 38
# ============================================================
# 📊 Energy = -56.34099028 Hartree
# 📊 Energy = -35354.4785 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -21.94345847 Hartree
# 📈 Energy improvement: 14.77039427 Hartree (9268.5553 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 8
#    Parameter range: [-0.0128,  0.0072]
#    Parameter variance:  0.0001
#    RMS parameter:  0.0079
#    Parameters:
#      θ[ 0]= 0.0072 θ[ 1]=-0.0010 θ[ 2]= 0.0025 θ[ 3]=-0.0111
#      θ[ 4]=-0.0098 θ[ 5]= 0.0060 θ[ 6]= 0.0043 θ[ 7]=-0.0128
#    ==================================================
#
# ============================================================
# 🔄 VQE ITERATION 39
# ============================================================
# 📊 Energy = -55.66026730 Hartree
# 📊 Energy = -34927.3187 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -21.26273549 Hartree
# 📈 Energy improvement: -0.68072298 Hartree (-427.1598 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 8
#    Parameter range: [-0.0128,  0.2072]
#    Parameter variance:  0.0049
#    RMS parameter:  0.0737
#    Parameters:
#      θ[ 0]= 0.2072 θ[ 1]=-0.0010 θ[ 2]= 0.0025 θ[ 3]=-0.0111
#      θ[ 4]=-0.0098 θ[ 5]= 0.0060 θ[ 6]= 0.0043 θ[ 7]=-0.0128
#    ==================================================
#
# ============================================================
# 🔄 VQE ITERATION 40
# ============================================================
# 📊 Energy = -56.31941602 Hartree
# 📊 Energy = -35340.9404 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -21.92188421 Hartree
# 📈 Energy improvement: 0.65914872 Hartree (413.6218 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 8
#    Parameter range: [-0.0128,  0.1990]
#    Parameter variance:  0.0045
#    RMS parameter:  0.0708
#    Parameters:
#      θ[ 0]= 0.0072 θ[ 1]= 0.1990 θ[ 2]= 0.0025 θ[ 3]=-0.0111
#      θ[ 4]=-0.0098 θ[ 5]= 0.0060 θ[ 6]= 0.0043 θ[ 7]=-0.0128
#    ==================================================
#
# ============================================================
# 🔄 VQE ITERATION 41
# ============================================================
# 📊 Energy = -55.68989350 Hartree
# 📊 Energy = -34945.9094 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -21.29236168 Hartree
# 📈 Energy improvement: -0.62952252 Hartree (-395.0310 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 8
#    Parameter range: [-0.0128,  0.2025]
#    Parameter variance:  0.0047
#    RMS parameter:  0.0720
#    Parameters:
#      θ[ 0]= 0.0072 θ[ 1]=-0.0010 θ[ 2]= 0.2025 θ[ 3]=-0.0111
#      θ[ 4]=-0.0098 θ[ 5]= 0.0060 θ[ 6]= 0.0043 θ[ 7]=-0.0128
#    ==================================================
#
# ============================================================
# 🔄 VQE ITERATION 42
# ============================================================
# 📊 Energy = -56.32037886 Hartree
# 📊 Energy = -35341.5446 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -21.92284704 Hartree
# 📈 Energy improvement: 0.63048536 Hartree (395.6352 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 8
#    Parameter range: [-0.0128,  0.1889]
#    Parameter variance:  0.0040
#    RMS parameter:  0.0671
#    Parameters:
#      θ[ 0]= 0.0072 θ[ 1]=-0.0010 θ[ 2]= 0.0025 θ[ 3]= 0.1889
#      θ[ 4]=-0.0098 θ[ 5]= 0.0060 θ[ 6]= 0.0043 θ[ 7]=-0.0128
#    ==================================================
#
# ============================================================
# 🔄 VQE ITERATION 43
# ============================================================
# 📊 Energy = -55.07216992 Hartree
# 📊 Energy = -34558.2823 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -20.67463810 Hartree
# 📈 Energy improvement: -1.24820894 Hartree (-783.2623 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 8
#    Parameter range: [-0.0128,  0.1902]
#    Parameter variance:  0.0040
#    RMS parameter:  0.0676
#    Parameters:
#      θ[ 0]= 0.0072 θ[ 1]=-0.0010 θ[ 2]= 0.0025 θ[ 3]=-0.0111
#      θ[ 4]= 0.1902 θ[ 5]= 0.0060 θ[ 6]= 0.0043 θ[ 7]=-0.0128
#    ==================================================
#
# ============================================================
# 🔄 VQE ITERATION 44
# ============================================================
# 📊 Energy = -55.62957300 Hartree
# 📊 Energy = -34908.0577 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -21.23204119 Hartree
# 📈 Energy improvement: 0.55740309 Hartree (349.7755 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 8
#    Parameter range: [-0.0128,  0.2060]
#    Parameter variance:  0.0048
#    RMS parameter:  0.0732
#    Parameters:
#      θ[ 0]= 0.0072 θ[ 1]=-0.0010 θ[ 2]= 0.0025 θ[ 3]=-0.0111
#      θ[ 4]=-0.0098 θ[ 5]= 0.2060 θ[ 6]= 0.0043 θ[ 7]=-0.0128
#    ==================================================
#
# ============================================================
# 🔄 VQE ITERATION 45
# ============================================================
# 📊 Energy = -55.64009979 Hartree
# 📊 Energy = -34914.6634 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -21.24256798 Hartree
# 📈 Energy improvement: 0.01052679 Hartree (6.6057 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 8
#    Parameter range: [-0.0128,  0.2043]
#    Parameter variance:  0.0047
#    RMS parameter:  0.0726
#    Parameters:
#      θ[ 0]= 0.0072 θ[ 1]=-0.0010 θ[ 2]= 0.0025 θ[ 3]=-0.0111
#      θ[ 4]=-0.0098 θ[ 5]= 0.0060 θ[ 6]= 0.2043 θ[ 7]=-0.0128
#    ==================================================
#
# ============================================================
# 🔄 VQE ITERATION 46
# ============================================================
# 📊 Energy = -56.24994071 Hartree
# 📊 Energy = -35297.3440 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -21.85240890 Hartree
# 📈 Energy improvement: 0.60984092 Hartree (382.6807 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 8
#    Parameter range: [-0.0111,  0.1872]
#    Parameter variance:  0.0039
#    RMS parameter:  0.0665
#    Parameters:
#      θ[ 0]= 0.0072 θ[ 1]=-0.0010 θ[ 2]= 0.0025 θ[ 3]=-0.0111
#      θ[ 4]=-0.0098 θ[ 5]= 0.0060 θ[ 6]= 0.0043 θ[ 7]= 0.1872
#    ==================================================
#
# ============================================================
# 🔄 VQE ITERATION 47
# ============================================================
# 📊 Energy = -55.37614795 Hartree
# 📊 Energy = -34749.0312 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -20.97861613 Hartree
# 📈 Energy improvement: -0.87379276 Hartree (-548.3128 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 8
#    Parameter range: [-0.1453, -0.0033]
#    Parameter variance:  0.0018
#    RMS parameter:  0.0712
#    Parameters:
#      θ[ 0]=-0.0655 θ[ 1]=-0.0033 θ[ 2]=-0.0671 θ[ 3]=-0.0134
#      θ[ 4]=-0.1453 θ[ 5]=-0.0701 θ[ 6]=-0.0706 θ[ 7]=-0.0226
#    ==================================================
#
# ============================================================
# 🔄 VQE ITERATION 48
# ============================================================
# 📊 Energy = -56.09499767 Hartree
# 📊 Energy = -35200.1159 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -21.69746585 Hartree
# 📈 Energy improvement: 0.71884972 Hartree (451.0847 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 8
#    Parameter range: [-0.0177,  0.0807]
#    Parameter variance:  0.0010
#    RMS parameter:  0.0316
#    Parameters:
#      θ[ 0]=-0.0139 θ[ 1]=-0.0017 θ[ 2]=-0.0177 θ[ 3]=-0.0118
#      θ[ 4]= 0.0807 θ[ 5]=-0.0161 θ[ 6]=-0.0175 θ[ 7]=-0.0157
#    ==================================================
#
# ============================================================
# 🔄 VQE ITERATION 49
# ============================================================
# 📊 Energy = -56.27325365 Hartree
# 📊 Energy = -35311.9731 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -21.87572184 Hartree
# 📈 Energy improvement: 0.17825599 Hartree (111.8572 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 8
#    Parameter range: [-0.0425, -0.0016]
#    Parameter variance:  0.0001
#    RMS parameter:  0.0192
#    Parameters:
#      θ[ 0]=-0.0114 θ[ 1]=-0.0016 θ[ 2]=-0.0154 θ[ 3]=-0.0117
#      θ[ 4]=-0.0425 θ[ 5]=-0.0136 θ[ 6]=-0.0150 θ[ 7]=-0.0153
#    ==================================================
#
# ============================================================
# 🔄 VQE ITERATION 50
# ============================================================
# 📊 Energy = -56.33933127 Hartree
# 📊 Energy = -35353.4374 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -21.94179946 Hartree
# 📈 Energy improvement: 0.06607762 Hartree (41.4643 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 8
#    Parameter range: [-0.0128,  0.0129]
#    Parameter variance:  0.0001
#    RMS parameter:  0.0085
#    Parameters:
#      θ[ 0]= 0.0000 θ[ 1]=-0.0010 θ[ 2]= 0.0025 θ[ 3]=-0.0111
#      θ[ 4]=-0.0098 θ[ 5]= 0.0129 θ[ 6]= 0.0043 θ[ 7]=-0.0128
#    ==================================================
#
# ============================================================
# 🔄 VQE ITERATION 51
# ============================================================
# 📊 Energy = -56.32867627 Hartree
# 📊 Energy = -35346.7513 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -21.93114446 Hartree
# 📈 Energy improvement: -0.01065500 Hartree (-6.6861 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 8
#    Parameter range: [-0.0137,  0.0195]
#    Parameter variance:  0.0002
#    RMS parameter:  0.0123
#    Parameters:
#      θ[ 0]= 0.0195 θ[ 1]=-0.0012 θ[ 2]=-0.0039 θ[ 3]=-0.0114
#      θ[ 4]=-0.0124 θ[ 5]= 0.0183 θ[ 6]=-0.0027 θ[ 7]=-0.0137
#    ==================================================
#
# ============================================================
# 🔄 VQE ITERATION 52
# ============================================================
# 📊 Energy = -56.34080574 Hartree
# 📊 Energy = -35354.3627 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -21.94327393 Hartree
# 📈 Energy improvement: 0.01212947 Hartree (7.6113 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 8
#    Parameter range: [-0.0128,  0.0072]
#    Parameter variance:  0.0001
#    RMS parameter:  0.0088
#    Parameters:
#      θ[ 0]= 0.0072 θ[ 1]=-0.0110 θ[ 2]= 0.0025 θ[ 3]=-0.0111
#      θ[ 4]=-0.0098 θ[ 5]= 0.0060 θ[ 6]= 0.0046 θ[ 7]=-0.0128
#    ==================================================
#
# ============================================================
# 🔄 VQE ITERATION 53
# ============================================================
# 📊 Energy = -56.32871748 Hartree
# 📊 Energy = -35346.7772 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -21.93118567 Hartree
# 📈 Energy improvement: -0.01208826 Hartree (-7.5855 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 8
#    Parameter range: [-0.0139,  0.0223]
#    Parameter variance:  0.0001
#    RMS parameter:  0.0120
#    Parameters:
#      θ[ 0]= 0.0090 θ[ 1]=-0.0004 θ[ 2]=-0.0052 θ[ 3]=-0.0114
#      θ[ 4]=-0.0129 θ[ 5]= 0.0072 θ[ 6]= 0.0223 θ[ 7]=-0.0139
#    ==================================================
#
# ============================================================
# 🔄 VQE ITERATION 54
# ============================================================
# 📊 Energy = -56.34078809 Hartree
# 📊 Energy = -35354.3516 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -21.94325628 Hartree
# 📈 Energy improvement: 0.01207061 Hartree (7.5744 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 8
#    Parameter range: [-0.0211,  0.0072]
#    Parameter variance:  0.0001
#    RMS parameter:  0.0101
#    Parameters:
#      θ[ 0]= 0.0072 θ[ 1]=-0.0010 θ[ 2]= 0.0028 θ[ 3]=-0.0211
#      θ[ 4]=-0.0098 θ[ 5]= 0.0060 θ[ 6]= 0.0043 θ[ 7]=-0.0128
#    ==================================================
#
# ============================================================
# 🔄 VQE ITERATION 55
# ============================================================
# 📊 Energy = -56.32718540 Hartree
# 📊 Energy = -35345.8158 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -21.92965359 Hartree
# 📈 Energy improvement: -0.01360269 Hartree (-8.5358 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 8
#    Parameter range: [-0.0156,  0.0208]
#    Parameter variance:  0.0002
#    RMS parameter:  0.0125
#    Parameters:
#      θ[ 0]= 0.0105 θ[ 1]=-0.0008 θ[ 2]= 0.0208 θ[ 3]=-0.0105
#      θ[ 4]=-0.0156 θ[ 5]= 0.0083 θ[ 6]= 0.0075 θ[ 7]=-0.0149
#    ==================================================
#
# ============================================================
# 🔄 VQE ITERATION 56
# ============================================================
# 📊 Energy = -56.34429072 Hartree
# 📊 Energy = -35356.5495 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -21.94675891 Hartree
# 📈 Energy improvement: 0.01710532 Hartree (10.7337 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 8
#    Parameter range: [-0.0227,  0.0069]
#    Parameter variance:  0.0001
#    RMS parameter:  0.0100
#    Parameters:
#      θ[ 0]= 0.0069 θ[ 1]=-0.0010 θ[ 2]= 0.0021 θ[ 3]=-0.0112
#      θ[ 4]=-0.0081 θ[ 5]= 0.0056 θ[ 6]= 0.0039 θ[ 7]=-0.0227
#    ==================================================
#
# ============================================================
# 🔄 VQE ITERATION 57
# ============================================================
# 📊 Energy = -56.34238954 Hartree
# 📊 Energy = -35355.3565 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -21.94485773 Hartree
# 📈 Energy improvement: -0.00190118 Hartree (-1.1930 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 8
#    Parameter range: [-0.0220,  0.0115]
#    Parameter variance:  0.0001
#    RMS parameter:  0.0099
#    Parameters:
#      θ[ 0]= 0.0058 θ[ 1]=-0.0009 θ[ 2]= 0.0031 θ[ 3]=-0.0110
#      θ[ 4]= 0.0115 θ[ 5]= 0.0024 θ[ 6]= 0.0025 θ[ 7]=-0.0220
#    ==================================================
#
# ============================================================
# 🔄 VQE ITERATION 58
# ============================================================
# 📊 Energy = -56.34294274 Hartree
# 📊 Energy = -35355.7037 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -21.94541093 Hartree
# 📈 Energy improvement: 0.00055320 Hartree (0.3471 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 8
#    Parameter range: [-0.0259, -0.0011]
#    Parameter variance:  0.0001
#    RMS parameter:  0.0114
#    Parameters:
#      θ[ 0]=-0.0024 θ[ 1]=-0.0011 θ[ 2]=-0.0037 θ[ 3]=-0.0111
#      θ[ 4]=-0.0121 θ[ 5]=-0.0070 θ[ 6]=-0.0060 θ[ 7]=-0.0259
#    ==================================================
#
# ============================================================
# 🔄 VQE ITERATION 59
# ============================================================
# 📊 Energy = -56.34491081 Hartree
# 📊 Energy = -35356.9386 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -21.94737899 Hartree
# 📈 Energy improvement: 0.00196806 Hartree (1.2350 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 8
#    Parameter range: [-0.0286,  0.0089]
#    Parameter variance:  0.0001
#    RMS parameter:  0.0127
#    Parameters:
#      θ[ 0]= 0.0041 θ[ 1]=-0.0058 θ[ 2]= 0.0021 θ[ 3]=-0.0159
#      θ[ 4]=-0.0077 θ[ 5]= 0.0089 θ[ 6]= 0.0043 θ[ 7]=-0.0286
#    ==================================================
#
# ============================================================
# 🔄 VQE ITERATION 60
# ============================================================
# 📊 Energy = -56.34445896 Hartree
# 📊 Energy = -35356.6551 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -21.94692714 Hartree
# 📈 Energy improvement: -0.00045185 Hartree (-0.2835 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 8
#    Parameter range: [-0.0298,  0.0080]
#    Parameter variance:  0.0002
#    RMS parameter:  0.0131
#    Parameters:
#      θ[ 0]= 0.0040 θ[ 1]=-0.0057 θ[ 2]= 0.0068 θ[ 3]=-0.0157
#      θ[ 4]=-0.0084 θ[ 5]= 0.0080 θ[ 6]= 0.0041 θ[ 7]=-0.0298
#    ==================================================
#
# ============================================================
# 🔄 VQE ITERATION 61
# ============================================================
# 📊 Energy = -56.34488541 Hartree
# 📊 Energy = -35356.9227 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -21.94735360 Hartree
# 📈 Energy improvement: 0.00042645 Hartree (0.2676 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 8
#    Parameter range: [-0.0286,  0.0093]
#    Parameter variance:  0.0001
#    RMS parameter:  0.0127
#    Parameters:
#      θ[ 0]= 0.0045 θ[ 1]=-0.0058 θ[ 2]= 0.0022 θ[ 3]=-0.0159
#      θ[ 4]=-0.0077 θ[ 5]= 0.0093 θ[ 6]= 0.0035 θ[ 7]=-0.0286
#    ==================================================
#
# ============================================================
# 🔄 VQE ITERATION 62
# ============================================================
# 📊 Energy = -56.34481121 Hartree
# 📊 Energy = -35356.8761 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -21.94727940 Hartree
# 📈 Energy improvement: -0.00007420 Hartree (-0.0466 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 8
#    Parameter range: [-0.0299,  0.0089]
#    Parameter variance:  0.0001
#    RMS parameter:  0.0131
#    Parameters:
#      θ[ 0]= 0.0052 θ[ 1]=-0.0055 θ[ 2]= 0.0014 θ[ 3]=-0.0157
#      θ[ 4]=-0.0079 θ[ 5]= 0.0089 θ[ 6]= 0.0049 θ[ 7]=-0.0299
#    ==================================================
#
# ============================================================
# 🔄 VQE ITERATION 63
# ============================================================
# 📊 Energy = -56.34431135 Hartree
# 📊 Energy = -35356.5625 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -21.94677953 Hartree
# 📈 Energy improvement: -0.00049987 Hartree (-0.3137 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 8
#    Parameter range: [-0.0286,  0.0094]
#    Parameter variance:  0.0001
#    RMS parameter:  0.0127
#    Parameters:
#      θ[ 0]= 0.0039 θ[ 1]=-0.0056 θ[ 2]= 0.0021 θ[ 3]=-0.0158
#      θ[ 4]=-0.0086 θ[ 5]= 0.0094 θ[ 6]= 0.0044 θ[ 7]=-0.0286
#    ==================================================
#
# ============================================================
# 🔄 VQE ITERATION 64
# ============================================================
# 📊 Energy = -56.34592818 Hartree
# 📊 Energy = -35357.5770 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -21.94839637 Hartree
# 📈 Energy improvement: 0.00161683 Hartree (1.0146 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 8
#    Parameter range: [-0.0289,  0.0090]
#    Parameter variance:  0.0001
#    RMS parameter:  0.0126
# ...
#      θ[ 4]=-0.0003 θ[ 5]=-0.0024 θ[ 6]=-0.0020 θ[ 7]=-0.0869
#    ==================================================
#
# ============================================================
# 🔄 VQE ITERATION 168
# ============================================================
# 📊 Energy = -56.35581598 Hartree
# 📊 Energy = -35363.7817 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -21.95828416 Hartree
# 📈 Energy improvement: 0.00000719 Hartree (0.0045 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 8
#    Parameter range: [-0.0867,  0.0006]
#    Parameter variance:  0.0008
#    RMS parameter:  0.0307
#    Parameters:
#      θ[ 0]= 0.0000 θ[ 1]=-0.0019 θ[ 2]= 0.0006 θ[ 3]=-0.0045
#      θ[ 4]=-0.0000 θ[ 5]=-0.0025 θ[ 6]=-0.0015 θ[ 7]=-0.0867
#    ==================================================
#
# ============================================================
# 🔄 VQE ITERATION 169
# ============================================================
# 📊 Energy = -56.35583496 Hartree
# 📊 Energy = -35363.7936 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -21.95830315 Hartree
# 📈 Energy improvement: 0.00001898 Hartree (0.0119 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 8
#    Parameter range: [-0.0869,  0.0004]
#    Parameter variance:  0.0008
#    RMS parameter:  0.0308
#    Parameters:
#      θ[ 0]=-0.0001 θ[ 1]=-0.0021 θ[ 2]= 0.0004 θ[ 3]=-0.0045
#      θ[ 4]= 0.0001 θ[ 5]=-0.0022 θ[ 6]=-0.0012 θ[ 7]=-0.0869
#    ==================================================
#
# ============================================================
# 🔄 VQE ITERATION 170
# ============================================================
# 📊 Energy = -56.35583789 Hartree
# 📊 Energy = -35363.7955 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -21.95830607 Hartree
# 📈 Energy improvement: 0.00000293 Hartree (0.0018 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 8
#    Parameter range: [-0.0871,  0.0005]
#    Parameter variance:  0.0008
#    RMS parameter:  0.0309
#    Parameters:
#      θ[ 0]=-0.0002 θ[ 1]=-0.0019 θ[ 2]= 0.0005 θ[ 3]=-0.0044
#      θ[ 4]= 0.0003 θ[ 5]=-0.0020 θ[ 6]=-0.0011 θ[ 7]=-0.0871
#    ==================================================
#
# ============================================================
# 🔄 VQE ITERATION 171
# ============================================================
# 📊 Energy = -56.35583713 Hartree
# 📊 Energy = -35363.7950 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -21.95830531 Hartree
# 📈 Energy improvement: -0.00000076 Hartree (-0.0005 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 8
#    Parameter range: [-0.0872,  0.0004]
#    Parameter variance:  0.0008
#    RMS parameter:  0.0309
#    Parameters:
#      θ[ 0]=-0.0002 θ[ 1]=-0.0019 θ[ 2]= 0.0004 θ[ 3]=-0.0045
#      θ[ 4]= 0.0003 θ[ 5]=-0.0021 θ[ 6]=-0.0010 θ[ 7]=-0.0872
#    ==================================================
#
# ============================================================
# 🔄 VQE ITERATION 172
# ============================================================
# 📊 Energy = -56.35583609 Hartree
# 📊 Energy = -35363.7944 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -21.95830428 Hartree
# 📈 Energy improvement: -0.00000103 Hartree (-0.0006 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 8
#    Parameter range: [-0.0871,  0.0005]
#    Parameter variance:  0.0008
#    RMS parameter:  0.0309
#    Parameters:
#      θ[ 0]=-0.0001 θ[ 1]=-0.0019 θ[ 2]= 0.0005 θ[ 3]=-0.0044
#      θ[ 4]= 0.0004 θ[ 5]=-0.0021 θ[ 6]=-0.0011 θ[ 7]=-0.0871
#    ==================================================
#
# ============================================================
# 🔄 VQE ITERATION 173
# ============================================================
# 📊 Energy = -56.35584143 Hartree
# 📊 Energy = -35363.7977 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -21.95830961 Hartree
# 📈 Energy improvement: 0.00000533 Hartree (0.0033 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 8
#    Parameter range: [-0.0871,  0.0004]
#    Parameter variance:  0.0008
#    RMS parameter:  0.0309
#    Parameters:
#      θ[ 0]=-0.0002 θ[ 1]=-0.0019 θ[ 2]= 0.0004 θ[ 3]=-0.0044
#      θ[ 4]= 0.0004 θ[ 5]=-0.0019 θ[ 6]=-0.0011 θ[ 7]=-0.0871
#    ==================================================
#
# ============================================================
# 🔄 VQE ITERATION 174
# ============================================================
# 📊 Energy = -56.35584283 Hartree
# 📊 Energy = -35363.7986 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -21.95831102 Hartree
# 📈 Energy improvement: 0.00000141 Hartree (0.0009 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 8
#    Parameter range: [-0.0870,  0.0004]
#    Parameter variance:  0.0008
#    RMS parameter:  0.0308
#    Parameters:
#      θ[ 0]=-0.0002 θ[ 1]=-0.0019 θ[ 2]= 0.0003 θ[ 3]=-0.0043
#      θ[ 4]= 0.0004 θ[ 5]=-0.0019 θ[ 6]=-0.0010 θ[ 7]=-0.0870
#    ==================================================
#
# ============================================================
# 🔄 VQE ITERATION 175
# ============================================================
# 📊 Energy = -56.35584296 Hartree
# 📊 Energy = -35363.7987 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -21.95831115 Hartree
# 📈 Energy improvement: 0.00000013 Hartree (0.0001 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 8
#    Parameter range: [-0.0870,  0.0004]
#    Parameter variance:  0.0008
#    RMS parameter:  0.0308
#    Parameters:
#      θ[ 0]=-0.0002 θ[ 1]=-0.0019 θ[ 2]= 0.0003 θ[ 3]=-0.0044
#      θ[ 4]= 0.0004 θ[ 5]=-0.0017 θ[ 6]=-0.0010 θ[ 7]=-0.0870
#    ==================================================
#
# ============================================================
# 🔄 VQE ITERATION 176
# ============================================================
# 📊 Energy = -56.35583891 Hartree
# 📊 Energy = -35363.7961 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -21.95830710 Hartree
# 📈 Energy improvement: -0.00000405 Hartree (-0.0025 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 8
#    Parameter range: [-0.0869,  0.0004]
#    Parameter variance:  0.0008
#    RMS parameter:  0.0308
#    Parameters:
#      θ[ 0]=-0.0002 θ[ 1]=-0.0018 θ[ 2]= 0.0002 θ[ 3]=-0.0044
#      θ[ 4]= 0.0004 θ[ 5]=-0.0017 θ[ 6]=-0.0010 θ[ 7]=-0.0869
#    ==================================================
#
# ============================================================
# 🔄 VQE ITERATION 177
# ============================================================
# 📊 Energy = -56.35583862 Hartree
# 📊 Energy = -35363.7959 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -21.95830681 Hartree
# 📈 Energy improvement: -0.00000029 Hartree (-0.0002 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 8
#    Parameter range: [-0.0870,  0.0004]
#    Parameter variance:  0.0008
#    RMS parameter:  0.0308
#    Parameters:
#      θ[ 0]=-0.0002 θ[ 1]=-0.0020 θ[ 2]= 0.0003 θ[ 3]=-0.0044
#      θ[ 4]= 0.0004 θ[ 5]=-0.0017 θ[ 6]=-0.0010 θ[ 7]=-0.0870
#    ==================================================
#
# ============================================================
# 🔄 VQE ITERATION 178
# ============================================================
# 📊 Energy = -56.35585320 Hartree
# 📊 Energy = -35363.8051 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -21.95832139 Hartree
# 📈 Energy improvement: 0.00001459 Hartree (0.0092 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 8
#    Parameter range: [-0.0871,  0.0003]
#    Parameter variance:  0.0008
#    RMS parameter:  0.0309
#    Parameters:
#      θ[ 0]=-0.0002 θ[ 1]=-0.0019 θ[ 2]= 0.0003 θ[ 3]=-0.0044
#      θ[ 4]= 0.0003 θ[ 5]=-0.0016 θ[ 6]=-0.0010 θ[ 7]=-0.0871
#    ==================================================
#
# ============================================================
# 🔄 VQE ITERATION 179
# ============================================================
# 📊 Energy = -56.35586947 Hartree
# 📊 Energy = -35363.8153 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -21.95833765 Hartree
# 📈 Energy improvement: 0.00001626 Hartree (0.0102 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 8
#    Parameter range: [-0.0874,  0.0002]
#    Parameter variance:  0.0008
#    RMS parameter:  0.0310
#    Parameters:
#      θ[ 0]=-0.0000 θ[ 1]=-0.0019 θ[ 2]= 0.0002 θ[ 3]=-0.0043
#      θ[ 4]= 0.0001 θ[ 5]=-0.0015 θ[ 6]=-0.0011 θ[ 7]=-0.0874
#    ==================================================
#
# ============================================================
# 🔄 VQE ITERATION 180
# ============================================================
# 📊 Energy = -56.35588672 Hartree
# 📊 Energy = -35363.8261 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -21.95835491 Hartree
# 📈 Energy improvement: 0.00001725 Hartree (0.0108 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 8
#    Parameter range: [-0.0878,  0.0001]
#    Parameter variance:  0.0008
#    RMS parameter:  0.0311
#    Parameters:
#      θ[ 0]=-0.0003 θ[ 1]=-0.0018 θ[ 2]= 0.0001 θ[ 3]=-0.0040
#      θ[ 4]=-0.0003 θ[ 5]=-0.0011 θ[ 6]=-0.0013 θ[ 7]=-0.0878
#    ==================================================
#
# ============================================================
# 🔄 VQE ITERATION 181
# ============================================================
# 📊 Energy = -56.35590022 Hartree
# 📊 Energy = -35363.8346 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -21.95836841 Hartree
# 📈 Energy improvement: 0.00001350 Hartree (0.0085 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 8
#    Parameter range: [-0.0883,  0.0002]
#    Parameter variance:  0.0008
#    RMS parameter:  0.0313
#    Parameters:
#      θ[ 0]= 0.0002 θ[ 1]=-0.0021 θ[ 2]= 0.0001 θ[ 3]=-0.0038
#      θ[ 4]=-0.0004 θ[ 5]=-0.0009 θ[ 6]=-0.0013 θ[ 7]=-0.0883
#    ==================================================
#
# ============================================================
# 🔄 VQE ITERATION 182
# ============================================================
# 📊 Energy = -56.35589013 Hartree
# 📊 Energy = -35363.8283 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -21.95835832 Hartree
# 📈 Energy improvement: -0.00001009 Hartree (-0.0063 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 8
#    Parameter range: [-0.0885,  0.0005]
#    Parameter variance:  0.0008
#    RMS parameter:  0.0313
#    Parameters:
#      θ[ 0]= 0.0005 θ[ 1]=-0.0016 θ[ 2]=-0.0003 θ[ 3]=-0.0040
#      θ[ 4]=-0.0007 θ[ 5]=-0.0009 θ[ 6]=-0.0012 θ[ 7]=-0.0885
#    ==================================================
#
# ============================================================
# 🔄 VQE ITERATION 183
# ============================================================
# 📊 Energy = -56.35590306 Hartree
# 📊 Energy = -35363.8364 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -21.95837125 Hartree
# 📈 Energy improvement: 0.00001293 Hartree (0.0081 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 8
#    Parameter range: [-0.0884,  0.0002]
#    Parameter variance:  0.0008
#    RMS parameter:  0.0313
#    Parameters:
#      θ[ 0]= 0.0002 θ[ 1]=-0.0020 θ[ 2]= 0.0001 θ[ 3]=-0.0038
#      θ[ 4]=-0.0002 θ[ 5]=-0.0009 θ[ 6]=-0.0012 θ[ 7]=-0.0884
#    ==================================================
#
# ============================================================
# 🔄 VQE ITERATION 184
# ============================================================
# 📊 Energy = -56.35589782 Hartree
# 📊 Energy = -35363.8331 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -21.95836600 Hartree
# 📈 Energy improvement: -0.00000525 Hartree (-0.0033 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 8
#    Parameter range: [-0.0885,  0.0001]
#    Parameter variance:  0.0008
#    RMS parameter:  0.0313
#    Parameters:
#      θ[ 0]= 0.0001 θ[ 1]=-0.0021 θ[ 2]= 0.0001 θ[ 3]=-0.0040
#      θ[ 4]=-0.0002 θ[ 5]=-0.0006 θ[ 6]=-0.0012 θ[ 7]=-0.0885
#    ==================================================
#
# ============================================================
# 🔄 VQE ITERATION 185
# ============================================================
# 📊 Energy = -56.35590490 Hartree
# 📊 Energy = -35363.8375 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -21.95837308 Hartree
# 📈 Energy improvement: 0.00000708 Hartree (0.0044 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 8
#    Parameter range: [-0.0885,  0.0001]
#    Parameter variance:  0.0008
#    RMS parameter:  0.0313
#    Parameters:
#      θ[ 0]= 0.0001 θ[ 1]=-0.0020 θ[ 2]= 0.0001 θ[ 3]=-0.0038
#      θ[ 4]=-0.0002 θ[ 5]=-0.0009 θ[ 6]=-0.0012 θ[ 7]=-0.0885
#    ==================================================
#
# ============================================================
# 🔄 VQE ITERATION 186
# ============================================================
# 📊 Energy = -56.35590371 Hartree
# 📊 Energy = -35363.8368 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -21.95837190 Hartree
# 📈 Energy improvement: -0.00000118 Hartree (-0.0007 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 8
#    Parameter range: [-0.0884,  0.0001]
#    Parameter variance:  0.0008
#    RMS parameter:  0.0313
#    Parameters:
#      θ[ 0]= 0.0001 θ[ 1]=-0.0020 θ[ 2]= 0.0001 θ[ 3]=-0.0037
#      θ[ 4]=-0.0003 θ[ 5]=-0.0009 θ[ 6]=-0.0011 θ[ 7]=-0.0884
#    ==================================================
#
# ============================================================
# 🔄 VQE ITERATION 187
# ============================================================
# 📊 Energy = -56.35590470 Hartree
# 📊 Energy = -35363.8374 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -21.95837289 Hartree
# 📈 Energy improvement: 0.00000099 Hartree (0.0006 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 8
#    Parameter range: [-0.0884,  0.0001]
#    Parameter variance:  0.0008
#    RMS parameter:  0.0313
#    Parameters:
#      θ[ 0]= 0.0001 θ[ 1]=-0.0020 θ[ 2]=-0.0000 θ[ 3]=-0.0038
#      θ[ 4]=-0.0002 θ[ 5]=-0.0009 θ[ 6]=-0.0012 θ[ 7]=-0.0884
#    ==================================================
# Return from COBYLA because the objective function has been evaluated MAXFUN times.
# Number of function values = 150   Least value of F = -56.35590489732589
# The corresponding X is:
# [ 1.38791937e-04 -1.98896469e-03  7.32071002e-05 -3.81499224e-03
#  -2.35780400e-04 -9.11382223e-04 -1.18024194e-03 -8.84618370e-02]
#
# [Hybrid] Completed. Total energy evaluations: 187
#
# ============================================================
# 🔄 VQE ITERATION 188
# ============================================================
# 📊 Energy = -56.35590490 Hartree
# 📊 Energy = -35363.8375 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -21.95837308 Hartree
# 📈 Energy improvement: 0.00000019 Hartree (0.0001 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 8
#    Parameter range: [-0.0885,  0.0001]
#    Parameter variance:  0.0008
#    RMS parameter:  0.0313
#    Parameters:
#      θ[ 0]= 0.0001 θ[ 1]=-0.0020 θ[ 2]= 0.0001 θ[ 3]=-0.0038
#      θ[ 4]=-0.0002 θ[ 5]=-0.0009 θ[ 6]=-0.0012 θ[ 7]=-0.0885
#    ==================================================
#
# 🏁 VQE optimization complete
#    Final energy: -56.3559048973 Hartree
#    Total improvement: 0.014915 Hartree
#    Objective evaluations: 188
#    Effective circuit evaluations: 188
#
# [Hybrid VQE] Final energy: -56.35590489732589

# %% [markdown]
# ### Cell 7 Description: Hybrid VQE with ZNE (Richardson)
# Repeats the hybrid optimization but wraps each objective evaluation with a Zero Noise Extrapolation plugin using scaling factors [1,3,5] and Richardson extrapolation. On an ideal simulator these factors yield identical energies; history helps when executing on noisy backends.

# %%
# === 7. Hybrid VQE + ZNE (Richardson) ===
from vqeskeletal import ZNEDenoiserPlugin, VQE, HybridSPSAThenCOBYLA

class DirectHam:
    def __init__(self, sysd): self.sysd = sysd
    def get_hamiltonian(self): return self.sysd

zne_plugin = ZNEDenoiserPlugin(noise_factors=[1.0, 3.0, 5.0], extrapolation_method='richardson', verbose=True)
# Reuse hybrid optimizer settings
hybrid_opt2 = HybridSPSAThenCOBYLA(spsa_iters=40, switch_tol=5e-3, min_spsa=12, force_cobyla=True, verbose=True)

vqe_hybrid_zne = VQE(uccsd_ansatz, DirectHam(ham_system), hybrid_opt2, zne_plugin, verbose=True)
init_hybrid_zne = uccsd_ansatz.get_initial_parameters('random_small')
params_hybrid_zne, energy_hybrid_zne = vqe_hybrid_zne.run(init_hybrid_zne)
print('\n[Hybrid+ZNE VQE] Final (extrapolated) energy:', energy_hybrid_zne)
print('\nZNE analysis:', zne_plugin.get_zne_analysis())
# Out:
# Streaming output truncated to the last 5000 lines.
# 📊 Energy = -27993.9299 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -10.21366883 Hartree
# 📈 Energy improvement: 0.53008345 Hartree (332.6321 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 8
#    Parameter range: [-5.8663,  2.9655]
#    Parameter variance:  9.6812
#    RMS parameter:  3.5333
#    Parameters:
#      θ[ 0]= 1.9181 θ[ 1]=-4.5392 θ[ 2]=-3.2237 θ[ 3]=-2.2409
#      θ[ 4]= 1.4489 θ[ 5]=-3.8560 θ[ 6]= 2.9655 θ[ 7]=-5.8663
#    ==================================================
# [ZNE] Raw noisy values @ factors [1.0, 3.0, 5.0]: [-43.6224132685156, -43.6224132685156, -43.6224132685156]
# 📊 ZNE Applied:
#    Noisy values: [-43.62241327 -43.62241327 -43.62241327]
#    Noise factors: [1.0, 3.0, 5.0]
#    Extrapolated: -43.62241327
#    Improvement: 0.00000000
#
# ============================================================
# 🔄 VQE ITERATION 39
# ============================================================
# 📊 Energy = -43.62241327 Hartree
# 📊 Energy = -27373.4569 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -9.22488146 Hartree
# 📈 Energy improvement: -0.98878737 Hartree (-620.4730 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 8
#    Parameter range: [-6.0978,  2.7339]
#    Parameter variance:  9.3241
#    RMS parameter:  3.5395
#    Parameters:
#      θ[ 0]= 1.6866 θ[ 1]=-4.3077 θ[ 2]=-3.4552 θ[ 3]=-2.0094
#      θ[ 4]= 1.2174 θ[ 5]=-4.0875 θ[ 6]= 2.7339 θ[ 7]=-6.0978
#    ==================================================
# [ZNE] Raw noisy values @ factors [1.0, 3.0, 5.0]: [-45.06214860378368, -45.06214860378368, -45.06214860378368]
# 📊 ZNE Applied:
#    Noisy values: [-45.0621486 -45.0621486 -45.0621486]
#    Noise factors: [1.0, 3.0, 5.0]
#    Extrapolated: -45.06214860
#    Improvement: 0.00000000
#
# ============================================================
# 🔄 VQE ITERATION 40
# ============================================================
# 📊 Energy = -45.06214860 Hartree
# 📊 Energy = -28276.9038 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -10.66461679 Hartree
# 📈 Energy improvement: 1.43973534 Hartree (903.4469 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 8
#    Parameter range: [-5.7997,  3.0321]
#    Parameter variance:  9.7988
#    RMS parameter:  3.5343
#    Parameters:
#      θ[ 0]= 1.9847 θ[ 1]=-4.6058 θ[ 2]=-3.1571 θ[ 3]=-2.3075
#      θ[ 4]= 1.5155 θ[ 5]=-3.7894 θ[ 6]= 3.0321 θ[ 7]=-5.7997
#    ==================================================
# [SPSA] iter= 13 energy=-45.06214860 ΔE=9.810e-01 ak=4.270e-02 ck=1.158e-01
# [ZNE] Raw noisy values @ factors [1.0, 3.0, 5.0]: [-46.34143404097173, -46.34143404097173, -46.34143404097173]
# 📊 ZNE Applied:
#    Noisy values: [-46.34143404 -46.34143404 -46.34143404]
#    Noise factors: [1.0, 3.0, 5.0]
#    Extrapolated: -46.34143404
#    Improvement: 0.00000000
#
# ============================================================
# 🔄 VQE ITERATION 41
# ============================================================
# 📊 Energy = -46.34143404 Hartree
# 📊 Energy = -29079.6669 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -11.94390223 Hartree
# 📈 Energy improvement: 1.27928544 Hartree (802.7631 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 8
#    Parameter range: [-5.6848,  3.1470]
#    Parameter variance: 10.0192
#    RMS parameter:  3.5393
#    Parameters:
#      θ[ 0]= 2.0996 θ[ 1]=-4.4909 θ[ 2]=-3.2720 θ[ 3]=-2.1926
#      θ[ 4]= 1.6304 θ[ 5]=-3.9043 θ[ 6]= 3.1470 θ[ 7]=-5.6848
#    ==================================================
# [ZNE] Raw noisy values @ factors [1.0, 3.0, 5.0]: [-43.73402469798964, -43.73402469798964, -43.73402469798964]
# 📊 ZNE Applied:
#    Noisy values: [-43.7340247 -43.7340247 -43.7340247]
#    Noise factors: [1.0, 3.0, 5.0]
#    Extrapolated: -43.73402470
#    Improvement: 0.00000000
#
# ============================================================
# 🔄 VQE ITERATION 42
# ============================================================
# 📊 Energy = -43.73402470 Hartree
# 📊 Energy = -27443.4941 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -9.33649288 Hartree
# 📈 Energy improvement: -2.60740934 Hartree (-1636.1728 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 8
#    Parameter range: [-5.9146,  2.9172]
#    Parameter variance:  9.5982
#    RMS parameter:  3.5331
#    Parameters:
#      θ[ 0]= 1.8698 θ[ 1]=-4.7207 θ[ 2]=-3.0422 θ[ 3]=-2.4224
#      θ[ 4]= 1.4006 θ[ 5]=-3.6745 θ[ 6]= 2.9172 θ[ 7]=-5.9146
#    ==================================================
# [ZNE] Raw noisy values @ factors [1.0, 3.0, 5.0]: [-48.028473395791906, -48.028473395791906, -48.028473395791906]
# 📊 ZNE Applied:
#    Noisy values: [-48.0284734 -48.0284734 -48.0284734]
#    Noise factors: [1.0, 3.0, 5.0]
#    Extrapolated: -48.02847340
#    Improvement: 0.00000000
#
# ============================================================
# 🔄 VQE ITERATION 43
# ============================================================
# 📊 Energy = -48.02847340 Hartree
# 📊 Energy = -30138.2993 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -13.63094158 Hartree
# 📈 Energy improvement: 4.29444870 Hartree (2694.8052 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 8
#    Parameter range: [-5.3364,  3.4954]
#    Parameter variance: 10.8088
#    RMS parameter:  3.5770
#    Parameters:
#      θ[ 0]= 2.4481 θ[ 1]=-4.1425 θ[ 2]=-3.6205 θ[ 3]=-1.8442
#      θ[ 4]= 1.9789 θ[ 5]=-4.2528 θ[ 6]= 3.4954 θ[ 7]=-5.3364
#    ==================================================
# [SPSA] iter= 14 energy=-48.02847340 ΔE=2.966e+00 ak=4.084e-02 ck=1.149e-01
# [ZNE] Raw noisy values @ factors [1.0, 3.0, 5.0]: [-45.893161334198595, -45.893161334198595, -45.893161334198595]
# 📊 ZNE Applied:
#    Noisy values: [-45.89316133 -45.89316133 -45.89316133]
#    Noise factors: [1.0, 3.0, 5.0]
#    Extrapolated: -45.89316133
#    Improvement: 0.00000000
#
# ============================================================
# 🔄 VQE ITERATION 44
# ============================================================
# 📊 Energy = -45.89316133 Hartree
# 📊 Energy = -28798.3718 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -11.49562952 Hartree
# 📈 Energy improvement: -2.13531206 Hartree (-1339.9275 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 8
#    Parameter range: [-5.4505,  3.6095]
#    Parameter variance: 10.9201
#    RMS parameter:  3.6038
#    Parameters:
#      θ[ 0]= 2.3340 θ[ 1]=-4.0283 θ[ 2]=-3.7346 θ[ 3]=-1.7301
#      θ[ 4]= 1.8648 θ[ 5]=-4.3669 θ[ 6]= 3.6095 θ[ 7]=-5.4505
#    ==================================================
# [ZNE] Raw noisy values @ factors [1.0, 3.0, 5.0]: [-50.143958515635696, -50.143958515635696, -50.143958515635696]
# 📊 ZNE Applied:
#    Noisy values: [-50.14395852 -50.14395852 -50.14395852]
#    Noise factors: [1.0, 3.0, 5.0]
#    Extrapolated: -50.14395852
#    Improvement: 0.00000000
#
# ============================================================
# 🔄 VQE ITERATION 45
# ============================================================
# 📊 Energy = -50.14395852 Hartree
# 📊 Energy = -31465.7853 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -15.74642670 Hartree
# 📈 Energy improvement: 4.25079718 Hartree (2667.4135 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 8
#    Parameter range: [-5.2223,  3.3813]
#    Parameter variance: 10.7220
#    RMS parameter:  3.5536
#    Parameters:
#      θ[ 0]= 2.5622 θ[ 1]=-4.2566 θ[ 2]=-3.5064 θ[ 3]=-1.9583
#      θ[ 4]= 2.0930 θ[ 5]=-4.1387 θ[ 6]= 3.3813 θ[ 7]=-5.2223
#    ==================================================
# [ZNE] Raw noisy values @ factors [1.0, 3.0, 5.0]: [-54.5371823022805, -54.5371823022805, -54.5371823022805]
# 📊 ZNE Applied:
#    Noisy values: [-54.5371823 -54.5371823 -54.5371823]
#    Noise factors: [1.0, 3.0, 5.0]
#    Extrapolated: -54.53718230
#    Improvement: 0.00000000
#
# ============================================================
# 🔄 VQE ITERATION 46
# ============================================================
# 📊 Energy = -54.53718230 Hartree
# 📊 Energy = -34222.5727 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -20.13965049 Hartree
# 📈 Energy improvement: 4.39322379 Hartree (2756.7875 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 8
#    Parameter range: [-4.8722,  3.1778]
#    Parameter variance: 10.6745
#    RMS parameter:  3.4899
#    Parameters:
#      θ[ 0]= 3.1778 θ[ 1]=-4.8722 θ[ 2]=-2.8907 θ[ 3]=-2.5739
#      θ[ 4]= 2.7086 θ[ 5]=-3.5230 θ[ 6]= 2.7657 θ[ 7]=-4.6066
#    ==================================================
# [SPSA] iter= 15 energy=-54.53718230 ΔE=6.509e+00 ak=3.918e-02 ck=1.141e-01
# [ZNE] Raw noisy values @ factors [1.0, 3.0, 5.0]: [-55.36569073653862, -55.36569073653862, -55.36569073653862]
# 📊 ZNE Applied:
#    Noisy values: [-55.36569074 -55.36569074 -55.36569074]
#    Noise factors: [1.0, 3.0, 5.0]
#    Extrapolated: -55.36569074
#    Improvement: 0.00000000
#
# ============================================================
# 🔄 VQE ITERATION 47
# ============================================================
# 📊 Energy = -55.36569074 Hartree
# 📊 Energy = -34742.4692 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -20.96815892 Hartree
# 📈 Energy improvement: 0.82850843 Hartree (519.8965 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 8
#    Parameter range: [-4.7588,  3.2911]
#    Parameter variance: 10.8803
#    RMS parameter:  3.5193
#    Parameters:
#      θ[ 0]= 3.2911 θ[ 1]=-4.7588 θ[ 2]=-3.0041 θ[ 3]=-2.4605
#      θ[ 4]= 2.5952 θ[ 5]=-3.6364 θ[ 6]= 2.8791 θ[ 7]=-4.7200
#    ==================================================
# [ZNE] Raw noisy values @ factors [1.0, 3.0, 5.0]: [-52.82247747533717, -52.82247747533717, -52.82247747533717]
# 📊 ZNE Applied:
#    Noisy values: [-52.82247748 -52.82247748 -52.82247748]
#    Noise factors: [1.0, 3.0, 5.0]
#    Extrapolated: -52.82247748
#    Improvement: 0.00000000
#
# ============================================================
# 🔄 VQE ITERATION 48
# ============================================================
# 📊 Energy = -52.82247748 Hartree
# 📊 Energy = -33146.5800 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -18.42494566 Hartree
# 📈 Energy improvement: -2.54321326 Hartree (-1595.8892 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 8
#    Parameter range: [-4.9855,  3.0644]
#    Parameter variance: 10.4943
#    RMS parameter:  3.4640
#    Parameters:
#      θ[ 0]= 3.0644 θ[ 1]=-4.9855 θ[ 2]=-2.7774 θ[ 3]=-2.6873
#      θ[ 4]= 2.8219 θ[ 5]=-3.4097 θ[ 6]= 2.6523 θ[ 7]=-4.4933
#    ==================================================
# [ZNE] Raw noisy values @ factors [1.0, 3.0, 5.0]: [-53.088531615113936, -53.088531615113936, -53.088531615113936]
# 📊 ZNE Applied:
#    Noisy values: [-53.08853162 -53.08853162 -53.08853162]
#    Noise factors: [1.0, 3.0, 5.0]
#    Extrapolated: -53.08853162
#    Improvement: 0.00000000
#
# ============================================================
# 🔄 VQE ITERATION 49
# ============================================================
# 📊 Energy = -53.08853162 Hartree
# 📊 Energy = -33313.5314 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -18.69099980 Hartree
# 📈 Energy improvement: 0.26605414 Hartree (166.9514 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 8
#    Parameter range: [-5.0293,  3.6005]
#    Parameter variance: 11.5727
#    RMS parameter:  3.6163
#    Parameters:
#      θ[ 0]= 3.6005 θ[ 1]=-4.4495 θ[ 2]=-3.3134 θ[ 3]=-2.1512
#      θ[ 4]= 2.2859 θ[ 5]=-3.9457 θ[ 6]= 3.1884 θ[ 7]=-5.0293
#    ==================================================
# [SPSA] iter= 16 energy=-53.08853162 ΔE=-1.449e+00 ak=3.768e-02 ck=1.134e-01
# [ZNE] Raw noisy values @ factors [1.0, 3.0, 5.0]: [-53.15015804380362, -53.15015804380362, -53.15015804380362]
# 📊 ZNE Applied:
#    Noisy values: [-53.15015804 -53.15015804 -53.15015804]
#    Noise factors: [1.0, 3.0, 5.0]
#    Extrapolated: -53.15015804
#    Improvement: 0.00000000
#
# ============================================================
# 🔄 VQE ITERATION 50
# ============================================================
# 📊 Energy = -53.15015804 Hartree
# 📊 Energy = -33352.2025 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -18.75262623 Hartree
# 📈 Energy improvement: 0.06162643 Hartree (38.6711 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 8
#    Parameter range: [-4.9167,  3.4878]
#    Parameter variance: 11.4659
#    RMS parameter:  3.6112
#    Parameters:
#      θ[ 0]= 3.4878 θ[ 1]=-4.5622 θ[ 2]=-3.4261 θ[ 3]=-2.2639
#      θ[ 4]= 2.1732 θ[ 5]=-3.8331 θ[ 6]= 3.3011 θ[ 7]=-4.9167
#    ==================================================
# [ZNE] Raw noisy values @ factors [1.0, 3.0, 5.0]: [-53.341219344644344, -53.341219344644344, -53.341219344644344]
# 📊 ZNE Applied:
#    Noisy values: [-53.34121934 -53.34121934 -53.34121934]
#    Noise factors: [1.0, 3.0, 5.0]
#    Extrapolated: -53.34121934
#    Improvement: 0.00000000
#
# ============================================================
# 🔄 VQE ITERATION 51
# ============================================================
# 📊 Energy = -53.34121934 Hartree
# 📊 Energy = -33472.0952 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -18.94368753 Hartree
# 📈 Energy improvement: 0.19106130 Hartree (119.8927 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 8
#    Parameter range: [-5.1420,  3.7131]
#    Parameter variance: 11.7033
#    RMS parameter:  3.6249
#    Parameters:
#      θ[ 0]= 3.7131 θ[ 1]=-4.3368 θ[ 2]=-3.2008 θ[ 3]=-2.0385
#      θ[ 4]= 2.3986 θ[ 5]=-4.0584 θ[ 6]= 3.0757 θ[ 7]=-5.1420
#    ==================================================
# [ZNE] Raw noisy values @ factors [1.0, 3.0, 5.0]: [-53.1154017324713, -53.1154017324713, -53.1154017324713]
# 📊 ZNE Applied:
#    Noisy values: [-53.11540173 -53.11540173 -53.11540173]
#    Noise factors: [1.0, 3.0, 5.0]
#    Extrapolated: -53.11540173
#    Improvement: 0.00000000
#
# ============================================================
# 🔄 VQE ITERATION 52
# ============================================================
# 📊 Energy = -53.11540173 Hartree
# 📊 Energy = -33330.3926 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -18.71786992 Hartree
# 📈 Energy improvement: -0.22581761 Hartree (-141.7026 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 8
#    Parameter range: [-5.0601,  3.6313]
#    Parameter variance: 11.6060
#    RMS parameter:  3.6183
#    Parameters:
#      θ[ 0]= 3.6313 θ[ 1]=-4.4187 θ[ 2]=-3.2826 θ[ 3]=-2.1204
#      θ[ 4]= 2.3167 θ[ 5]=-3.9765 θ[ 6]= 3.1576 θ[ 7]=-5.0601
#    ==================================================
# [SPSA] iter= 17 energy=-53.11540173 ΔE=2.687e-02 ak=3.633e-02 ck=1.127e-01
# [ZNE] Raw noisy values @ factors [1.0, 3.0, 5.0]: [-53.55983424685804, -53.55983424685804, -53.55983424685804]
# 📊 ZNE Applied:
#    Noisy values: [-53.55983425 -53.55983425 -53.55983425]
#    Noise factors: [1.0, 3.0, 5.0]
#    Extrapolated: -53.55983425
#    Improvement: 0.00000000
#
# ============================================================
# 🔄 VQE ITERATION 53
# ============================================================
# 📊 Energy = -53.55983425 Hartree
# 📊 Energy = -33609.2780 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -19.16230243 Hartree
# 📈 Energy improvement: 0.44443251 Hartree (278.8854 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 8
#    Parameter range: [-4.9481,  3.5193]
#    Parameter variance: 11.8458
#    RMS parameter:  3.6608
#    Parameters:
#      θ[ 0]= 3.5193 θ[ 1]=-4.5307 θ[ 2]=-3.3947 θ[ 3]=-2.2324
#      θ[ 4]= 2.4287 θ[ 5]=-4.0886 θ[ 6]= 3.2696 θ[ 7]=-4.9481
#    ==================================================
# [ZNE] Raw noisy values @ factors [1.0, 3.0, 5.0]: [-52.37464537470803, -52.37464537470803, -52.37464537470803]
# 📊 ZNE Applied:
#    Noisy values: [-52.37464537 -52.37464537 -52.37464537]
#    Noise factors: [1.0, 3.0, 5.0]
#    Extrapolated: -52.37464537
#    Improvement: 0.00000000
#
# ============================================================
# 🔄 VQE ITERATION 54
# ============================================================
# 📊 Energy = -52.37464537 Hartree
# 📊 Energy = -32865.5613 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -17.97711356 Hartree
# 📈 Energy improvement: -1.18518887 Hartree (-743.7167 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 8
#    Parameter range: [-5.1722,  3.7433]
#    Parameter variance: 11.3898
#    RMS parameter:  3.5789
#    Parameters:
#      θ[ 0]= 3.7433 θ[ 1]=-4.3067 θ[ 2]=-3.1706 θ[ 3]=-2.0084
#      θ[ 4]= 2.2047 θ[ 5]=-3.8645 θ[ 6]= 3.0456 θ[ 7]=-5.1722
#    ==================================================
# [ZNE] Raw noisy values @ factors [1.0, 3.0, 5.0]: [-53.614149979865765, -53.614149979865765, -53.614149979865765]
# 📊 ZNE Applied:
#    Noisy values: [-53.61414998 -53.61414998 -53.61414998]
#    Noise factors: [1.0, 3.0, 5.0]
#    Extrapolated: -53.61414998
#    Improvement: 0.00000000
#
# ============================================================
# 🔄 VQE ITERATION 55
# ============================================================
# 📊 Energy = -53.61414998 Hartree
# 📊 Energy = -33643.3616 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -19.21661817 Hartree
# 📈 Energy improvement: 1.23950461 Hartree (777.8003 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 8
#    Parameter range: [-4.8744,  3.4456]
#    Parameter variance: 12.0164
#    RMS parameter:  3.6903
#    Parameters:
#      θ[ 0]= 3.4456 θ[ 1]=-4.6044 θ[ 2]=-3.4683 θ[ 3]=-2.3061
#      θ[ 4]= 2.5024 θ[ 5]=-4.1622 θ[ 6]= 3.3433 θ[ 7]=-4.8744
#    ==================================================
# [SPSA] iter= 18 energy=-53.61414998 ΔE=4.987e-01 ak=3.510e-02 ck=1.120e-01
# [ZNE] Raw noisy values @ factors [1.0, 3.0, 5.0]: [-53.43840871729943, -53.43840871729943, -53.43840871729943]
# 📊 ZNE Applied:
#    Noisy values: [-53.43840872 -53.43840872 -53.43840872]
#    Noise factors: [1.0, 3.0, 5.0]
#    Extrapolated: -53.43840872
#    Improvement: 0.00000000
#
# ============================================================
# 🔄 VQE ITERATION 56
# ============================================================
# 📊 Energy = -53.43840872 Hartree
# 📊 Energy = -33533.0824 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -19.04087690 Hartree
# 📈 Energy improvement: -0.17574126 Hartree (-110.2792 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 8
#    Parameter range: [-4.9859,  3.5570]
#    Parameter variance: 12.4730
#    RMS parameter:  3.7423
#    Parameters:
#      θ[ 0]= 3.5570 θ[ 1]=-4.7158 θ[ 2]=-3.3569 θ[ 3]=-2.4175
#      θ[ 4]= 2.6138 θ[ 5]=-4.0508 θ[ 6]= 3.4547 θ[ 7]=-4.9859
#    ==================================================
# [ZNE] Raw noisy values @ factors [1.0, 3.0, 5.0]: [-52.64459670303682, -52.64459670303682, -52.64459670303682]
# 📊 ZNE Applied:
#    Noisy values: [-52.6445967 -52.6445967 -52.6445967]
#    Noise factors: [1.0, 3.0, 5.0]
#    Extrapolated: -52.64459670
#    Improvement: 0.00000000
#
# ============================================================
# 🔄 VQE ITERATION 57
# ============================================================
# 📊 Energy = -52.64459670 Hartree
# 📊 Energy = -33034.9582 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -18.24706489 Hartree
# 📈 Energy improvement: -0.79381201 Hartree (-498.1242 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 8
#    Parameter range: [-4.7630,  3.3342]
#    Parameter variance: 11.5830
#    RMS parameter:  3.6409
#    Parameters:
#      θ[ 0]= 3.3342 θ[ 1]=-4.4930 θ[ 2]=-3.5797 θ[ 3]=-2.1947
#      θ[ 4]= 2.3910 θ[ 5]=-4.2736 θ[ 6]= 3.2319 θ[ 7]=-4.7630
#    ==================================================
# [ZNE] Raw noisy values @ factors [1.0, 3.0, 5.0]: [-53.362177267073086, -53.362177267073086, -53.362177267073086]
# 📊 ZNE Applied:
#    Noisy values: [-53.36217727 -53.36217727 -53.36217727]
#    Noise factors: [1.0, 3.0, 5.0]
#    Extrapolated: -53.36217727
#    Improvement: 0.00000000
#
# ============================================================
# 🔄 VQE ITERATION 58
# ============================================================
# 📊 Energy = -53.36217727 Hartree
# 📊 Energy = -33485.2465 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -18.96464545 Hartree
# 📈 Energy improvement: 0.71758056 Hartree (450.2883 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 8
#    Parameter range: [-4.9955,  3.5666]
#    Parameter variance: 12.5136
#    RMS parameter:  3.7469
#    Parameters:
#      θ[ 0]= 3.5666 θ[ 1]=-4.7254 θ[ 2]=-3.3473 θ[ 3]=-2.4271
#      θ[ 4]= 2.6234 θ[ 5]=-4.0412 θ[ 6]= 3.4643 θ[ 7]=-4.9955
#    ==================================================
# [SPSA] iter= 19 energy=-53.36217727 ΔE=-2.520e-01 ak=3.398e-02 ck=1.114e-01
# [ZNE] Raw noisy values @ factors [1.0, 3.0, 5.0]: [-51.45277294065613, -51.45277294065613, -51.45277294065613]
# 📊 ZNE Applied:
#    Noisy values: [-51.45277294 -51.45277294 -51.45277294]
#    Noise factors: [1.0, 3.0, 5.0]
#    Extrapolated: -51.45277294
#    Improvement: 0.00000000
#
# ============================================================
# 🔄 VQE ITERATION 59
# ============================================================
# 📊 Energy = -51.45277294 Hartree
# 📊 Energy = -32287.0781 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -17.05524113 Hartree
# 📈 Energy improvement: -1.90940433 Hartree (-1198.1684 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 8
#    Parameter range: [-5.1063,  3.6775]
#    Parameter variance: 12.7229
#    RMS parameter:  3.7933
#    Parameters:
#      θ[ 0]= 3.6775 θ[ 1]=-4.8363 θ[ 2]=-3.4581 θ[ 3]=-2.3163
#      θ[ 4]= 2.5126 θ[ 5]=-4.1520 θ[ 6]= 3.3535 θ[ 7]=-5.1063
#    ==================================================
# [ZNE] Raw noisy values @ factors [1.0, 3.0, 5.0]: [-54.704152164749125, -54.704152164749125, -54.704152164749125]
# 📊 ZNE Applied:
#    Noisy values: [-54.70415216 -54.70415216 -54.70415216]
#    Noise factors: [1.0, 3.0, 5.0]
#    Extrapolated: -54.70415216
#    Improvement: 0.00000000
#
# ============================================================
# 🔄 VQE ITERATION 60
# ============================================================
# 📊 Energy = -54.70415216 Hartree
# 📊 Energy = -34327.3478 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -20.30662035 Hartree
# 📈 Energy improvement: 3.25137922 Hartree (2040.2697 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 8
#    Parameter range: [-4.8847,  3.5752]
#    Parameter variance: 12.3228
#    RMS parameter:  3.7034
#    Parameters:
#      θ[ 0]= 3.4558 θ[ 1]=-4.6146 θ[ 2]=-3.2364 θ[ 3]=-2.5380
#      θ[ 4]= 2.7343 θ[ 5]=-3.9303 θ[ 6]= 3.5752 θ[ 7]=-4.8847
#    ==================================================
# [ZNE] Raw noisy values @ factors [1.0, 3.0, 5.0]: [-51.715729149050546, -51.715729149050546, -51.715729149050546]
# 📊 ZNE Applied:
#    Noisy values: [-51.71572915 -51.71572915 -51.71572915]
#    Noise factors: [1.0, 3.0, 5.0]
#    Extrapolated: -51.71572915
#    Improvement: 0.00000000
#
# ============================================================
# 🔄 VQE ITERATION 61
# ============================================================
# 📊 Energy = -51.71572915 Hartree
# 📊 Energy = -32452.0855 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -17.31819734 Hartree
# 📈 Energy improvement: -2.98842302 Hartree (-1875.2623 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 8
#    Parameter range: [-4.5123,  3.9476]
#    Parameter variance: 11.8165
#    RMS parameter:  3.5782
#    Parameters:
#      θ[ 0]= 3.0834 θ[ 1]=-4.2422 θ[ 2]=-2.8640 θ[ 3]=-2.9104
#      θ[ 4]= 3.1067 θ[ 5]=-3.5579 θ[ 6]= 3.9476 θ[ 7]=-4.5123
#    ==================================================
# [SPSA] iter= 20 energy=-51.71572915 ΔE=-1.646e+00 ak=3.295e-02 ck=1.108e-01
# [ZNE] Raw noisy values @ factors [1.0, 3.0, 5.0]: [-51.85761090861256, -51.85761090861256, -51.85761090861256]
# 📊 ZNE Applied:
#    Noisy values: [-51.85761091 -51.85761091 -51.85761091]
#    Noise factors: [1.0, 3.0, 5.0]
#    Extrapolated: -51.85761091
#    Improvement: 0.00000000
#
# ============================================================
# 🔄 VQE ITERATION 62
# ============================================================
# 📊 Energy = -51.85761091 Hartree
# 📊 Energy = -32541.1176 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -17.46007910 Hartree
# 📈 Energy improvement: 0.14188176 Hartree (89.0321 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 8
#    Parameter range: [-4.4020,  4.0579]
#    Parameter variance: 12.0288
#    RMS parameter:  3.6078
#    Parameters:
#      θ[ 0]= 3.1937 θ[ 1]=-4.3525 θ[ 2]=-2.7537 θ[ 3]=-3.0207
#      θ[ 4]= 2.9964 θ[ 5]=-3.6682 θ[ 6]= 4.0579 θ[ 7]=-4.4020
#    ==================================================
# [ZNE] Raw noisy values @ factors [1.0, 3.0, 5.0]: [-52.01324881413686, -52.01324881413686, -52.01324881413686]
# 📊 ZNE Applied:
#    Noisy values: [-52.01324881 -52.01324881 -52.01324881]
#    Noise factors: [1.0, 3.0, 5.0]
#    Extrapolated: -52.01324881
#    Improvement: 0.00000000
#
# ============================================================
# 🔄 VQE ITERATION 63
# ============================================================
# 📊 Energy = -52.01324881 Hartree
# 📊 Energy = -32638.7818 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -17.61571700 Hartree
# 📈 Energy improvement: 0.15563791 Hartree (97.6642 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 8
#    Parameter range: [-4.6226,  3.8373]
#    Parameter variance: 11.6285
#    RMS parameter:  3.5519
#    Parameters:
#      θ[ 0]= 2.9731 θ[ 1]=-4.1319 θ[ 2]=-2.9743 θ[ 3]=-2.8001
#      θ[ 4]= 3.2170 θ[ 5]=-3.4477 θ[ 6]= 3.8373 θ[ 7]=-4.6226
#    ==================================================
# [ZNE] Raw noisy values @ factors [1.0, 3.0, 5.0]: [-51.75214175659476, -51.75214175659476, -51.75214175659476]
# 📊 ZNE Applied:
#    Noisy values: [-51.75214176 -51.75214176 -51.75214176]
#    Noise factors: [1.0, 3.0, 5.0]
#    Extrapolated: -51.75214176
#    Improvement: 0.00000000
#
# ============================================================
# 🔄 VQE ITERATION 64
# ============================================================
# 📊 Energy = -51.75214176 Hartree
# 📊 Energy = -32474.9347 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -17.35460994 Hartree
# 📈 Energy improvement: -0.26110706 Hartree (-163.8470 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 8
#    Parameter range: [-4.5348,  3.9250]
#    Parameter variance: 11.7761
#    RMS parameter:  3.5726
#    Parameters:
#      θ[ 0]= 3.0608 θ[ 1]=-4.2196 θ[ 2]=-2.8866 θ[ 3]=-2.8878
#      θ[ 4]= 3.1292 θ[ 5]=-3.5354 θ[ 6]= 3.9250 θ[ 7]=-4.5348
#    ==================================================
# [SPSA] iter= 21 energy=-51.75214176 ΔE=3.641e-02 ak=3.199e-02 ck=1.103e-01
# [ZNE] Raw noisy values @ factors [1.0, 3.0, 5.0]: [-51.267636070221975, -51.267636070221975, -51.267636070221975]
# 📊 ZNE Applied:
#    Noisy values: [-51.26763607 -51.26763607 -51.26763607]
#    Noise factors: [1.0, 3.0, 5.0]
#    Extrapolated: -51.26763607
#    Improvement: 0.00000000
#
# ============================================================
# 🔄 VQE ITERATION 65
# ============================================================
# 📊 Energy = -51.26763607 Hartree
# 📊 Energy = -32170.9030 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -16.87010426 Hartree
# 📈 Energy improvement: -0.48450569 Hartree (-304.0317 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 8
#    Parameter range: [-4.4251,  4.0348]
#    Parameter variance: 11.7689
#    RMS parameter:  3.5641
#    Parameters:
#      θ[ 0]= 3.1706 θ[ 1]=-4.1098 θ[ 2]=-2.9964 θ[ 3]=-2.9976
#      θ[ 4]= 3.0195 θ[ 5]=-3.4256 θ[ 6]= 4.0348 θ[ 7]=-4.4251
#    ==================================================
# [ZNE] Raw noisy values @ factors [1.0, 3.0, 5.0]: [-51.54746743769247, -51.54746743769247, -51.54746743769247]
# 📊 ZNE Applied:
#    Noisy values: [-51.54746744 -51.54746744 -51.54746744]
#    Noise factors: [1.0, 3.0, 5.0]
#    Extrapolated: -51.54746744
#    Improvement: 0.00000000
#
# ============================================================
# 🔄 VQE ITERATION 66
# ============================================================
# 📊 Energy = -51.54746744 Hartree
# 📊 Energy = -32346.4997 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -17.14993562 Hartree
# 📈 Energy improvement: 0.27983137 Hartree (175.5967 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 8
#    Parameter range: [-4.6446,  3.8152]
#    Parameter variance: 11.8058
#    RMS parameter:  3.5845
#    Parameters:
#      θ[ 0]= 2.9510 θ[ 1]=-4.3294 θ[ 2]=-2.7768 θ[ 3]=-2.7780
#      θ[ 4]= 3.2390 θ[ 5]=-3.6451 θ[ 6]= 3.8152 θ[ 7]=-4.6446
#    ==================================================
# [ZNE] Raw noisy values @ factors [1.0, 3.0, 5.0]: [-51.74695428867955, -51.74695428867955, -51.74695428867955]
# 📊 ZNE Applied:
#    Noisy values: [-51.74695429 -51.74695429 -51.74695429]
#    Noise factors: [1.0, 3.0, 5.0]
#    Extrapolated: -51.74695429
#    Improvement: 0.00000000
#
# ============================================================
# 🔄 VQE ITERATION 67
# ============================================================
# 📊 Energy = -51.74695429 Hartree
# 📊 Energy = -32471.6795 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -17.34942248 Hartree
# 📈 Energy improvement: 0.19948685 Hartree (125.1798 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 8
#    Parameter range: [-4.5745,  3.8854]
#    Parameter variance: 11.7842
#    RMS parameter:  3.5765
#    Parameters:
#      θ[ 0]= 3.0212 θ[ 1]=-4.2593 θ[ 2]=-2.8470 θ[ 3]=-2.8482
#      θ[ 4]= 3.1689 θ[ 5]=-3.5750 θ[ 6]= 3.8854 θ[ 7]=-4.5745
#    ==================================================
# [SPSA] iter= 22 energy=-51.74695429 ΔE=-5.187e-03 ak=3.111e-02 ck=1.098e-01
# [ZNE] Raw noisy values @ factors [1.0, 3.0, 5.0]: [-53.047929434054, -53.047929434054, -53.047929434054]
# 📊 ZNE Applied:
#    Noisy values: [-53.04792943 -53.04792943 -53.04792943]
#    Noise factors: [1.0, 3.0, 5.0]
#    Extrapolated: -53.04792943
#    Improvement: 0.00000000
#
# ============================================================
# 🔄 VQE ITERATION 68
# ============================================================
# 📊 Energy = -53.04792943 Hartree
# 📊 Energy = -33288.0532 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -18.65039762 Hartree
# 📈 Energy improvement: 1.30097515 Hartree (816.3736 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 8
#    Parameter range: [-4.4652,  3.9946]
#    Parameter variance: 11.9954
#    RMS parameter:  3.6059
#    Parameters:
#      θ[ 0]= 2.9119 θ[ 1]=-4.3685 θ[ 2]=-2.9562 θ[ 3]=-2.7389
#      θ[ 4]= 3.2782 θ[ 5]=-3.6843 θ[ 6]= 3.9946 θ[ 7]=-4.4652
#    ==================================================
# [ZNE] Raw noisy values @ factors [1.0, 3.0, 5.0]: [-49.92572787628081, -49.92572787628081, -49.92572787628081]
# 📊 ZNE Applied:
#    Noisy values: [-49.92572788 -49.92572788 -49.92572788]
#    Noise factors: [1.0, 3.0, 5.0]
#    Extrapolated: -49.92572788
#    Improvement: 0.00000000
#
# ============================================================
# 🔄 VQE ITERATION 69
# ============================================================
# 📊 Energy = -49.92572788 Hartree
# 📊 Energy = -31328.8436 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -15.52819606 Hartree
# 📈 Energy improvement: -3.12220156 Hartree (-1959.2096 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 8
#    Parameter range: [-4.6838,  3.7761]
#    Parameter variance: 11.5969
#    RMS parameter:  3.5502
#    Parameters:
#      θ[ 0]= 3.1305 θ[ 1]=-4.1500 θ[ 2]=-2.7377 θ[ 3]=-2.9574
#      θ[ 4]= 3.0596 θ[ 5]=-3.4657 θ[ 6]= 3.7761 θ[ 7]=-4.6838
#    ==================================================
# [ZNE] Raw noisy values @ factors [1.0, 3.0, 5.0]: [-51.0716837471261, -51.0716837471261, -51.0716837471261]
# 📊 ZNE Applied:
#    Noisy values: [-51.07168375 -51.07168375 -51.07168375]
#    Noise factors: [1.0, 3.0, 5.0]
#    Extrapolated: -51.07168375
#    Improvement: 0.00000000
#
# ============================================================
# 🔄 VQE ITERATION 70
# ============================================================
# 📊 Energy = -51.07168375 Hartree
# 📊 Energy = -32047.9412 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -16.67415193 Hartree
# 📈 Energy improvement: 1.14595587 Hartree (719.0976 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 8
#    Parameter range: [-4.6919,  4.3180]
#    Parameter variance: 12.7601
#    RMS parameter:  3.7104
#    Parameters:
#      θ[ 0]= 2.5885 θ[ 1]=-4.6919 θ[ 2]=-3.2796 θ[ 3]=-2.4155
#      θ[ 4]= 3.6016 θ[ 5]=-4.0077 θ[ 6]= 4.3180 θ[ 7]=-4.1418
#    ==================================================
# [SPSA] iter= 23 energy=-51.07168375 ΔE=-6.753e-01 ak=3.029e-02 ck=1.093e-01
# [ZNE] Raw noisy values @ factors [1.0, 3.0, 5.0]: [-52.066782988526946, -52.066782988526946, -52.066782988526946]
# 📊 ZNE Applied:
#    Noisy values: [-52.06678299 -52.06678299 -52.06678299]
#    Noise factors: [1.0, 3.0, 5.0]
#    Extrapolated: -52.06678299
#    Improvement: 0.00000000
#
# ============================================================
# 🔄 VQE ITERATION 71
# ============================================================
# 📊 Energy = -52.06678299 Hartree
# 📊 Energy = -32672.3749 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -17.66925118 Hartree
# 📈 Energy improvement: 0.99509924 Hartree (624.4337 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 8
#    Parameter range: [-4.8007,  4.2092]
#    Parameter variance: 12.9777
#    RMS parameter:  3.7396
#    Parameters:
#      θ[ 0]= 2.6973 θ[ 1]=-4.8007 θ[ 2]=-3.3884 θ[ 3]=-2.3067
#      θ[ 4]= 3.7104 θ[ 5]=-3.8989 θ[ 6]= 4.2092 θ[ 7]=-4.2506
#    ==================================================
# [ZNE] Raw noisy values @ factors [1.0, 3.0, 5.0]: [-49.61666889330371, -49.61666889330371, -49.61666889330371]
# 📊 ZNE Applied:
#    Noisy values: [-49.61666889 -49.61666889 -49.61666889]
#    Noise factors: [1.0, 3.0, 5.0]
#    Extrapolated: -49.61666889
#    Improvement: 0.00000000
#
# ============================================================
# 🔄 VQE ITERATION 72
# ============================================================
# 📊 Energy = -49.61666889 Hartree
# 📊 Energy = -31134.9063 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -15.21913708 Hartree
# 📈 Energy improvement: -2.45011410 Hartree (-1537.4686 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 8
#    Parameter range: [-4.5831,  4.4268]
#    Parameter variance: 12.5662
#    RMS parameter:  3.6842
#    Parameters:
#      θ[ 0]= 2.4797 θ[ 1]=-4.5831 θ[ 2]=-3.1708 θ[ 3]=-2.5243
#      θ[ 4]= 3.4927 θ[ 5]=-4.1165 θ[ 6]= 4.4268 θ[ 7]=-4.0330
#    ==================================================
# [ZNE] Raw noisy values @ factors [1.0, 3.0, 5.0]: [-52.262144060013654, -52.262144060013654, -52.262144060013654]
# 📊 ZNE Applied:
#    Noisy values: [-52.26214406 -52.26214406 -52.26214406]
#    Noise factors: [1.0, 3.0, 5.0]
#    Extrapolated: -52.26214406
#    Improvement: 0.00000000
#
# ============================================================
# 🔄 VQE ITERATION 73
# ============================================================
# 📊 Energy = -52.26214406 Hartree
# 📊 Energy = -32794.9658 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -17.86461225 Hartree
# 📈 Energy improvement: 2.64547517 Hartree (1660.0595 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 8
#    Parameter range: [-5.0243,  3.9856]
#    Parameter variance: 13.4989
#    RMS parameter:  3.8087
#    Parameters:
#      θ[ 0]= 2.9209 θ[ 1]=-5.0243 θ[ 2]=-3.6120 θ[ 3]=-2.0831
#      θ[ 4]= 3.9339 θ[ 5]=-3.6753 θ[ 6]= 3.9856 θ[ 7]=-4.4742
#    ==================================================
# [SPSA] iter= 24 energy=-52.26214406 ΔE=1.190e+00 ak=2.952e-02 ck=1.088e-01
# [ZNE] Raw noisy values @ factors [1.0, 3.0, 5.0]: [-51.595174388242334, -51.595174388242334, -51.595174388242334]
# 📊 ZNE Applied:
#    Noisy values: [-51.59517439 -51.59517439 -51.59517439]
#    Noise factors: [1.0, 3.0, 5.0]
#    Extrapolated: -51.59517439
#    Improvement: 0.00000000
#
# ============================================================
# 🔄 VQE ITERATION 74
# ============================================================
# 📊 Energy = -51.59517439 Hartree
# 📊 Energy = -32376.4363 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -17.19764258 Hartree
# 📈 Energy improvement: -0.66696967 Hartree (-418.5295 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 8
#    Parameter range: [-5.1326,  4.0940]
#    Parameter variance: 14.2604
#    RMS parameter:  3.9144
#    Parameters:
#      θ[ 0]= 3.0292 θ[ 1]=-5.1326 θ[ 2]=-3.7203 θ[ 3]=-2.1915
#      θ[ 4]= 4.0423 θ[ 5]=-3.7837 θ[ 6]= 4.0940 θ[ 7]=-4.5826
#    ==================================================
# [ZNE] Raw noisy values @ factors [1.0, 3.0, 5.0]: [-52.42316641464103, -52.42316641464103, -52.42316641464103]
# 📊 ZNE Applied:
#    Noisy values: [-52.42316641 -52.42316641 -52.42316641]
#    Noise factors: [1.0, 3.0, 5.0]
#    Extrapolated: -52.42316641
#    Improvement: 0.00000000
#
# ============================================================
# 🔄 VQE ITERATION 75
# ============================================================
# 📊 Energy = -52.42316641 Hartree
# 📊 Energy = -32896.0087 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -18.02563460 Hartree
# 📈 Energy improvement: 0.82799203 Hartree (519.5724 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 8
#    Parameter range: [-4.9159,  3.8773]
#    Parameter variance: 12.7594
#    RMS parameter:  3.7031
#    Parameters:
#      θ[ 0]= 2.8125 θ[ 1]=-4.9159 θ[ 2]=-3.5036 θ[ 3]=-1.9748
#      θ[ 4]= 3.8256 θ[ 5]=-3.5670 θ[ 6]= 3.8773 θ[ 7]=-4.3658
#    ==================================================
# [ZNE] Raw noisy values @ factors [1.0, 3.0, 5.0]: [-52.42162061074157, -52.42162061074157, -52.42162061074157]
# 📊 ZNE Applied:
#    Noisy values: [-52.42162061 -52.42162061 -52.42162061]
#    Noise factors: [1.0, 3.0, 5.0]
#    Extrapolated: -52.42162061
#    Improvement: 0.00000000
#
# ============================================================
# 🔄 VQE ITERATION 76
# ============================================================
# 📊 Energy = -52.42162061 Hartree
# 📊 Energy = -32895.0387 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -18.02408880 Hartree
# 📈 Energy improvement: -0.00154580 Hartree (-0.9700 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 8
#    Parameter range: [-4.9142,  3.8756]
#    Parameter variance: 12.7481
#    RMS parameter:  3.7015
#    Parameters:
#      θ[ 0]= 2.8108 θ[ 1]=-4.9142 θ[ 2]=-3.5019 θ[ 3]=-1.9731
#      θ[ 4]= 3.8239 θ[ 5]=-3.5653 θ[ 6]= 3.8756 θ[ 7]=-4.3641
#    ==================================================
# [SPSA] iter= 25 energy=-52.42162061 ΔE=1.595e-01 ak=2.881e-02 ck=1.084e-01
# [ZNE] Raw noisy values @ factors [1.0, 3.0, 5.0]: [-51.86098852087505, -51.86098852087505, -51.86098852087505]
# 📊 ZNE Applied:
#    Noisy values: [-51.86098852 -51.86098852 -51.86098852]
#    Noise factors: [1.0, 3.0, 5.0]
#    Extrapolated: -51.86098852
#    Improvement: 0.00000000
#
# ============================================================
# 🔄 VQE ITERATION 77
# ============================================================
# 📊 Energy = -51.86098852 Hartree
# 📊 Energy = -32543.2370 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -17.46345671 Hartree
# 📈 Energy improvement: -0.56063209 Hartree (-351.8017 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 8
#    Parameter range: [-5.0222,  3.9835]
#    Parameter variance: 12.9615
#    RMS parameter:  3.7302
#    Parameters:
#      θ[ 0]= 2.7029 θ[ 1]=-5.0222 θ[ 2]=-3.3940 θ[ 3]=-2.0810
#      θ[ 4]= 3.9318 θ[ 5]=-3.6732 θ[ 6]= 3.9835 θ[ 7]=-4.2562
#    ==================================================
# [ZNE] Raw noisy values @ factors [1.0, 3.0, 5.0]: [-52.472666438242626, -52.472666438242626, -52.472666438242626]
# 📊 ZNE Applied:
#    Noisy values: [-52.47266644 -52.47266644 -52.47266644]
#    Noise factors: [1.0, 3.0, 5.0]
#    Extrapolated: -52.47266644
#    Improvement: 0.00000000
#
# ============================================================
# 🔄 VQE ITERATION 78
# ============================================================
# 📊 Energy = -52.47266644 Hartree
# 📊 Energy = -32927.0704 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -18.07513463 Hartree
# 📈 Energy improvement: 0.61167792 Hartree (383.8334 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 8
#    Parameter range: [-4.8063,  3.7677]
#    Parameter variance: 12.5581
#    RMS parameter:  3.6757
#    Parameters:
#      θ[ 0]= 2.9188 θ[ 1]=-4.8063 θ[ 2]=-3.6099 θ[ 3]=-1.8652
#      θ[ 4]= 3.7159 θ[ 5]=-3.4573 θ[ 6]= 3.7677 θ[ 7]=-4.4721
#    ==================================================
# [ZNE] Raw noisy values @ factors [1.0, 3.0, 5.0]: [-52.50495506054672, -52.50495506054672, -52.50495506054672]
# 📊 ZNE Applied:
#    Noisy values: [-52.50495506 -52.50495506 -52.50495506]
#    Noise factors: [1.0, 3.0, 5.0]
#    Extrapolated: -52.50495506
#    Improvement: 0.00000000
#
# ============================================================
# 🔄 VQE ITERATION 79
# ============================================================
# 📊 Energy = -52.50495506 Hartree
# 📊 Energy = -32947.3318 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -18.10742325 Hartree
# 📈 Energy improvement: 0.03228862 Hartree (20.2614 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 8
#    Parameter range: [-4.8345,  3.7959]
#    Parameter variance: 12.6055
#    RMS parameter:  3.6821
#    Parameters:
#      θ[ 0]= 2.8905 θ[ 1]=-4.8345 θ[ 2]=-3.5816 θ[ 3]=-1.8934
#      θ[ 4]= 3.7442 θ[ 5]=-3.4856 θ[ 6]= 3.7959 θ[ 7]=-4.4439
#    ==================================================
# [SPSA] iter= 26 energy=-52.50495506 ΔE=8.333e-02 ak=2.813e-02 ck=1.079e-01
# [ZNE] Raw noisy values @ factors [1.0, 3.0, 5.0]: [-50.413717318866944, -50.413717318866944, -50.413717318866944]
# 📊 ZNE Applied:
#    Noisy values: [-50.41371732 -50.41371732 -50.41371732]
#    Noise factors: [1.0, 3.0, 5.0]
#    Extrapolated: -50.41371732
#    Improvement: 0.00000000
#
# ============================================================
# 🔄 VQE ITERATION 80
# ============================================================
# 📊 Energy = -50.41371732 Hartree
# 📊 Energy = -31635.0613 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -16.01618551 Hartree
# 📈 Energy improvement: -2.09123774 Hartree (-1312.2705 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 8
#    Parameter range: [-4.9421,  3.9034]
#    Parameter variance: 12.5030
#    RMS parameter:  3.6682
#    Parameters:
#      θ[ 0]= 2.7830 θ[ 1]=-4.9421 θ[ 2]=-3.6892 θ[ 3]=-1.7859
#      θ[ 4]= 3.6366 θ[ 5]=-3.3780 θ[ 6]= 3.9034 θ[ 7]=-4.3363
#    ==================================================
# [ZNE] Raw noisy values @ factors [1.0, 3.0, 5.0]: [-54.26543005808735, -54.26543005808735, -54.26543005808735]
# 📊 ZNE Applied:
#    Noisy values: [-54.26543006 -54.26543006 -54.26543006]
#    Noise factors: [1.0, 3.0, 5.0]
#    Extrapolated: -54.26543006
#    Improvement: 0.00000000
#
# ============================================================
# 🔄 VQE ITERATION 81
# ============================================================
# 📊 Energy = -54.26543006 Hartree
# 📊 Energy = -34052.0458 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -19.86789824 Hartree
# 📈 Energy improvement: 3.85171274 Hartree (2416.9844 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 8
#    Parameter range: [-4.7270,  3.8517]
#    Parameter variance: 12.7312
#    RMS parameter:  3.6992
#    Parameters:
#      θ[ 0]= 2.9981 θ[ 1]=-4.7270 θ[ 2]=-3.4741 θ[ 3]=-2.0009
#      θ[ 4]= 3.8517 θ[ 5]=-3.5931 θ[ 6]= 3.6884 θ[ 7]=-4.5514
#    ==================================================
# [ZNE] Raw noisy values @ factors [1.0, 3.0, 5.0]: [-53.505996196312985, -53.505996196312985, -53.505996196312985]
# 📊 ZNE Applied:
#    Noisy values: [-53.5059962 -53.5059962 -53.5059962]
#    Noise factors: [1.0, 3.0, 5.0]
#    Extrapolated: -53.50599620
#    Improvement: 0.00000000
#
# ============================================================
# 🔄 VQE ITERATION 82
# ============================================================
# 📊 Energy = -53.50599620 Hartree
# 📊 Energy = -33575.4942 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -19.10846438 Hartree
# 📈 Energy improvement: -0.75943386 Hartree (-476.5516 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 8
#    Parameter range: [-4.9364,  4.2367]
#    Parameter variance: 13.3709
#    RMS parameter:  3.7846
#    Parameters:
#      θ[ 0]= 3.3831 θ[ 1]=-4.3420 θ[ 2]=-3.0891 θ[ 3]=-2.3859
#      θ[ 4]= 4.2367 θ[ 5]=-3.9781 θ[ 6]= 3.3033 θ[ 7]=-4.9364
#    ==================================================
# [SPSA] iter= 27 energy=-53.50599620 ΔE=1.001e+00 ak=2.750e-02 ck=1.075e-01
# [ZNE] Raw noisy values @ factors [1.0, 3.0, 5.0]: [-53.32251458071109, -53.32251458071109, -53.32251458071109]
# 📊 ZNE Applied:
#    Noisy values: [-53.32251458 -53.32251458 -53.32251458]
#    Noise factors: [1.0, 3.0, 5.0]
#    Extrapolated: -53.32251458
#    Improvement: 0.00000000
#
# ============================================================
# 🔄 VQE ITERATION 83
# ============================================================
# 📊 Energy = -53.32251458 Hartree
# 📊 Energy = -33460.3578 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -18.92498277 Hartree
# 📈 Energy improvement: -0.18348162 Hartree (-115.1364 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 8
#    Parameter range: [-4.8293,  4.3438]
#    Parameter variance: 13.2592
#    RMS parameter:  3.7563
#    Parameters:
#      θ[ 0]= 3.2760 θ[ 1]=-4.2348 θ[ 2]=-3.1962 θ[ 3]=-2.2788
#      θ[ 4]= 4.3438 θ[ 5]=-3.8710 θ[ 6]= 3.4105 θ[ 7]=-4.8293
#    ==================================================
# [ZNE] Raw noisy values @ factors [1.0, 3.0, 5.0]: [-53.01676683290926, -53.01676683290926, -53.01676683290926]
# 📊 ZNE Applied:
#    Noisy values: [-53.01676683 -53.01676683 -53.01676683]
#    Noise factors: [1.0, 3.0, 5.0]
#    Extrapolated: -53.01676683
#    Improvement: 0.00000000
#
# ============================================================
# 🔄 VQE ITERATION 84
# ============================================================
# 📊 Energy = -53.01676683 Hartree
# 📊 Energy = -33268.4983 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -18.61923502 Hartree
# 📈 Energy improvement: -0.30574775 Hartree (-191.8595 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 8
#    Parameter range: [-5.0435,  4.1296]
#    Parameter variance: 13.4998
#    RMS parameter:  3.8157
#    Parameters:
#      θ[ 0]= 3.4902 θ[ 1]=-4.4491 θ[ 2]=-2.9820 θ[ 3]=-2.4931
#      θ[ 4]= 4.1296 θ[ 5]=-4.0852 θ[ 6]= 3.1962 θ[ 7]=-5.0435
#    ==================================================
# [ZNE] Raw noisy values @ factors [1.0, 3.0, 5.0]: [-53.50664452689996, -53.50664452689996, -53.50664452689996]
# ...
#    ==================================================
# [ZNE] Raw noisy values @ factors [1.0, 3.0, 5.0]: [-56.354264177102664, -56.354264177102664, -56.354264177102664]
# 📊 ZNE Applied:
#    Noisy values: [-56.35426418 -56.35426418 -56.35426418]
#    Noise factors: [1.0, 3.0, 5.0]
#    Extrapolated: -56.35426418
#    Improvement: 0.00000000
#
# ============================================================
# 🔄 VQE ITERATION 222
# ============================================================
# 📊 Energy = -56.35426418 Hartree
# 📊 Energy = -35362.8080 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -21.95673236 Hartree
# 📈 Energy improvement: 0.00003316 Hartree (0.0208 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 8
#    Parameter range: [-0.0632,  0.0107]
#    Parameter variance:  0.0005
#    RMS parameter:  0.0229
#    Parameters:
#      θ[ 0]=-0.0006 θ[ 1]= 0.0107 θ[ 2]= 0.0008 θ[ 3]=-0.0095
#      θ[ 4]=-0.0007 θ[ 5]=-0.0007 θ[ 6]=-0.0006 θ[ 7]=-0.0632
#    ==================================================
# [ZNE] Raw noisy values @ factors [1.0, 3.0, 5.0]: [-56.35427772247053, -56.35427772247053, -56.35427772247053]
# 📊 ZNE Applied:
#    Noisy values: [-56.35427772 -56.35427772 -56.35427772]
#    Noise factors: [1.0, 3.0, 5.0]
#    Extrapolated: -56.35427772
#    Improvement: 0.00000000
#
# ============================================================
# 🔄 VQE ITERATION 223
# ============================================================
# 📊 Energy = -56.35427772 Hartree
# 📊 Energy = -35362.8165 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -21.95674591 Hartree
# 📈 Energy improvement: 0.00001355 Hartree (0.0085 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 8
#    Parameter range: [-0.0634,  0.0105]
#    Parameter variance:  0.0005
#    RMS parameter:  0.0230
#    Parameters:
#      θ[ 0]=-0.0004 θ[ 1]= 0.0105 θ[ 2]= 0.0009 θ[ 3]=-0.0093
#      θ[ 4]=-0.0009 θ[ 5]=-0.0008 θ[ 6]=-0.0006 θ[ 7]=-0.0634
#    ==================================================
# [ZNE] Raw noisy values @ factors [1.0, 3.0, 5.0]: [-56.35430374372345, -56.35430374372345, -56.35430374372345]
# 📊 ZNE Applied:
#    Noisy values: [-56.35430374 -56.35430374 -56.35430374]
#    Noise factors: [1.0, 3.0, 5.0]
#    Extrapolated: -56.35430374
#    Improvement: 0.00000000
#
# ============================================================
# 🔄 VQE ITERATION 224
# ============================================================
# 📊 Energy = -56.35430374 Hartree
# 📊 Energy = -35362.8328 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -21.95677193 Hartree
# 📈 Energy improvement: 0.00002602 Hartree (0.0163 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 8
#    Parameter range: [-0.0637,  0.0105]
#    Parameter variance:  0.0005
#    RMS parameter:  0.0231
#    Parameters:
#      θ[ 0]=-0.0004 θ[ 1]= 0.0105 θ[ 2]= 0.0008 θ[ 3]=-0.0094
#      θ[ 4]=-0.0009 θ[ 5]=-0.0010 θ[ 6]=-0.0006 θ[ 7]=-0.0637
#    ==================================================
# [ZNE] Raw noisy values @ factors [1.0, 3.0, 5.0]: [-56.35433502699888, -56.35433502699888, -56.35433502699888]
# 📊 ZNE Applied:
#    Noisy values: [-56.35433503 -56.35433503 -56.35433503]
#    Noise factors: [1.0, 3.0, 5.0]
#    Extrapolated: -56.35433503
#    Improvement: 0.00000000
#
# ============================================================
# 🔄 VQE ITERATION 225
# ============================================================
# 📊 Energy = -56.35433503 Hartree
# 📊 Energy = -35362.8524 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -21.95680321 Hartree
# 📈 Energy improvement: 0.00003128 Hartree (0.0196 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 8
#    Parameter range: [-0.0638,  0.0106]
#    Parameter variance:  0.0005
#    RMS parameter:  0.0231
#    Parameters:
#      θ[ 0]=-0.0003 θ[ 1]= 0.0106 θ[ 2]= 0.0006 θ[ 3]=-0.0093
#      θ[ 4]=-0.0007 θ[ 5]=-0.0010 θ[ 6]=-0.0006 θ[ 7]=-0.0638
#    ==================================================
# [ZNE] Raw noisy values @ factors [1.0, 3.0, 5.0]: [-56.35435195119372, -56.35435195119372, -56.35435195119372]
# 📊 ZNE Applied:
#    Noisy values: [-56.35435195 -56.35435195 -56.35435195]
#    Noise factors: [1.0, 3.0, 5.0]
#    Extrapolated: -56.35435195
#    Improvement: 0.00000000
#
# ============================================================
# 🔄 VQE ITERATION 226
# ============================================================
# 📊 Energy = -56.35435195 Hartree
# 📊 Energy = -35362.8630 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -21.95682014 Hartree
# 📈 Energy improvement: 0.00001692 Hartree (0.0106 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 8
#    Parameter range: [-0.0640,  0.0107]
#    Parameter variance:  0.0005
#    RMS parameter:  0.0232
#    Parameters:
#      θ[ 0]=-0.0001 θ[ 1]= 0.0107 θ[ 2]= 0.0005 θ[ 3]=-0.0093
#      θ[ 4]=-0.0009 θ[ 5]=-0.0009 θ[ 6]=-0.0007 θ[ 7]=-0.0640
#    ==================================================
# [ZNE] Raw noisy values @ factors [1.0, 3.0, 5.0]: [-56.354392971961666, -56.354392971961666, -56.354392971961666]
# 📊 ZNE Applied:
#    Noisy values: [-56.35439297 -56.35439297 -56.35439297]
#    Noise factors: [1.0, 3.0, 5.0]
#    Extrapolated: -56.35439297
#    Improvement: 0.00000000
#
# ============================================================
# 🔄 VQE ITERATION 227
# ============================================================
# 📊 Energy = -56.35439297 Hartree
# 📊 Energy = -35362.8888 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -21.95686116 Hartree
# 📈 Energy improvement: 0.00004102 Hartree (0.0257 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 8
#    Parameter range: [-0.0644,  0.0107]
#    Parameter variance:  0.0005
#    RMS parameter:  0.0233
#    Parameters:
#      θ[ 0]=-0.0000 θ[ 1]= 0.0107 θ[ 2]= 0.0004 θ[ 3]=-0.0093
#      θ[ 4]=-0.0007 θ[ 5]=-0.0010 θ[ 6]=-0.0007 θ[ 7]=-0.0644
#    ==================================================
# [ZNE] Raw noisy values @ factors [1.0, 3.0, 5.0]: [-56.35446483622714, -56.35446483622714, -56.35446483622714]
# 📊 ZNE Applied:
#    Noisy values: [-56.35446484 -56.35446484 -56.35446484]
#    Noise factors: [1.0, 3.0, 5.0]
#    Extrapolated: -56.35446484
#    Improvement: 0.00000000
#
# ============================================================
# 🔄 VQE ITERATION 228
# ============================================================
# 📊 Energy = -56.35446484 Hartree
# 📊 Energy = -35362.9339 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -21.95693302 Hartree
# 📈 Energy improvement: 0.00007186 Hartree (0.0451 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 8
#    Parameter range: [-0.0651,  0.0107]
#    Parameter variance:  0.0005
#    RMS parameter:  0.0235
#    Parameters:
#      θ[ 0]=-0.0000 θ[ 1]= 0.0107 θ[ 2]= 0.0003 θ[ 3]=-0.0091
#      θ[ 4]=-0.0004 θ[ 5]=-0.0011 θ[ 6]=-0.0008 θ[ 7]=-0.0651
#    ==================================================
# [ZNE] Raw noisy values @ factors [1.0, 3.0, 5.0]: [-56.35456480479986, -56.35456480479986, -56.35456480479986]
# 📊 ZNE Applied:
#    Noisy values: [-56.3545648 -56.3545648 -56.3545648]
#    Noise factors: [1.0, 3.0, 5.0]
#    Extrapolated: -56.35456480
#    Improvement: 0.00000000
#
# ============================================================
# 🔄 VQE ITERATION 229
# ============================================================
# 📊 Energy = -56.35456480 Hartree
# 📊 Energy = -35362.9966 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -21.95703299 Hartree
# 📈 Energy improvement: 0.00009997 Hartree (0.0627 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 8
#    Parameter range: [-0.0663,  0.0102]
#    Parameter variance:  0.0005
#    RMS parameter:  0.0239
#    Parameters:
#      θ[ 0]= 0.0005 θ[ 1]= 0.0102 θ[ 2]=-0.0001 θ[ 3]=-0.0092
#      θ[ 4]= 0.0002 θ[ 5]=-0.0012 θ[ 6]=-0.0006 θ[ 7]=-0.0663
#    ==================================================
# [ZNE] Raw noisy values @ factors [1.0, 3.0, 5.0]: [-56.3546329231895, -56.3546329231895, -56.3546329231895]
# 📊 ZNE Applied:
#    Noisy values: [-56.35463292 -56.35463292 -56.35463292]
#    Noise factors: [1.0, 3.0, 5.0]
#    Extrapolated: -56.35463292
#    Improvement: 0.00000000
#
# ============================================================
# 🔄 VQE ITERATION 230
# ============================================================
# 📊 Energy = -56.35463292 Hartree
# 📊 Energy = -35363.0394 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -21.95710111 Hartree
# 📈 Energy improvement: 0.00006812 Hartree (0.0427 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 8
#    Parameter range: [-0.0674,  0.0108]
#    Parameter variance:  0.0005
#    RMS parameter:  0.0244
#    Parameters:
#      θ[ 0]= 0.0010 θ[ 1]= 0.0108 θ[ 2]=-0.0005 θ[ 3]=-0.0088
#      θ[ 4]= 0.0001 θ[ 5]=-0.0016 θ[ 6]=-0.0002 θ[ 7]=-0.0674
#    ==================================================
# [ZNE] Raw noisy values @ factors [1.0, 3.0, 5.0]: [-56.35474155646688, -56.35474155646688, -56.35474155646688]
# 📊 ZNE Applied:
#    Noisy values: [-56.35474156 -56.35474156 -56.35474156]
#    Noise factors: [1.0, 3.0, 5.0]
#    Extrapolated: -56.35474156
#    Improvement: 0.00000000
#
# ============================================================
# 🔄 VQE ITERATION 231
# ============================================================
# 📊 Energy = -56.35474156 Hartree
# 📊 Energy = -35363.1075 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -21.95720974 Hartree
# 📈 Energy improvement: 0.00010863 Hartree (0.0682 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 8
#    Parameter range: [-0.0685,  0.0109]
#    Parameter variance:  0.0005
#    RMS parameter:  0.0247
#    Parameters:
#      θ[ 0]= 0.0008 θ[ 1]= 0.0109 θ[ 2]=-0.0005 θ[ 3]=-0.0088
#      θ[ 4]= 0.0001 θ[ 5]=-0.0013 θ[ 6]=-0.0013 θ[ 7]=-0.0685
#    ==================================================
# [ZNE] Raw noisy values @ factors [1.0, 3.0, 5.0]: [-56.354753883029, -56.354753883029, -56.354753883029]
# 📊 ZNE Applied:
#    Noisy values: [-56.35475388 -56.35475388 -56.35475388]
#    Noise factors: [1.0, 3.0, 5.0]
#    Extrapolated: -56.35475388
#    Improvement: 0.00000000
#
# ============================================================
# 🔄 VQE ITERATION 232
# ============================================================
# 📊 Energy = -56.35475388 Hartree
# 📊 Energy = -35363.1153 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -21.95722207 Hartree
# 📈 Energy improvement: 0.00001233 Hartree (0.0077 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 8
#    Parameter range: [-0.0687,  0.0105]
#    Parameter variance:  0.0005
#    RMS parameter:  0.0247
#    Parameters:
#      θ[ 0]= 0.0011 θ[ 1]= 0.0105 θ[ 2]=-0.0001 θ[ 3]=-0.0075
#      θ[ 4]= 0.0003 θ[ 5]=-0.0008 θ[ 6]=-0.0016 θ[ 7]=-0.0687
#    ==================================================
# [ZNE] Raw noisy values @ factors [1.0, 3.0, 5.0]: [-56.35476612467153, -56.35476612467153, -56.35476612467153]
# 📊 ZNE Applied:
#    Noisy values: [-56.35476612 -56.35476612 -56.35476612]
#    Noise factors: [1.0, 3.0, 5.0]
#    Extrapolated: -56.35476612
#    Improvement: 0.00000000
#
# ============================================================
# 🔄 VQE ITERATION 233
# ============================================================
# 📊 Energy = -56.35476612 Hartree
# 📊 Energy = -35363.1229 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -21.95723431 Hartree
# 📈 Energy improvement: 0.00001224 Hartree (0.0077 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 8
#    Parameter range: [-0.0689,  0.0103]
#    Parameter variance:  0.0005
#    RMS parameter:  0.0248
#    Parameters:
#      θ[ 0]= 0.0009 θ[ 1]= 0.0103 θ[ 2]=-0.0007 θ[ 3]=-0.0073
#      θ[ 4]= 0.0004 θ[ 5]=-0.0010 θ[ 6]=-0.0018 θ[ 7]=-0.0689
#    ==================================================
# [ZNE] Raw noisy values @ factors [1.0, 3.0, 5.0]: [-56.35477267009377, -56.35477267009377, -56.35477267009377]
# 📊 ZNE Applied:
#    Noisy values: [-56.35477267 -56.35477267 -56.35477267]
#    Noise factors: [1.0, 3.0, 5.0]
#    Extrapolated: -56.35477267
#    Improvement: 0.00000000
#
# ============================================================
# 🔄 VQE ITERATION 234
# ============================================================
# 📊 Energy = -56.35477267 Hartree
# 📊 Energy = -35363.1270 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -21.95724086 Hartree
# 📈 Energy improvement: 0.00000655 Hartree (0.0041 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 8
#    Parameter range: [-0.0691,  0.0102]
#    Parameter variance:  0.0005
#    RMS parameter:  0.0248
#    Parameters:
#      θ[ 0]= 0.0011 θ[ 1]= 0.0102 θ[ 2]=-0.0009 θ[ 3]=-0.0074
#      θ[ 4]= 0.0002 θ[ 5]=-0.0009 θ[ 6]=-0.0019 θ[ 7]=-0.0691
#    ==================================================
# [ZNE] Raw noisy values @ factors [1.0, 3.0, 5.0]: [-56.35479701031555, -56.35479701031555, -56.35479701031555]
# 📊 ZNE Applied:
#    Noisy values: [-56.35479701 -56.35479701 -56.35479701]
#    Noise factors: [1.0, 3.0, 5.0]
#    Extrapolated: -56.35479701
#    Improvement: 0.00000000
#
# ============================================================
# 🔄 VQE ITERATION 235
# ============================================================
# 📊 Energy = -56.35479701 Hartree
# 📊 Energy = -35363.1423 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -21.95726520 Hartree
# 📈 Energy improvement: 0.00002434 Hartree (0.0153 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 8
#    Parameter range: [-0.0694,  0.0101]
#    Parameter variance:  0.0005
#    RMS parameter:  0.0250
#    Parameters:
#      θ[ 0]= 0.0010 θ[ 1]= 0.0101 θ[ 2]=-0.0008 θ[ 3]=-0.0075
#      θ[ 4]= 0.0004 θ[ 5]=-0.0009 θ[ 6]=-0.0019 θ[ 7]=-0.0694
#    ==================================================
# Return from COBYLA because the objective function has been evaluated MAXFUN times.
# Number of function values = 150   Least value of F = -56.35479701031555
# The corresponding X is:
# [ 0.00100245  0.0100934  -0.00078464 -0.00751596  0.00040113 -0.00092846
#  -0.00192013 -0.06940983]
#
# [Hybrid] Completed. Total energy evaluations: 235
# [ZNE] Raw noisy values @ factors [1.0, 3.0, 5.0]: [-56.35479701031555, -56.35479701031555, -56.35479701031555]
# 📊 ZNE Applied:
#    Noisy values: [-56.35479701 -56.35479701 -56.35479701]
#    Noise factors: [1.0, 3.0, 5.0]
#    Extrapolated: -56.35479701
#    Improvement: 0.00000000
#
# ============================================================
# 🔄 VQE ITERATION 236
# ============================================================
# 📊 Energy = -56.35479701 Hartree
# 📊 Energy = -35363.1423 kcal/mol
# 📊 Energy (minus constant shift -34.397532) = -21.95726520 Hartree
# 📈 Energy improvement: 0.00000000 Hartree (0.0000 kcal/mol)
#
# 🌊 Trial Wavefunction |ψ(θ)⟩:
#    ==================================================
#    Total parameters: 8
#    Parameter range: [-0.0694,  0.0101]
#    Parameter variance:  0.0005
#    RMS parameter:  0.0250
#    Parameters:
#      θ[ 0]= 0.0010 θ[ 1]= 0.0101 θ[ 2]=-0.0008 θ[ 3]=-0.0075
#      θ[ 4]= 0.0004 θ[ 5]=-0.0009 θ[ 6]=-0.0019 θ[ 7]=-0.0694
#    ==================================================
#
# 🏁 VQE optimization complete
#    Final energy: -56.3547970103 Hartree
#    Total improvement: 0.032951 Hartree
#    Objective evaluations: 236
#    Effective circuit evaluations: 708
#
# [Hybrid+ZNE VQE] Final (extrapolated) energy: -56.35479701031555
#
# ZNE analysis: {'total_applications': 236, 'average_improvement': np.float64(2.8903433319054925e-15), 'std_improvement': np.float64(4.506918957337928e-15), 'max_improvement': np.float64(1.4210854715202004e-14), 'min_improvement': np.float64(0.0), 'extrapolation_method': 'richardson', 'noise_factors': [1.0, 3.0, 5.0], 'success_rate': np.float64(32.6271186440678)}

# %% [markdown]
# ### Cell 8 Description: Consolidated VQE Run Summary
# Aggregates energies, best improvements, iteration counts, and parameter numbers for any executed VQE variants (Basic, Hybrid, Hybrid+ZNE). Safe to rerun; skips variants not yet executed. Also prints ZNE extrapolation details if available.

# %%
# === 8. VQE Results Summary (Energies & Iterations) ===
# Collect and print final energies + iteration counts for each executed variant.
# Safe to run multiple times after any subset of runs.

summary_rows = []
from math import isnan

# Helper: build lightweight object for baseline (non-VQE) run so we can reuse collect()
if 'baseline_energy' in globals() and 'baseline_params' in globals():
    class _BaselineObj:
        def __init__(self, energy, params):
            self.energy_history = [float(energy)]  # single evaluation (or quick mini optimization)
            self.iteration_count = len(self.energy_history)
            class _AnsatzWrap:
                def __init__(self, n): self.num_parameters = n
            self.ansatz_plugin = _AnsatzWrap(len(params))
    baseline_obj = _BaselineObj(baseline_energy, baseline_params)
else:
    baseline_obj = None

def collect(label, vqe_obj, energy_name, energy_val):
    if vqe_obj is None:
        return
    # Final recorded energy; fall back to provided energy_val
    final_energy = float(energy_val) if energy_val is not None else (
        vqe_obj.energy_history[-1] if vqe_obj.energy_history else float('nan')
    )
    best_energy = min(vqe_obj.energy_history) if vqe_obj.energy_history else final_energy
    iters = getattr(vqe_obj, 'iteration_count', len(getattr(vqe_obj,'energy_history', [])))
    params = getattr(getattr(vqe_obj, 'ansatz_plugin', object()), 'num_parameters', None)
    summary_rows.append({
        'variant': label,
        'final_energy': final_energy,
        'best_energy': best_energy,
        'iterations': iters,
        'parameters': params,
        'improvement': (vqe_obj.energy_history[0] - best_energy) if len(vqe_obj.energy_history) >= 2 else 0.0
    })

# Baselines / variants
collect('Baseline HF', baseline_obj, 'baseline_energy', globals().get('baseline_energy'))
collect('CoordinateDescent', globals().get('vqe_cd'), 'energy_cd', globals().get('energy_cd'))
collect('Basic (SPSA)', globals().get('vqe_basic'), 'energy_basic', globals().get('energy_basic'))
collect('Hybrid (SPSA->COBYLA)', globals().get('vqe_hybrid'), 'energy_hybrid', globals().get('energy_hybrid'))
collect('Hybrid+ZNE', globals().get('vqe_hybrid_zne'), 'energy_hybrid_zne', globals().get('energy_hybrid_zne'))

if not summary_rows:
    print('No VQE runs detected yet. Run the variant cells first.')
else:
    # Pretty print
    print('\n=== VQE Run Summary ===')
    header = f"{'Variant':28s} {'Final Energy (Ha)':>18s} {'Best (Ha)':>14s} {'Δ (Ha)':>12s} {'Iters':>7s} {'Params':>7s}"""
    print(header)
    print('-'*len(header))
    for row in summary_rows:
        dE = row['improvement']
        print(f"{row['variant']:28s} {row['final_energy']:18.10f} {row['best_energy']:14.10f} {dE:12.6f} {row['iterations']:7d} {row['parameters']:7}")
    print('\nNotes:')
    print('  Δ (Ha) = initial_energy - best_energy (if multiple evaluations).')
    print('  Best vs Final can differ if last evaluation was not the minimum encountered.')
    if 'zne_plugin' in globals():
        zne_analysis = zne_plugin.get_zne_analysis()
        if 'error' not in zne_analysis:
            print('\nZNE summary (last run):')
            for k,v in zne_analysis.items():
                if isinstance(v, float):
                    print(f"  {k}: {v}")
                else:
                    print(f"  {k}: {v}")
        else:
            print('\nZNE summary: No multi-noise measurements collected (single-factor only).')
# Out:
# === VQE Run Summary ===
# Variant                       Final Energy (Ha)      Best (Ha)       Δ (Ha)   Iters  Params
# -------------------------------------------------------------------------------------------
# Baseline HF                      -56.3435034487 -56.3435034487     0.000000       1       8
# CoordinateDescent                -56.3560213016 -56.3560213016     0.012518     130       8
# Basic (SPSA)                     -60.3219620006 -60.7421061722    60.742106     389      12
# Hybrid (SPSA->COBYLA)            -56.3559048973 -56.3559048973     0.014915     188       8
# Hybrid+ZNE                       -56.3547970103 -56.3547970103     0.032951     236       8
#
# Notes:
#   Δ (Ha) = initial_energy - best_energy (if multiple evaluations).
#   Best vs Final can differ if last evaluation was not the minimum encountered.
#
# ZNE summary (last run):
#   total_applications: 236
#   average_improvement: 2.8903433319054925e-15
#   std_improvement: 4.506918957337928e-15
#   max_improvement: 1.4210854715202004e-14
#   min_improvement: 0.0
#   extrapolation_method: richardson
#   noise_factors: [1.0, 3.0, 5.0]
#   success_rate: 32.6271186440678

# %% [markdown]
# ### Gradio UI: Interactive Viewer for VQE Results and Artifacts
#
# This UI cell launches a small web app to explore outputs generated by the notebook. Run Cells 2–7 first so objects exist (ham_system, uccsd_ansatz, vqe_* variants, summary_rows). The UI provides:
#
# - Basic VQE tab: Streams a live energy-reduction plot from `vqe_basic.energy_history` and shows the final energy.
# - Hamiltonian Operator tab: Prints the first 10 non‑zero Pauli terms from `ham_system['hamiltonian_active']`.
# - UCCSD Ansatz Circuit tab: Renders the stored `uccsd_ansatz.ansatz_circuit`.
# - Optimizer Experiments tab: Shows five per‑variant energy plots (Baseline HF, CoordinateDescent, Basic (SPSA), Hybrid, Hybrid+ZNE) and an animated all‑variants comparison.
# - Extras tab: Simple note pad to save observations in‑session.
# - Summary Cell tab: Renders the markdown table created by the summary cell (final energy, best energy, iterations, params).
#
# Notes
# - The cell auto‑installs `gradio`, `matplotlib`, and `plotly` if missing.
# - On Colab it opens a public URL; locally it serves at http://127.0.0.1:7860 by default.
# - If a tab shows “N/A” or empties, run the corresponding compute cell (e.g., Basic/Hybrid/ZNE) and refresh the tab.

# %%
# --- Gradio UI for VQE Workflow in Colab ---
# Install required packages (if not already installed)
try:
    import gradio as gr
except ImportError:
    # !pip install gradio --quiet
    import gradio as gr

try:
    import matplotlib.pyplot as plt
except ImportError:
    # !pip install matplotlib --quiet
    import matplotlib.pyplot as plt

try:
    import plotly.graph_objs as go
except ImportError:
    # !pip install plotly --quiet
    import plotly.graph_objs as go

try:
    from qiskit import QuantumCircuit
except ImportError:
    # !pip install qiskit --quiet
    from qiskit import QuantumCircuit

import numpy as np
import io
import time
import threading

# --- Helper Functions ---
def get_energy_history(vqe_obj):
    """Extract energy history from VQE object."""
    if hasattr(vqe_obj, 'energy_history'):
        return np.array(vqe_obj.energy_history)
    return np.array([])

def plot_energy_reduction(energy_history, title="Energy Reduction"):
    """Plot energy reduction over iterations using Matplotlib."""
    fig, ax = plt.subplots(figsize=(6, 4))
    ax.plot(np.arange(1, len(energy_history)+1), energy_history, marker='o', color='blue')
    ax.set_xlabel("Iteration")
    ax.set_ylabel("Energy (Hartree)")
    ax.set_title(title)
    ax.grid(True)
    fig.tight_layout()
    return fig

def live_plot_energy_reduction(energy_history, title="Energy Reduction"):
    fig, ax = plt.subplots(figsize=(6, 4))
    ax.set_xlabel("Iteration")
    ax.set_ylabel("Energy (Hartree)")
    ax.set_title(title)
    ax.grid(True)
    fig.tight_layout()
    for i in range(1, len(energy_history)+1):
        ax.clear()
        ax.plot(np.arange(1, i+1), energy_history[:i], marker='o', color='blue')
        ax.set_xlabel("Iteration")
        ax.set_ylabel("Energy (Hartree)")
        ax.set_title(title)
        ax.grid(True)
        fig.tight_layout()
        yield fig
        time.sleep(0.15)

def plot_comparison(energies, labels, title="VQE Variant Comparison"):
    """Plot comparison of final energies for different VQE variants."""
    fig = go.Figure()
    fig.add_trace(go.Bar(x=labels, y=energies, marker_color='indigo'))
    fig.update_layout(title=title, xaxis_title="Variant", yaxis_title="Final Energy (Hartree)", font_family="monospace")
    return fig

def live_text_reveal(text, delay=0.08):
    lines = text.split('\n')
    out = ""
    for line in lines:
        out += line + "\n"
        yield out
        time.sleep(delay)

def plot_all_histories(histories, labels, title):
    """Plot multiple energy histories for comparison with improved clarity."""
    fig, ax = plt.subplots(figsize=(12, 7))  # Larger figure for visibility
    colors = ["#e6194b", "#3cb44b", "#ffe119", "#4363d8", "#f58231", "#911eb4", "#46f0f0", "#f032e6"]
    markers = ['o', 's', '^', 'D', 'P', 'X', '*', 'v']
    for i, (hist, label) in enumerate(zip(histories, labels)):
        if len(hist) > 0:
            ax.plot(np.arange(1, len(hist)+1), hist, marker=markers[i % len(markers)], color=colors[i % len(colors)], label=label, linewidth=2, markersize=8)
    ax.set_xlabel("Iteration", fontsize=14)
    ax.set_ylabel("Energy (Hartree)", fontsize=14)
    ax.set_title(title, fontsize=16, fontweight='bold')
    ax.grid(True, which='both', linestyle='--', alpha=0.7)
    ax.legend(loc='upper left', bbox_to_anchor=(1, 1), fontsize=13)  # Move legend outside plot
    fig.tight_layout(rect=[0, 0, 0.85, 1])  # Make room for legend
    return fig

def live_plot_all_histories(histories, labels, title):
    fig, ax = plt.subplots(figsize=(12, 7))
    colors = ["#e6194b", "#3cb44b", "#ffe119", "#4363d8", "#f58231", "#911eb4", "#46f0f0", "#f032e6"]
    markers = ['o', 's', '^', 'D', 'P', 'X', '*', 'v']
    ax.set_xlabel("Iteration", fontsize=14)
    ax.set_ylabel("Energy (Hartree)", fontsize=14)
    ax.set_title(title, fontsize=16, fontweight='bold')
    ax.grid(True, which='both', linestyle='--', alpha=0.7)
    fig.tight_layout(rect=[0, 0, 0.85, 1])
    max_len = max(len(hist) for hist in histories)
    for step in range(1, max_len+1):
        ax.clear()
        for i, (hist, label) in enumerate(zip(histories, labels)):
            if len(hist) >= step:
                ax.plot(np.arange(1, step+1), hist[:step], marker=markers[i % len(markers)], color=colors[i % len(colors)], label=label, linewidth=2, markersize=8)
            else:
                ax.plot(np.arange(1, len(hist)+1), hist, marker=markers[i % len(markers)], color=colors[i % len(colors)], label=label, linewidth=2, markersize=8)
        ax.set_xlabel("Iteration", fontsize=14)
        ax.set_ylabel("Energy (Hartree)", fontsize=14)
        ax.set_title(title, fontsize=16, fontweight='bold')
        ax.grid(True, which='both', linestyle='--', alpha=0.7)
        ax.legend(loc='upper left', bbox_to_anchor=(1, 1), fontsize=13)
        fig.tight_layout(rect=[0, 0, 0.85, 1])
        yield fig
        time.sleep(0.15)

def get_hamiltonian_terms(ham_system, n_terms=10):
    """Return first n terms of the Hamiltonian as a formatted string."""
    qubit_op = ham_system['hamiltonian_active']
    labels = qubit_op.paulis.to_labels()
    coeffs = qubit_op.coeffs
    terms = [
        f"{coeff.real:+.8f} * {lbl}"
        for lbl, coeff in zip(labels, coeffs)
        if abs(complex(coeff)) > 1e-12
    ]
    return "\n".join(terms[:n_terms])

def get_ansatz_circuit(ansatz):
    """Visualize ansatz_circuit: mpl drawer if possible, else text drawer as image."""
    circ = getattr(ansatz, 'ansatz_circuit', None)
    if circ is None or not isinstance(circ, QuantumCircuit):
        return "Error: ansatz_circuit not found or not a QuantumCircuit object."
    try:
        fig = circ.draw(output='mpl', style={'fontsize': 10, 'font': 'monospace'})
        plt.close(fig)
        return fig
    except Exception as e:
        # Fallback: text drawer as image
        text = circ.draw(output='text')
        fig = plt.figure(figsize=(12, 4))
        plt.axis('off')
        plt.text(0.01, 0.5, str(text), fontsize=10, fontfamily='monospace', va='center', ha='left')
        plt.tight_layout()
        plt.close(fig)
        return fig

def get_summary_table(summary_rows):
    """Format summary table as markdown."""
    header = "| Variant | Final Energy (Ha) | Best (Ha) | Δ (Ha) | Iters | Params |\n|---|---|---|---|---|---|"
    rows = []
    for row in summary_rows:
        dE = row['improvement']
        rows.append(f"| {row['variant']} | {row['final_energy']:.8f} | {row['best_energy']:.8f} | {dE:.6f} | {row['iterations']} | {row['parameters']} |")
    return header + "\n" + "\n".join(rows)

# --- Load objects from Colab session ---
# These should be available if you have run the notebook cells.
# If not, you can run the notebook cells first.

# --- Gradio UI ---
PIXEL_FONT_URL = "https://fonts.googleapis.com/css2?family=Press+Start+2P&display=swap"
pixel_font_css = (
    "@import url('" + PIXEL_FONT_URL + "');\n"
    ".gradio-container, .gradio-markdown, .gradio-input, .gradio-output, .gradio-button, .gradio-label, .gradio-plot, .gradio-textbox, .gradio-tab, .gradio-radio, .gradio-checkbox, .gradio-dropdown, .gradio-table, .gradio-html, .gradio-markdown h1, .gradio-markdown h2, .gradio-markdown h3, .gradio-markdown h4, .gradio-markdown h5, .gradio-markdown h6 {\n"
    "    font-family: 'Press Start 2P', 'monospace', 'Menlo', 'Roboto Mono', monospace !important;\n"
    "    letter-spacing: 1px;\n"
    "    font-size: 13px !important;\n"
    "}\n"
    ".gradio-button {\n"
    "    font-size: 13px !important;\n"
    "    padding: 8px 18px !important;\n"
    "    border-radius: 6px !important;\n"
    "    background: #222 !important;\n"
    "    color: #fff !important;\n"
    "    border: 2px solid #888 !important;\n"
    "    box-shadow: 2px 2px 0 #888;\n"
    "}\n"
)

with gr.Blocks(theme="soft", css=pixel_font_css) as demo:
    gr.Markdown("# NEBULA : Enhanced VQE: Hybrid Initialization, Adaptive Optimization & Noise Mitigation")
    gr.Markdown("Interact with NH₃/H₂ VQE experiments. Each tab provides a different aspect of the workflow. Run notebook cells first to populate results.")

    with gr.Tab("Basic VQE"):
        btn_basic = gr.Button("Show Basic VQE Results")
        gr.Markdown("### Energy Reduction Step-by-Step")
        energy_plot = gr.Plot(label="Energy Reduction Graph")
        final_energy = gr.Textbox(label="Final Computed Energy", interactive=False)

        def show_basic_vqe():
            energy_hist = get_energy_history(globals().get('vqe_basic'))
            if len(energy_hist) == 0:
                yield None, "N/A"
                return
            for fig in live_plot_energy_reduction(energy_hist, "Basic VQE Energy Reduction"):
                yield fig, ""
            yield fig, str(energy_hist[-1])
        btn_basic.click(show_basic_vqe, outputs=[energy_plot, final_energy])

    with gr.Tab("Hamiltonian Operator"):
        btn_ham = gr.Button("Show Hamiltonian Terms")
        gr.Markdown("### First 10 Terms of Hamiltonian")
        hamiltonian_terms = gr.Textbox(label="Hamiltonian Terms", lines=12, interactive=False)

        def show_hamiltonian():
            ham = globals().get('ham_system')
            if ham:
                terms = get_hamiltonian_terms(ham, 10)
            else:
                terms = "Hamiltonian not found. Run Cell 2 in notebook."
            for partial in live_text_reveal(terms):
                yield partial
        btn_ham.click(show_hamiltonian, outputs=hamiltonian_terms)

    with gr.Tab("UCCSD Ansatz Circuit"):
        btn_circuit = gr.Button("Show UCCSD Circuit")
        gr.Markdown("### UCCSD Ansatz Circuit Visualization")
        circuit_plot = gr.Plot(label="UCCSD Circuit")

        def show_circuit():
            ansatz = globals().get('uccsd_ansatz')
            if ansatz:
                fig = get_ansatz_circuit(ansatz)
                yield fig
            else:
                yield "Ansatz not found. Run Cell 3 in notebook."
        btn_circuit.click(show_circuit, outputs=circuit_plot)

    with gr.Tab("Optimizer Experiments"):
        btn_all = gr.Button("Show All Comparison Graphs")
        gr.Markdown("### Compare Optimizer Variants (5 Graphs)")
        graph1 = gr.Plot(label="Baseline HF Energy ")
        graph2 = gr.Plot(label="CoordinateDescent Energy ")
        graph3 = gr.Plot(label="Basic (SPSA) Energy ")
        graph4 = gr.Plot(label="Hybrid (SPSA->COBYLA) Energy ")
        graph5 = gr.Plot(label="Hybrid+ZNE Energy ")
        all_graph = gr.Plot(label="All Variants Comparison")

        def show_all_graphs():
            variants = [
                ('Baseline HF', 'baseline_obj'),
                ('CoordinateDescent', 'vqe_cd'),
                ('Basic (SPSA)', 'vqe_basic'),
                ('Hybrid (SPSA->COBYLA)', 'vqe_hybrid'),
                ('Hybrid+ZNE', 'vqe_hybrid_zne')
            ]
            histories = []
            figs = []
            # Show all 5 graphs as static images first
            for label, obj_name in variants:
                obj = globals().get(obj_name)
                hist = get_energy_history(obj) if obj else np.array([])
                histories.append(hist)
                figs.append(plot_energy_reduction(hist, f"{label} Energy "))
            yield figs[0], figs[1], figs[2], figs[3], figs[4], None
            # Animate all variants comparison
            for all_fig in live_plot_all_histories(histories, [v[0] for v in variants], "All VQE Variants Energy Comparison"):
                yield figs[0], figs[1], figs[2], figs[3], figs[4], all_fig
            # Final output
            all_fig = plot_all_histories(histories, [v[0] for v in variants], "All VQE Variants Energy Comparison")
            yield figs[0], figs[1], figs[2], figs[3], figs[4], all_fig
        btn_all.click(show_all_graphs, outputs=[graph1, graph2, graph3, graph4, graph5, all_graph])

    with gr.Tab("Extras"):
        btn_notes = gr.Button("Save Note")
        gr.Markdown("### Add Notes or Observations")
        notes = gr.Textbox(label="Your Notes", lines=6, interactive=True)
        notes_display = gr.Markdown()

        def save_note(note):
            return f"*Your Note:*\n\n{note}"
        btn_notes.click(save_note, inputs=notes, outputs=notes_display)

    with gr.Tab("Summary Cell"):
        btn_summary = gr.Button("Show Summary Table")
        gr.Markdown("### VQE Results Summary Table")
        summary_md = gr.Markdown()

        def show_summary():
            rows = globals().get('summary_rows', [])
            if rows:
                table = get_summary_table(rows)
            else:
                table = "No summary available. Run summary cell in notebook."
            for partial in live_text_reveal(table):
                yield partial
        btn_summary.click(show_summary, outputs=summary_md)

    demo.launch()
# Out:
# It looks like you are running Gradio on a hosted Jupyter notebook, which requires `share=True`. Automatically setting `share=True` (you can turn this off by setting `share=False` in `launch()` explicitly).
#
# Colab notebook detected. To show errors in colab notebook, set debug=True in launch()
# * Running on public URL: https://109d16c9b92750992c.gradio.live
#
# This share link expires in 1 week. For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://109d16c9b92750992c.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
